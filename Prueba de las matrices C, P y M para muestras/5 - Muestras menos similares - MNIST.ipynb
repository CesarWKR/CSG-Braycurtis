# %% [markdown]
# # Librerias

# %%
# Carga de librerías
import numpy as np
import tensorflow as tf
import PIL
import PIL.Image
import pathlib
import scipy as sp
import seaborn as sns
from itertools import product
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
import os
import pathlib
from pathlib import Path
# Out:
# WARNING:tensorflow:From C:\Users\Cesar\AppData\Local\Temp\ipykernel_14664\3157514746.py:13: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.

# %%
import pickle
import sys
from pathlib import Path

# Añadir el directorio raíz del proyecto a sys.path
module_path = Path('/Users/Cesar/Desktop/Proyecto-CSG/').resolve()
if module_path not in sys.path:
    sys.path.append(str(module_path))

# Añadir el directorio que contiene 'new_spectral_metric' a sys.path
new_spectral_metric_path = module_path / '/Users/Cesar/Desktop/Proyecto-CSG/new_spectral_metric/'
if new_spectral_metric_path not in sys.path:
    sys.path.append(str(new_spectral_metric_path))

from numpy.linalg import LinAlgError
from scipy.sparse.csgraph import laplacian
# from spectral_metric.lib import find_samples, compute_expectation_with_monter_carlo 
from new_spectral_metric.new_estimator_intra_class import CumulativeGradientEstimator
from new_spectral_metric.new_visualize import make_graph
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Conv2D, Dense, MaxPooling2D, Lambda
from tensorflow.keras import backend as K
from pathlib import Path
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from matplotlib.collections import LineCollection
from matplotlib.font_manager import FontProperties
from pathlib import Path

# %% [markdown]
# # DATASET DESDE DIRECTORIO

# %%
#Lectura de dataset

directorio_dataset = ('../Datasets/MNIST')
directorio_dataset = pathlib.Path(directorio_dataset)

# Lectura de la carpeta train
directorio_train = ('../Datasets/MNIST/train')
directorio_train = pathlib.Path(directorio_train)

# Lectura de la carpeta test
directorio_test = ('../Datasets/MNIST/test')
directorio_test = pathlib.Path(directorio_test)

total_dataset = len(list(directorio_dataset.glob('*/*/*.png')))  # Cuenta la cantidad de imagenes del dataset (Aqui busca en las subcarpetas del directorio del dataset)
total_train = len(list(directorio_train.glob('*/*.png')))  # Cuenta la cantidad de imagenes de train
total_test = len(list(directorio_test.glob('*/*.png')))  # Cuenta la cantidad de imagenes de test

print(f"Total imagenes dataset: {total_dataset}")
print(f"Total imagenes train: {total_train}")
print(f"Total imagenes test: {total_test}")
# Out:
# Total imagenes dataset: 70000
# Total imagenes train: 60000
# Total imagenes test: 10000

# %%
# Definir el batchsize del dataset completo
batch_size_total = total_dataset

# %%
# Dimensiones de imagen y tamaño de batch en train
img_height = 28
img_width = 28
#batch_size = 32
batch_size_train = total_train

# %%
import tensorflow as tf
import pathlib

# Data splitting (entrenamiento y validación)
train_images = tf.keras.preprocessing.image_dataset_from_directory(
  directorio_train,
  #validation_split=0.2,
  color_mode='rgb',
  label_mode='int',
  #subset="training",
  #seed=123,
  shuffle=False,
  image_size=(img_height, img_width),
  batch_size=batch_size_train)
# Out:
# Found 60000 files belonging to 10 classes.

# %%
# Dimensiones de imagen y tamaño de batch en test
img_height = 28
img_width = 28
#batch_size = 32
batch_size_test = total_test

# %%
# Data splitting (entrenamiento y validación)
test_images = tf.keras.preprocessing.image_dataset_from_directory(
  directorio_test,
  #validation_split=0.2,
  color_mode='rgb',
  label_mode='int',
  #subset="training",
  #seed=123,
  shuffle=False,
  image_size=(img_height, img_width),
  batch_size=batch_size_test)
# Out:
# Found 10000 files belonging to 10 classes.

# %%
# Contar el total de imágenes por clase en train y test  
class_counts_total = {p.name: len(list(p.glob('*.png'))) for p in directorio_dataset.glob('*/*')}  
class_counts_train = {p.name: len(list(p.glob('*.png'))) for p in directorio_train.glob('*')}  
class_counts_test = {p.name: len(list(p.glob('*.png'))) for p in directorio_test.glob('*')}  

# Encontrar el valor más bajo de imágenes por clase en train  
menor_train = min(class_counts_train.values()) if class_counts_train else None  # Se almacena el valor de la clase que menos muestras tiene

# Encontrar el valor más bajo de imágenes por clase en test  
menor_test = min(class_counts_test.values()) if class_counts_test else None  # Se almacena el valor de la clase que menos muestras tiene

# Mostrar el total de imágenes por clase en train  
print("\nTotal de imágenes por clase en train:")  
for class_name, count in class_counts_train.items():  
    print(f"Clase: {class_name}, Número de imágenes: {count}")  
print(f"Total imágenes train: {sum(class_counts_train.values())}")  

# Mostrar el valor más bajo en train  
print(f"Menor número de imágenes en train: {menor_train}")  

# Mostrar el total de imágenes por clase en test  
print("\nTotal de imágenes por clase en test:")  
for class_name, count in class_counts_test.items():  
    print(f"Clase: {class_name}, Número de imágenes: {count}")  
print(f"Total imágenes test: {sum(class_counts_test.values())}")  

# Mostrar el valor más bajo en test  
print(f"Menor número de imágenes en test: {menor_test}")
# Out:
# Total de imágenes por clase en train:
# Clase: 0_train, Número de imágenes: 5923
# Clase: 1_train, Número de imágenes: 6742
# Clase: 2_train, Número de imágenes: 5958
# Clase: 3_train, Número de imágenes: 6131
# Clase: 4_train, Número de imágenes: 5842
# Clase: 5_train, Número de imágenes: 5421
# Clase: 6_train, Número de imágenes: 5918
# Clase: 7_train, Número de imágenes: 6265
# Clase: 8_train, Número de imágenes: 5851
# Clase: 9_train, Número de imágenes: 5949
# Total imágenes train: 60000
# Menor número de imágenes en train: 5421
#
# Total de imágenes por clase en test:
# Clase: 0_test, Número de imágenes: 980
# Clase: 1_test, Número de imágenes: 1135
# Clase: 2_test, Número de imágenes: 1032
# Clase: 3_test, Número de imágenes: 1010
# Clase: 4_test, Número de imágenes: 982
# Clase: 5_test, Número de imágenes: 892
# Clase: 6_test, Número de imágenes: 958
# Clase: 7_test, Número de imágenes: 1028
# Clase: 8_test, Número de imágenes: 974
# Clase: 9_test, Número de imágenes: 1009
# Total imágenes test: 10000
# Menor número de imágenes en test: 892

# %%
# Nombres de las clases
class_names_train = list(class_counts_train.keys())
class_names_test = list(class_counts_test.keys())
#class_names_total = sorted(list(set(class_names_train + class_names_test)))
class_names_total = list(class_counts_total.keys())

# Mostrar el número de clases y los nombres
print(f"\nNúmero de clases en train: {len(class_names_train)}")
print(f"Nombres de las clases en train: {class_names_train}")

print(f"\nNúmero de clases en test: {len(class_names_test)}")
print(f"Nombres de las clases en test: {class_names_test}")

print(f"\nNúmero total de clases en el dataset: {len(class_names_total)}")   # Este valor cambia si el nombre de las clases es diferente
print(f"Nombres de todas las clases en el dataset: {class_names_total}")     # Este valor tambien cambia si el nombre de las clases es diferente
# Out:
# Número de clases en train: 10
# Nombres de las clases en train: ['0_train', '1_train', '2_train', '3_train', '4_train', '5_train', '6_train', '7_train', '8_train', '9_train']
#
# Número de clases en test: 10
# Nombres de las clases en test: ['0_test', '1_test', '2_test', '3_test', '4_test', '5_test', '6_test', '7_test', '8_test', '9_test']
#
# Número total de clases en el dataset: 20
# Nombres de todas las clases en el dataset: ['0_test', '1_test', '2_test', '3_test', '4_test', '5_test', '6_test', '7_test', '8_test', '9_test', '0_train', '1_train', '2_train', '3_train', '4_train', '5_train', '6_train', '7_train', '8_train', '9_train']

# %%
for images, labels0 in train_images.take(1):  # only take first element of dataset
    numpy_all_images = images.numpy()  # convertir el tensor de imágenes en un arreglo de numpy y ahora contiene las imágenes del conjunto de datos en formato de numpy.
    numpy_all_labels = labels0.numpy()  # convierte el tensor de etiquetas en un arreglo de numpy y ahora contiene las etiquetas del conjunto de datos en formato de numpy

numpy_all_images /= 255.0  # Scale the features to the [0, 1] range
print(numpy_all_images.shape)

# CIFAR-10 
fully_dataset_train = numpy_all_images.reshape((numpy_all_images.shape[0], numpy_all_images.shape[1]*numpy_all_images.shape[2]*numpy_all_images.shape[3])) # es un arreglo bidimensional donde cada fila representa una imagen y cada columna representa un píxel de la imagen
fully_labels_train = numpy_all_labels.reshape(numpy_all_labels.shape[0],)
# Out:
# (60000, 28, 28, 3)

# %% [markdown]
# # Dataset complexity using CSG

# %%
estimator = CumulativeGradientEstimator(M_sample=menor_train, k_nearest=10)  # Utiliza el numero menor de muestras encontrado en cada clase dependiendo si es train o test
estimator.fit(data=fully_dataset_train, target=fully_labels_train)
csg = estimator.csg  # The actual complexity values.
estimator.evals, estimator.evecs  # The eigenvalues and vectors.

make_graph(estimator.difference, title="Dataset Complexity - MNIST: "+str(csg), classes=class_names_train)
# Out:
# C:\Users\Cesar\Desktop\Proyecto-CSG\new_spectral_metric\new_visualize.py:48: RuntimeWarning: divide by zero encountered in divide
#   similarities = difference.max() / difference * 100
# C:\Users\Cesar\Desktop\Proyecto-CSG\new_spectral_metric\new_visualize.py:59: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# # Calcular la similitud entre clases

# %%
from scipy.stats import entropy
import pandas as pd

# Calcular la entropía por clase  
entropy_per_class = entropy(estimator.W / estimator.W.sum(-1)[:, None], axis=-1)  

# Encontrar la clase menos confusa (menor entropía)  
least_confused_class_index = np.argmin(entropy_per_class)  
least_confused_class_name = class_names_train[least_confused_class_index]  

print("Class that is the least confused (lowest entropy):", least_confused_class_name)
# Out:
# Class that is the least confused (lowest entropy): 0_train

# %%
# Obtener los índices de los pares menos similares  
pairs = list(zip(*np.unravel_index(np.argsort(estimator.W, axis=None), estimator.W.shape)))  

# Filtrar pares donde i != j para evitar pares de la misma clase  
pairs = [(i, j) for i, j in pairs if i != j]  

print("Least similar pairs")  
lst = []  
seen_pairs = set()  

# Iterar sobre los primeros 10 pares menos similares  
for i, j in pairs:  
    # Verificar si el par o su inverso ya ha sido visto  
    if (i, j) not in seen_pairs and (j, i) not in seen_pairs:  
        lst.append({"Intent pair": f"{class_names_train[i]} <> {class_names_train[j]}", "Similarity": estimator.W[i, j]})  
        seen_pairs.add((i, j))  
        seen_pairs.add((j, i))  
    
    # Detenerse después de encontrar 10 pares únicos  
    if len(lst) == 10:  
        break  

# Mostrar los resultados en un DataFrame  
print(pd.DataFrame(lst))
# Out:
# Least similar pairs
#           Intent pair  Similarity
# 0  0_train <> 1_train    0.005257
# 1  1_train <> 6_train    0.005331
# 2  7_train <> 0_train    0.006180
# 3  6_train <> 7_train    0.006733
# 4  5_train <> 1_train    0.009371
# 5  3_train <> 0_train    0.009574
# 6  0_train <> 4_train    0.009703
# 7  9_train <> 1_train    0.010017
# 8  1_train <> 3_train    0.010810
# 9  6_train <> 4_train    0.010939

# %% [markdown]
# # Obtener los nombres de las imagenes en train o test (dependiendo de lo que se quiera probar)

# %%
# Obtener todos los nombres de archivo en el dataset
filenames = [str(f) for f in directorio_train.glob('*/*.png')]

# Crear un mapeo de índices a rutas completas de archivo  
filenames_dict = {i: str(f) for i, f in enumerate(directorio_train.glob('*/*.png'))}

# %% [markdown]
# # Calcular la similitud entre muestras

# %% [markdown]
# # 1. Visualizar las muestras (par de imagenes) menos similares entre la misma clase

# %%
# Función para encontrar y mostrar las imágenes menos similares dentro de cada clase usando la matriz C  
def show_least_similar_using_C_all_classes(estimator, class_names, filenames_dict):  
    images_to_show = []  # Lista para almacenar las imágenes y sus detalles  

    # Primero, recorre las clases y genera la lista de descripciones  
    for class_intent in range(len(class_names)):  
        class_name = class_names[class_intent]  
        print(f"Clase: {class_name}")  
        
        # Obtener la matriz de similitud de las muestras dentro de la clase  
        C = estimator.C[class_intent]  
        
        # Ordenar los índices según las similitudes (de menor a mayor)  
        least_similar_indices = np.argsort(C, axis=None)  
        
        shown_pairs = set()  # Para rastrear los pares de índices ya mostrados  
        count = 0  
        show_samples = 20  # Número de muestras para visualizar la similitud  
        
        for idx in least_similar_indices:  
            if count >= show_samples:  
                break  
            
            # Convertir el índice plano a índice 2D  
            idx_2d = np.unravel_index(idx, C.shape)  
            
            # Saltar las comparaciones de una muestra consigo misma  
            if idx_2d[0] == idx_2d[1]:  
                continue  
            
            # Crear un par ordenado de índices para prevenir duplicados  
            index_pair = tuple(sorted((idx_2d[0], idx_2d[1])))  
            
            # Verificamos si el par ya fue mostrado  
            if index_pair in shown_pairs:  
                continue  
            
            shown_pairs.add(index_pair)  
            
            # Obtener los índices de las muestras en el dataset  
            source_idx = estimator.class_indices[class_intent][idx_2d[0]]  
            target_idx = estimator.class_indices[class_intent][idx_2d[1]]  
            
            # Verificar que los índices estén dentro de los límites del dataset  
            if source_idx < len(filenames_dict) and target_idx < len(filenames_dict):  
                source_filename = Path(filenames_dict[int(source_idx)])  
                target_filename = Path(filenames_dict[int(target_idx)])  
                
                value = C[idx_2d]  
                
                # Formatear y mostrar la salida  
                print(f"\t{source_filename.name} ({class_name}) vs {target_filename.name} ({class_name}), Similitud: {value:.4f}")  
                
                # Agrega los detalles a la lista para visualización  
                images_to_show.append((source_filename, target_filename, class_name, value))  
                
                count += 1  
    
    # Luego, realiza la visualización de las imágenes  
    for source_filename, target_filename, class_name, value in images_to_show:  
        img_source = plt.imread(source_filename)  
        img_target = plt.imread(target_filename)  
        
        fig, axs = plt.subplots(1, 2, figsize=(5, 3))  
        axs[0].imshow(img_source)  
        axs[0].set_title(f"{class_name}: \n{source_filename.name}", fontsize=8) 
        axs[0].axis('off')  # Elimina los ejes para centrar la atención en la imagen  
        
        axs[1].imshow(img_target)  
        axs[1].set_title(f"{class_name}: \n{target_filename.name}", fontsize=8)  
        axs[1].axis('off') 
        plt.suptitle(f"Similitud: {value:.4f}")  
        plt.subplots_adjust(wspace=0.3, hspace=0.3)  # Ajusta el espacio entre subtramas  
        plt.show()  


print("Muestras menos similares entre las imágenes de la misma clase \n")  
show_least_similar_using_C_all_classes(estimator, class_names_train, filenames_dict)
# Out:
# Muestras menos similares entre las imágenes de la misma clase
#
# Clase: 0_train
# 	38106.png (0_train) vs 8449.png (0_train), Similitud: 0.0015
# 	1102.png (0_train) vs 37921.png (0_train), Similitud: 0.0029
# 	24444.png (0_train) vs 8449.png (0_train), Similitud: 0.0034
# 	23120.png (0_train) vs 37921.png (0_train), Similitud: 0.0044
# 	1102.png (0_train) vs 8449.png (0_train), Similitud: 0.0049
# 	24444.png (0_train) vs 36783.png (0_train), Similitud: 0.0068
# 	59653.png (0_train) vs 1102.png (0_train), Similitud: 0.0073
# 	59653.png (0_train) vs 3734.png (0_train), Similitud: 0.0078
# 	51228.png (0_train) vs 36783.png (0_train), Similitud: 0.0083
# 	3734.png (0_train) vs 8449.png (0_train), Similitud: 0.0088
# 	27865.png (0_train) vs 37921.png (0_train), Similitud: 0.0093
# 	34014.png (0_train) vs 8449.png (0_train), Similitud: 0.0103
# 	37921.png (0_train) vs 44656.png (0_train), Similitud: 0.0117
# 	8449.png (0_train) vs 44656.png (0_train), Similitud: 0.0117
# 	42448.png (0_train) vs 8449.png (0_train), Similitud: 0.0122
# 	37921.png (0_train) vs 51490.png (0_train), Similitud: 0.0127
# 	246.png (0_train) vs 37921.png (0_train), Similitud: 0.0132
# 	19664.png (0_train) vs 8449.png (0_train), Similitud: 0.0132
# 	34919.png (0_train) vs 38106.png (0_train), Similitud: 0.0137
# 	37921.png (0_train) vs 54486.png (0_train), Similitud: 0.0137
# Clase: 1_train
# 	31727.png (1_train) vs 29609.png (1_train), Similitud: 0.0000
# 	31727.png (1_train) vs 27793.png (1_train), Similitud: 0.0000
# 	38415.png (1_train) vs 31727.png (1_train), Similitud: 0.0000
# 	12230.png (1_train) vs 31727.png (1_train), Similitud: 0.0010
# 	56071.png (1_train) vs 31727.png (1_train), Similitud: 0.0010
# 	31727.png (1_train) vs 19176.png (1_train), Similitud: 0.0010
# 	31727.png (1_train) vs 3592.png (1_train), Similitud: 0.0015
# 	31727.png (1_train) vs 47796.png (1_train), Similitud: 0.0015
# 	58147.png (1_train) vs 31727.png (1_train), Similitud: 0.0015
# 	38164.png (1_train) vs 31727.png (1_train), Similitud: 0.0020
# 	31727.png (1_train) vs 13449.png (1_train), Similitud: 0.0020
# 	31727.png (1_train) vs 35995.png (1_train), Similitud: 0.0029
# 	31727.png (1_train) vs 48573.png (1_train), Similitud: 0.0029
# 	31727.png (1_train) vs 43897.png (1_train), Similitud: 0.0034
# 	31727.png (1_train) vs 32204.png (1_train), Similitud: 0.0039
# 	31727.png (1_train) vs 26587.png (1_train), Similitud: 0.0054
# 	38487.png (1_train) vs 31727.png (1_train), Similitud: 0.0054
# 	58591.png (1_train) vs 31727.png (1_train), Similitud: 0.0059
# 	31727.png (1_train) vs 58561.png (1_train), Similitud: 0.0063
# 	31727.png (1_train) vs 4566.png (1_train), Similitud: 0.0063
# Clase: 2_train
# 	29967.png (2_train) vs 27413.png (2_train), Similitud: 0.0220
# 	52109.png (2_train) vs 35947.png (2_train), Similitud: 0.0225
# 	20967.png (2_train) vs 27413.png (2_train), Similitud: 0.0244
# 	11420.png (2_train) vs 59734.png (2_train), Similitud: 0.0259
# 	29967.png (2_train) vs 45779.png (2_train), Similitud: 0.0259
# 	35947.png (2_train) vs 47966.png (2_train), Similitud: 0.0264
# 	558.png (2_train) vs 35947.png (2_train), Similitud: 0.0269
# 	32751.png (2_train) vs 29967.png (2_train), Similitud: 0.0269
# 	22112.png (2_train) vs 39899.png (2_train), Similitud: 0.0288
# 	33505.png (2_train) vs 45501.png (2_train), Similitud: 0.0293
# 	18514.png (2_train) vs 35947.png (2_train), Similitud: 0.0298
# 	29967.png (2_train) vs 33930.png (2_train), Similitud: 0.0303
# 	29967.png (2_train) vs 50196.png (2_train), Similitud: 0.0317
# 	35947.png (2_train) vs 1988.png (2_train), Similitud: 0.0317
# 	2402.png (2_train) vs 45501.png (2_train), Similitud: 0.0317
# 	24360.png (2_train) vs 31188.png (2_train), Similitud: 0.0317
# 	35947.png (2_train) vs 24939.png (2_train), Similitud: 0.0322
# 	1852.png (2_train) vs 33930.png (2_train), Similitud: 0.0322
# 	35927.png (2_train) vs 55011.png (2_train), Similitud: 0.0322
# 	20710.png (2_train) vs 35947.png (2_train), Similitud: 0.0322
# Clase: 3_train
# 	53570.png (3_train) vs 18986.png (3_train), Similitud: 0.0347
# 	41565.png (3_train) vs 2092.png (3_train), Similitud: 0.0361
# 	13713.png (3_train) vs 13831.png (3_train), Similitud: 0.0381
# 	57474.png (3_train) vs 41565.png (3_train), Similitud: 0.0420
# 	52129.png (3_train) vs 23490.png (3_train), Similitud: 0.0420
# 	34048.png (3_train) vs 17062.png (3_train), Similitud: 0.0425
# 	32688.png (3_train) vs 52129.png (3_train), Similitud: 0.0444
# 	52394.png (3_train) vs 52129.png (3_train), Similitud: 0.0449
# 	14266.png (3_train) vs 41565.png (3_train), Similitud: 0.0454
# 	41565.png (3_train) vs 23490.png (3_train), Similitud: 0.0464
# 	52129.png (3_train) vs 47618.png (3_train), Similitud: 0.0469
# 	22522.png (3_train) vs 11693.png (3_train), Similitud: 0.0474
# 	14916.png (3_train) vs 11693.png (3_train), Similitud: 0.0474
# 	57474.png (3_train) vs 11693.png (3_train), Similitud: 0.0479
# 	11693.png (3_train) vs 21112.png (3_train), Similitud: 0.0479
# 	52129.png (3_train) vs 51274.png (3_train), Similitud: 0.0483
# 	11583.png (3_train) vs 17062.png (3_train), Similitud: 0.0483
# 	9074.png (3_train) vs 34048.png (3_train), Similitud: 0.0493
# 	14266.png (3_train) vs 39851.png (3_train), Similitud: 0.0493
# 	52014.png (3_train) vs 53570.png (3_train), Similitud: 0.0493
# Clase: 4_train
# 	31114.png (4_train) vs 18308.png (4_train), Similitud: 0.0273
# 	16068.png (4_train) vs 6810.png (4_train), Similitud: 0.0283
# 	1004.png (4_train) vs 4952.png (4_train), Similitud: 0.0283
# 	32830.png (4_train) vs 31114.png (4_train), Similitud: 0.0283
# 	17576.png (4_train) vs 54452.png (4_train), Similitud: 0.0298
# 	6810.png (4_train) vs 17576.png (4_train), Similitud: 0.0303
# 	18551.png (4_train) vs 54452.png (4_train), Similitud: 0.0303
# 	828.png (4_train) vs 5936.png (4_train), Similitud: 0.0308
# 	34750.png (4_train) vs 828.png (4_train), Similitud: 0.0317
# 	828.png (4_train) vs 52279.png (4_train), Similitud: 0.0322
# 	31114.png (4_train) vs 24514.png (4_train), Similitud: 0.0322
# 	24822.png (4_train) vs 828.png (4_train), Similitud: 0.0322
# 	17926.png (4_train) vs 6810.png (4_train), Similitud: 0.0327
# 	55490.png (4_train) vs 17406.png (4_train), Similitud: 0.0327
# 	40288.png (4_train) vs 17576.png (4_train), Similitud: 0.0332
# 	33726.png (4_train) vs 31114.png (4_train), Similitud: 0.0332
# 	828.png (4_train) vs 16912.png (4_train), Similitud: 0.0332
# 	49398.png (4_train) vs 31114.png (4_train), Similitud: 0.0332
# 	15376.png (4_train) vs 6810.png (4_train), Similitud: 0.0337
# 	6810.png (4_train) vs 53363.png (4_train), Similitud: 0.0337
# Clase: 5_train
# 	34365.png (5_train) vs 57942.png (5_train), Similitud: 0.0024
# 	34365.png (5_train) vs 29870.png (5_train), Similitud: 0.0054
# 	5414.png (5_train) vs 12572.png (5_train), Similitud: 0.0068
# 	36774.png (5_train) vs 5414.png (5_train), Similitud: 0.0068
# 	7740.png (5_train) vs 34365.png (5_train), Similitud: 0.0073
# 	51990.png (5_train) vs 57461.png (5_train), Similitud: 0.0093
# 	51990.png (5_train) vs 6431.png (5_train), Similitud: 0.0103
# 	12572.png (5_train) vs 34365.png (5_train), Similitud: 0.0103
# 	30448.png (5_train) vs 13699.png (5_train), Similitud: 0.0107
# 	47940.png (5_train) vs 14389.png (5_train), Similitud: 0.0112
# 	36774.png (5_train) vs 13699.png (5_train), Similitud: 0.0112
# 	5414.png (5_train) vs 49460.png (5_train), Similitud: 0.0117
# 	11115.png (5_train) vs 51990.png (5_train), Similitud: 0.0117
# 	34365.png (5_train) vs 36774.png (5_train), Similitud: 0.0122
# 	31242.png (5_train) vs 34365.png (5_train), Similitud: 0.0127
# 	51990.png (5_train) vs 59993.png (5_train), Similitud: 0.0127
# 	36774.png (5_train) vs 53715.png (5_train), Similitud: 0.0127
# 	57461.png (5_train) vs 55322.png (5_train), Similitud: 0.0127
# 	37448.png (5_train) vs 34365.png (5_train), Similitud: 0.0132
# 	34365.png (5_train) vs 50322.png (5_train), Similitud: 0.0132
# Clase: 6_train
# 	35026.png (6_train) vs 3136.png (6_train), Similitud: 0.0273
# 	18908.png (6_train) vs 3136.png (6_train), Similitud: 0.0361
# 	33790.png (6_train) vs 3136.png (6_train), Similitud: 0.0361
# 	53398.png (6_train) vs 3136.png (6_train), Similitud: 0.0366
# 	3136.png (6_train) vs 4170.png (6_train), Similitud: 0.0381
# 	2588.png (6_train) vs 3136.png (6_train), Similitud: 0.0415
# 	3136.png (6_train) vs 1190.png (6_train), Similitud: 0.0415
# 	3136.png (6_train) vs 12220.png (6_train), Similitud: 0.0420
# 	35734.png (6_train) vs 3136.png (6_train), Similitud: 0.0430
# 	53398.png (6_train) vs 39709.png (6_train), Similitud: 0.0430
# 	38936.png (6_train) vs 3136.png (6_train), Similitud: 0.0435
# 	3136.png (6_train) vs 9860.png (6_train), Similitud: 0.0444
# 	28066.png (6_train) vs 15183.png (6_train), Similitud: 0.0459
# 	3136.png (6_train) vs 44128.png (6_train), Similitud: 0.0469
# 	34698.png (6_train) vs 3136.png (6_train), Similitud: 0.0474
# 	45580.png (6_train) vs 35026.png (6_train), Similitud: 0.0479
# 	18220.png (6_train) vs 16188.png (6_train), Similitud: 0.0479
# 	9534.png (6_train) vs 53398.png (6_train), Similitud: 0.0479
# 	9075.png (6_train) vs 8224.png (6_train), Similitud: 0.0483
# 	3136.png (6_train) vs 15134.png (6_train), Similitud: 0.0488
# Clase: 7_train
# 	20720.png (7_train) vs 45811.png (7_train), Similitud: 0.0122
# 	54871.png (7_train) vs 34314.png (7_train), Similitud: 0.0156
# 	41535.png (7_train) vs 28670.png (7_train), Similitud: 0.0215
# 	15554.png (7_train) vs 41535.png (7_train), Similitud: 0.0229
# 	9235.png (7_train) vs 5068.png (7_train), Similitud: 0.0259
# 	16264.png (7_train) vs 57672.png (7_train), Similitud: 0.0259
# 	586.png (7_train) vs 1127.png (7_train), Similitud: 0.0264
# 	55291.png (7_train) vs 34314.png (7_train), Similitud: 0.0283
# 	5068.png (7_train) vs 31300.png (7_train), Similitud: 0.0283
# 	28670.png (7_train) vs 44323.png (7_train), Similitud: 0.0283
# 	28670.png (7_train) vs 16264.png (7_train), Similitud: 0.0293
# 	52486.png (7_train) vs 28670.png (7_train), Similitud: 0.0293
# 	46009.png (7_train) vs 5068.png (7_train), Similitud: 0.0293
# 	46009.png (7_train) vs 39316.png (7_train), Similitud: 0.0293
# 	16264.png (7_train) vs 14522.png (7_train), Similitud: 0.0293
# 	586.png (7_train) vs 28670.png (7_train), Similitud: 0.0298
# 	50664.png (7_train) vs 16264.png (7_train), Similitud: 0.0298
# 	16264.png (7_train) vs 50536.png (7_train), Similitud: 0.0298
# 	49933.png (7_train) vs 20720.png (7_train), Similitud: 0.0303
# 	39048.png (7_train) vs 28670.png (7_train), Similitud: 0.0303
# Clase: 8_train
# 	45954.png (8_train) vs 1120.png (8_train), Similitud: 0.0825
# 	25546.png (8_train) vs 8761.png (8_train), Similitud: 0.0850
# 	8761.png (8_train) vs 12032.png (8_train), Similitud: 0.0903
# 	20157.png (8_train) vs 25546.png (8_train), Similitud: 0.0933
# 	8701.png (8_train) vs 25546.png (8_train), Similitud: 0.0947
# 	30777.png (8_train) vs 10064.png (8_train), Similitud: 0.0957
# 	25546.png (8_train) vs 8867.png (8_train), Similitud: 0.0962
# 	1120.png (8_train) vs 49543.png (8_train), Similitud: 0.0967
# 	30147.png (8_train) vs 25546.png (8_train), Similitud: 0.0972
# 	42504.png (8_train) vs 25232.png (8_train), Similitud: 0.0977
# 	33074.png (8_train) vs 10358.png (8_train), Similitud: 0.0981
# 	8761.png (8_train) vs 31972.png (8_train), Similitud: 0.1006
# 	42504.png (8_train) vs 43109.png (8_train), Similitud: 0.1006
# 	7851.png (8_train) vs 1120.png (8_train), Similitud: 0.1011
# 	10064.png (8_train) vs 25232.png (8_train), Similitud: 0.1021
# 	10064.png (8_train) vs 14478.png (8_train), Similitud: 0.1025
# 	46504.png (8_train) vs 42504.png (8_train), Similitud: 0.1050
# 	1120.png (8_train) vs 17609.png (8_train), Similitud: 0.1055
# 	35232.png (8_train) vs 32253.png (8_train), Similitud: 0.1069
# 	10358.png (8_train) vs 53006.png (8_train), Similitud: 0.1069
# Clase: 9_train
# 	9938.png (9_train) vs 2798.png (9_train), Similitud: 0.0093
# 	40804.png (9_train) vs 2798.png (9_train), Similitud: 0.0151
# 	2798.png (9_train) vs 32256.png (9_train), Similitud: 0.0181
# 	600.png (9_train) vs 2798.png (9_train), Similitud: 0.0181
# 	2798.png (9_train) vs 25900.png (9_train), Similitud: 0.0215
# 	20054.png (9_train) vs 2798.png (9_train), Similitud: 0.0225
# 	2798.png (9_train) vs 48224.png (9_train), Similitud: 0.0229
# 	2798.png (9_train) vs 49442.png (9_train), Similitud: 0.0244
# 	2798.png (9_train) vs 13728.png (9_train), Similitud: 0.0244
# 	15970.png (9_train) vs 2798.png (9_train), Similitud: 0.0254
# 	2798.png (9_train) vs 49690.png (9_train), Similitud: 0.0259
# 	21302.png (9_train) vs 2798.png (9_train), Similitud: 0.0259
# 	43058.png (9_train) vs 2798.png (9_train), Similitud: 0.0259
# 	27968.png (9_train) vs 2798.png (9_train), Similitud: 0.0264
# 	2798.png (9_train) vs 21592.png (9_train), Similitud: 0.0273
# 	38809.png (9_train) vs 2798.png (9_train), Similitud: 0.0273
# 	9876.png (9_train) vs 5746.png (9_train), Similitud: 0.0278
# 	2798.png (9_train) vs 3745.png (9_train), Similitud: 0.0278
# 	2798.png (9_train) vs 54335.png (9_train), Similitud: 0.0278
# 	58034.png (9_train) vs 2798.png (9_train), Similitud: 0.0283
