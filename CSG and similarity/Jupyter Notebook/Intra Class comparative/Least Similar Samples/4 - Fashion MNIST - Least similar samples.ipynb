# %% [markdown]
# # Librerias

# %%
# Carga de librerías
import numpy as np
import tensorflow as tf
import PIL
import PIL.Image
import pathlib
import scipy as sp
import seaborn as sns
from itertools import product
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
import os
import pathlib
from pathlib import Path
# Out:
# WARNING:tensorflow:From C:\Users\Cesar\AppData\Local\Temp\ipykernel_4052\3157514746.py:13: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.

# %%
import pickle
import sys
from pathlib import Path


from numpy.linalg import LinAlgError
from scipy.sparse.csgraph import laplacian
from new_spectral_metric.new_estimator_intra_class import CumulativeGradientEstimator_Intra_class
from new_spectral_metric.new_visualize import make_graph
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Conv2D, Dense, MaxPooling2D, Lambda
from tensorflow.keras import backend as K
from pathlib import Path
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from matplotlib.collections import LineCollection
from matplotlib.font_manager import FontProperties
from pathlib import Path

# %% [markdown]
# # DATASET DESDE DIRECTORIO

# %%
#Lectura de dataset

directorio_dataset = ('../../Datasets/Fashion_MNIST')
directorio_dataset = pathlib.Path(directorio_dataset)

# Lectura de la carpeta train
directorio_train = ('../../Datasets/Fashion_MNIST/train')
directorio_train = pathlib.Path(directorio_train)

# Lectura de la carpeta test
directorio_test = ('../../Datasets/Fashion_MNIST/test')
directorio_test = pathlib.Path(directorio_test)

total_dataset = len(list(directorio_dataset.glob('*/*/*.png')))  # Cuenta la cantidad de imagenes del dataset (Aqui busca en las subcarpetas del directorio del dataset)
total_train = len(list(directorio_train.glob('*/*.png')))  # Cuenta la cantidad de imagenes de train
total_test = len(list(directorio_test.glob('*/*.png')))  # Cuenta la cantidad de imagenes de test

print(f"Total imagenes dataset: {total_dataset}")
print(f"Total imagenes train: {total_train}")
print(f"Total imagenes test: {total_test}")
# Out:
# Total imagenes dataset: 70000
# Total imagenes train: 60000
# Total imagenes test: 10000

# %%
# Definir el batchsize del dataset completo
batch_size_total = total_dataset

# %%
# Dimensiones de imagen y tamaño de batch en train
img_height = 28
img_width = 28
#batch_size = 32
batch_size_train = total_train

# %%
import tensorflow as tf
import pathlib

# Data splitting (entrenamiento y validación)
train_images = tf.keras.preprocessing.image_dataset_from_directory(
  directorio_train,
  #validation_split=0.2,
  color_mode='rgb',
  label_mode='int',
  #subset="training",
  #seed=123,
  shuffle=False,
  image_size=(img_height, img_width),
  batch_size=batch_size_train)
# Out:
# Found 60000 files belonging to 10 classes.

# %%
# Dimensiones de imagen y tamaño de batch en test
img_height = 28
img_width = 28
#batch_size = 32
batch_size_test = total_test

# %%
# Data splitting (entrenamiento y validación)
test_images = tf.keras.preprocessing.image_dataset_from_directory(
  directorio_test,
  #validation_split=0.2,
  color_mode='rgb',
  label_mode='int',
  #subset="training",
  #seed=123,
  shuffle=False,
  image_size=(img_height, img_width),
  batch_size=batch_size_test)
# Out:
# Found 10000 files belonging to 10 classes.

# %%
# Contar el total de imágenes por clase en train y test  
class_counts_total = {p.name: len(list(p.glob('*.png'))) for p in directorio_dataset.glob('*/*')}  
class_counts_train = {p.name: len(list(p.glob('*.png'))) for p in directorio_train.glob('*')}  
class_counts_test = {p.name: len(list(p.glob('*.png'))) for p in directorio_test.glob('*')}  

# Encontrar el valor más bajo de imágenes por clase en train  
menor_train = min(class_counts_train.values()) if class_counts_train else None  # Se almacena el valor de la clase que menos muestras tiene

# Encontrar el valor más alto de imágenes por clase en train  
mayor_train = max(class_counts_train.values()) if class_counts_train else None  # Se almacena el valor de la clase que mas muestras tiene


# Encontrar el valor más bajo de imágenes por clase en test  
menor_test = min(class_counts_test.values()) if class_counts_test else None  # Se almacena el valor de la clase que menos muestras tiene

# Encontrar el valor más alto de imágenes por clase en test  
mayor_test = max(class_counts_test.values()) if class_counts_test else None  # Se almacena el valor de la clase que mas muestras tiene


# Mostrar el total de imágenes por clase en train  
print("\nTotal images per class in train:")  
for class_name, count in class_counts_train.items():  
    print(f"Class: {class_name}, Number of images: {count}")  
print(f"Total images train: {sum(class_counts_train.values())}")  

# Mostrar el valor más bajo en train  
print(f"Fewer number of images in train: {menor_train}")  

# Mostrar el valor más alto en train  
print(f"Higher number of images in train: {mayor_train}")  

# Mostrar el total de imágenes por clase en test  
print("\nTotal images per class in test:")  
for class_name, count in class_counts_test.items():  
    print(f"Class: {class_name}, Number of images: {count}")  
print(f"Total images test: {sum(class_counts_test.values())}")  

# Mostrar el valor más bajo en test  
print(f"Fewer images in test: {menor_test}")

# Mostrar el valor más alto en test  
print(f"Higher number of images in test: {mayor_test}")
# Out:
# Total images per class in train:
# Class: 0 - T shirt_top, Number of images: 6000
# Class: 1 - Trouser, Number of images: 6000
# Class: 2 - Pullover, Number of images: 6000
# Class: 3 - Dress, Number of images: 6000
# Class: 4 - Coat, Number of images: 6000
# Class: 5 - Sandal, Number of images: 6000
# Class: 6 - Shirt, Number of images: 6000
# Class: 7 - Sneaker, Number of images: 6000
# Class: 8 - Bag, Number of images: 6000
# Class: 9 - Ankle boot, Number of images: 6000
# Total images train: 60000
# Fewer number of images in train: 6000
# Higher number of images in train: 6000
#
# Total images per class in test:
# Class: 0 - T shirt_top, Number of images: 1000
# Class: 1 - Trouser, Number of images: 1000
# Class: 2 - Pullover, Number of images: 1000
# Class: 3 - Dress, Number of images: 1000
# Class: 4 - Coat, Number of images: 1000
# Class: 5 - Sandal, Number of images: 1000
# Class: 6 - Shirt, Number of images: 1000
# Class: 7 - Sneaker, Number of images: 1000
# Class: 8 - Bag, Number of images: 1000
# Class: 9 - Ankle boot, Number of images: 1000
# Total images test: 10000
# Fewer images in test: 1000
# Higher number of images in test: 1000

# %%
# Nombres de las clases
class_names_train = list(class_counts_train.keys())
class_names_test = list(class_counts_test.keys())
#class_names_total = sorted(list(set(class_names_train + class_names_test)))
class_names_total = list(class_counts_total.keys())

# Mostrar el número de clases y los nombres
print(f"\nNúmero de clases en train: {len(class_names_train)}")
print(f"Nombres de las clases en train: {class_names_train}")

print(f"\nNúmero de clases en test: {len(class_names_test)}")
print(f"Nombres de las clases en test: {class_names_test}")

print(f"\nNúmero total de clases en el dataset: {len(class_names_total)}")   # Este valor cambia si el nombre de las clases es diferente
print(f"Nombres de todas las clases en el dataset: {class_names_total}")     # Este valor tambien cambia si el nombre de las clases es diferente
# Out:
# Número de clases en train: 10
# Nombres de las clases en train: ['0 - T shirt_top', '1 - Trouser', '2 - Pullover', '3 - Dress', '4 - Coat', '5 - Sandal', '6 - Shirt', '7 - Sneaker', '8 - Bag', '9 - Ankle boot']
#
# Número de clases en test: 10
# Nombres de las clases en test: ['0 - T shirt_top', '1 - Trouser', '2 - Pullover', '3 - Dress', '4 - Coat', '5 - Sandal', '6 - Shirt', '7 - Sneaker', '8 - Bag', '9 - Ankle boot']
#
# Número total de clases en el dataset: 10
# Nombres de todas las clases en el dataset: ['0 - T shirt_top', '1 - Trouser', '2 - Pullover', '3 - Dress', '4 - Coat', '5 - Sandal', '6 - Shirt', '7 - Sneaker', '8 - Bag', '9 - Ankle boot']

# %%
for images, labels0 in train_images.take(1):  # only take first element of dataset
    numpy_all_images = images.numpy()  # convertir el tensor de imágenes en un arreglo de numpy y ahora contiene las imágenes del conjunto de datos en formato de numpy.
    numpy_all_labels = labels0.numpy()  # convierte el tensor de etiquetas en un arreglo de numpy y ahora contiene las etiquetas del conjunto de datos en formato de numpy

numpy_all_images /= 255.0  # Scale the features to the [0, 1] range
print(numpy_all_images.shape)

# CIFAR-10 
fully_dataset_train = numpy_all_images.reshape((numpy_all_images.shape[0], numpy_all_images.shape[1]*numpy_all_images.shape[2]*numpy_all_images.shape[3])) # es un arreglo bidimensional donde cada fila representa una imagen y cada columna representa un píxel de la imagen
fully_labels_train = numpy_all_labels.reshape(numpy_all_labels.shape[0],)
# Out:
# (60000, 28, 28, 3)

# %% [markdown]
# # Dataset complexity using CSG

# %%
estimator = CumulativeGradientEstimator_Intra_class(M_sample=mayor_train, k_nearest=10)  # Utiliza el numero menor de muestras encontrado en cada clase dependiendo si es train o test
estimator.fit(data=fully_dataset_train, target=fully_labels_train)
csg = estimator.csg  # The actual complexity values.
estimator.evals, estimator.evecs  # The eigenvalues and vectors.

make_graph(estimator.difference, title="Dataset Complexity - Fashion MNIST: "+str(csg), classes=class_names_train)
# Out:
# c:\Users\Cesar\AppData\Local\Programs\Python\Python312\Lib\site-packages\new_spectral_metric\new_visualize.py:48: RuntimeWarning: divide by zero encountered in divide
#   similarities = difference.max() / difference * 100
# c:\Users\Cesar\AppData\Local\Programs\Python\Python312\Lib\site-packages\new_spectral_metric\new_visualize.py:59: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# # Calcular la similitud entre clases

# %%
from scipy.stats import entropy
import pandas as pd

# Calcular la entropía por clase  
entropy_per_class = entropy(estimator.W / estimator.W.sum(-1)[:, None], axis=-1)  

# Encontrar la clase menos confusa (menor entropía)  
least_confused_class_index = np.argmin(entropy_per_class)  
least_confused_class_name = class_names_train[least_confused_class_index]  

print("Class that is the least confused (lowest entropy):", least_confused_class_name)
# Out:
# Class that is the least confused (lowest entropy): 9 - Ankle boot

# %%
# Obtener los índices de los pares menos similares  
pairs = list(zip(*np.unravel_index(np.argsort(estimator.W, axis=None), estimator.W.shape)))  

# Filtrar pares donde i != j para evitar pares de la misma clase  
pairs = [(i, j) for i, j in pairs if i != j]  

print("Least similar pairs")  
lst = []  
seen_pairs = set()  

# Iterar sobre los primeros 10 pares menos similares  
for i, j in pairs:  
    # Verificar si el par o su inverso ya ha sido visto  
    if (i, j) not in seen_pairs and (j, i) not in seen_pairs:  
        lst.append({"Intent pair": f"{class_names_train[i]} <> {class_names_train[j]}", "Similarity": estimator.W[i, j]})  
        seen_pairs.add((i, j))  
        seen_pairs.add((j, i))  
    
    # Detenerse después de encontrar 10 pares únicos  
    if len(lst) == 10:  
        break  

# Mostrar los resultados en un DataFrame  
print(pd.DataFrame(lst))
# Out:
# Least similar pairs
#                       Intent pair  Similarity
# 0      7 - Sneaker <> 1 - Trouser    0.000817
# 1         7 - Sneaker <> 4 - Coat    0.001050
# 2        7 - Sneaker <> 3 - Dress    0.001183
# 3        7 - Sneaker <> 6 - Shirt    0.001350
# 4     7 - Sneaker <> 2 - Pullover    0.001400
# 5  7 - Sneaker <> 0 - T shirt_top    0.001517
# 6      4 - Coat <> 9 - Ankle boot    0.001600
# 7     9 - Ankle boot <> 3 - Dress    0.001733
# 8   9 - Ankle boot <> 1 - Trouser    0.001783
# 9     6 - Shirt <> 9 - Ankle boot    0.001900

# %% [markdown]
# # Obtener los nombres de las imagenes en train o test (dependiendo de lo que se quiera probar)

# %%
# Obtener todos los nombres de archivo en el dataset
filenames = [str(f) for f in directorio_train.glob('*/*.png')]

# Crear un mapeo de índices a rutas completas de archivo  
filenames_dict = {i: str(f) for i, f in enumerate(directorio_train.glob('*/*.png'))}

# %% [markdown]
# # Calcular la similitud entre muestras

# %%
# Función para encontrar y mostrar las imágenes menos similares dentro de cada clase usando la matriz C  
def show_least_similar_using_C_all_classes(estimator, class_names, filenames_dict):  
    images_to_show = []  # Lista para almacenar las imágenes y sus detalles  

    # Primero, recorre las clases y genera la lista de descripciones  
    for class_intent in range(len(class_names)):  
        class_name = class_names[class_intent]  
        print(f"Clase: {class_name}")  
        
        # Obtener la matriz de similitud de las muestras dentro de la clase  
        C = estimator.C[class_intent]  

        # Imprimir la forma de la matriz de similitud de la clase  
        print(f"Shape of the class matrix {class_name}: {C.shape}")
        
        # Ordenar los índices según las similitudes (de menor a mayor)  
        least_similar_indices = np.argsort(C, axis=None)  
        
        shown_pairs = set()  # Para rastrear los pares de índices ya mostrados  
        count = 0  
        show_samples = 20  # Número de muestras para visualizar la similitud  
        
        # Diccionario para contar la participación de cada imagen  
        participation_count = {}

        for idx in least_similar_indices:  
            if count >= show_samples:  
                break  
            
            # Convertir el índice plano a índice 2D  
            idx_2d = np.unravel_index(idx, C.shape)  
            
            # Saltar las comparaciones de una muestra consigo misma  
            if idx_2d[0] == idx_2d[1]:  
                continue  
            
            # Crear un par ordenado de índices para prevenir duplicados  
            index_pair = tuple(sorted((idx_2d[0], idx_2d[1])))  
            
            # Verificamos si el par ya fue mostrado  
            if index_pair in shown_pairs:  
                continue  
            
            shown_pairs.add(index_pair)  
            
            # Actualizar el conteo de participación  
            participation_count[idx_2d[0]] = participation_count.get(idx_2d[0], 0) + 1  
            participation_count[idx_2d[1]] = participation_count.get(idx_2d[1], 0) + 1

            # Obtener los índices de las muestras en el dataset  
            source_idx = estimator.class_indices[class_intent][idx_2d[0]]  
            target_idx = estimator.class_indices[class_intent][idx_2d[1]]  
            
            # Verificar que los índices estén dentro de los límites del dataset  
            if source_idx < len(filenames_dict) and target_idx < len(filenames_dict):  
                source_filename = Path(filenames_dict[int(source_idx)])  
                target_filename = Path(filenames_dict[int(target_idx)])  
                
                value = C[idx_2d]  
                
                # Formatear y mostrar la salida  
                print(f"\t{source_filename.name} ({class_name}) vs {target_filename.name} ({class_name}), Similarity: {value:.4f}")  
                
                # Agrega los detalles a la lista para visualización  
                images_to_show.append((source_filename, target_filename, class_name, value))  
                
                count += 1  
    

        # Encontrar las muestras más atípicas  
        most_atypical = sorted(participation_count.items(), key=lambda x: -x[1])  
        
        # Mostrar las 10 más atípicas  
        print("\nMuestras más atípicas de esta clase:")  
        for rank, (img_idx, freq) in enumerate(most_atypical[:10], 1):  
            img_name = Path(filenames_dict[int(estimator.class_indices[class_intent][img_idx])]).name  
            print(f"\t#{rank}: {img_name} con {freq} apariciones")  
        print("\n")


    # Luego, realiza la visualización de las imágenes  
    for source_filename, target_filename, class_name, value in images_to_show:  
        img_source = plt.imread(source_filename)  
        img_target = plt.imread(target_filename)  
        
        fig, axs = plt.subplots(1, 2, figsize=(5, 3))  
        axs[0].imshow(img_source)  
        axs[0].set_title(f"{class_name}: \n{source_filename.name}", fontsize=8) 
        axs[0].axis('off')  # Elimina los ejes para centrar la atención en la imagen  
        
        axs[1].imshow(img_target)  
        axs[1].set_title(f"{class_name}: \n{target_filename.name}", fontsize=8)  
        axs[1].axis('off') 
        plt.suptitle(f"Similarity: {value:.4f}")  
        plt.subplots_adjust(wspace=0.3, hspace=0.3)  # Ajusta el espacio entre subtramas  
        plt.show()  


print("Muestras menos similares entre las imágenes de la misma clase \n")  
show_least_similar_using_C_all_classes(estimator, class_names_train, filenames_dict)
# Out:
# Muestras menos similares entre las imágenes de la misma clase
#
# Clase: 0 - T shirt_top
# Shape of the class matrix 0 - T shirt_top: (6000, 6000)
# 	55765.png (0 - T shirt_top) vs 13103.png (0 - T shirt_top), Similarity: 0.0432
# 	55765.png (0 - T shirt_top) vs 10181.png (0 - T shirt_top), Similarity: 0.0437
# 	10181.png (0 - T shirt_top) vs 5513.png (0 - T shirt_top), Similarity: 0.0450
# 	55765.png (0 - T shirt_top) vs 2372.png (0 - T shirt_top), Similarity: 0.0472
# 	17382.png (0 - T shirt_top) vs 55765.png (0 - T shirt_top), Similarity: 0.0489
# 	55765.png (0 - T shirt_top) vs 22576.png (0 - T shirt_top), Similarity: 0.0489
# 	55765.png (0 - T shirt_top) vs 45276.png (0 - T shirt_top), Similarity: 0.0493
# 	10181.png (0 - T shirt_top) vs 7593.png (0 - T shirt_top), Similarity: 0.0494
# 	55765.png (0 - T shirt_top) vs 14081.png (0 - T shirt_top), Similarity: 0.0503
# 	13137.png (0 - T shirt_top) vs 39750.png (0 - T shirt_top), Similarity: 0.0504
# 	39750.png (0 - T shirt_top) vs 791.png (0 - T shirt_top), Similarity: 0.0507
# 	51167.png (0 - T shirt_top) vs 55765.png (0 - T shirt_top), Similarity: 0.0514
# 	39750.png (0 - T shirt_top) vs 16541.png (0 - T shirt_top), Similarity: 0.0516
# 	39750.png (0 - T shirt_top) vs 17191.png (0 - T shirt_top), Similarity: 0.0516
# 	55483.png (0 - T shirt_top) vs 39750.png (0 - T shirt_top), Similarity: 0.0520
# 	23915.png (0 - T shirt_top) vs 39750.png (0 - T shirt_top), Similarity: 0.0524
# 	55765.png (0 - T shirt_top) vs 18514.png (0 - T shirt_top), Similarity: 0.0528
# 	22805.png (0 - T shirt_top) vs 39750.png (0 - T shirt_top), Similarity: 0.0529
# 	6207.png (0 - T shirt_top) vs 39750.png (0 - T shirt_top), Similarity: 0.0530
# 	15938.png (0 - T shirt_top) vs 55765.png (0 - T shirt_top), Similarity: 0.0532
#
# Muestras más atípicas de esta clase:
# 	#1: 55765.png con 10 apariciones
# 	#2: 39750.png con 8 apariciones
# 	#3: 10181.png con 3 apariciones
# 	#4: 13103.png con 1 apariciones
# 	#5: 5513.png con 1 apariciones
# 	#6: 2372.png con 1 apariciones
# 	#7: 17382.png con 1 apariciones
# 	#8: 22576.png con 1 apariciones
# 	#9: 45276.png con 1 apariciones
# 	#10: 7593.png con 1 apariciones
#
#
# Clase: 1 - Trouser
# Shape of the class matrix 1 - Trouser: (6000, 6000)
# 	32110.png (1 - Trouser) vs 26254.png (1 - Trouser), Similarity: 0.1111
# 	5188.png (1 - Trouser) vs 34547.png (1 - Trouser), Similarity: 0.1127
# 	5188.png (1 - Trouser) vs 46375.png (1 - Trouser), Similarity: 0.1136
# 	43542.png (1 - Trouser) vs 32110.png (1 - Trouser), Similarity: 0.1175
# 	33875.png (1 - Trouser) vs 32110.png (1 - Trouser), Similarity: 0.1181
# 	58065.png (1 - Trouser) vs 32110.png (1 - Trouser), Similarity: 0.1185
# 	32110.png (1 - Trouser) vs 46375.png (1 - Trouser), Similarity: 0.1186
# 	5556.png (1 - Trouser) vs 5188.png (1 - Trouser), Similarity: 0.1191
# 	5188.png (1 - Trouser) vs 43178.png (1 - Trouser), Similarity: 0.1193
# 	16730.png (1 - Trouser) vs 32110.png (1 - Trouser), Similarity: 0.1207
# 	3613.png (1 - Trouser) vs 32110.png (1 - Trouser), Similarity: 0.1210
# 	32110.png (1 - Trouser) vs 34547.png (1 - Trouser), Similarity: 0.1221
# 	5556.png (1 - Trouser) vs 32110.png (1 - Trouser), Similarity: 0.1223
# 	36400.png (1 - Trouser) vs 32110.png (1 - Trouser), Similarity: 0.1237
# 	32110.png (1 - Trouser) vs 35325.png (1 - Trouser), Similarity: 0.1270
# 	20809.png (1 - Trouser) vs 32110.png (1 - Trouser), Similarity: 0.1276
# 	32110.png (1 - Trouser) vs 2789.png (1 - Trouser), Similarity: 0.1284
# 	32110.png (1 - Trouser) vs 5192.png (1 - Trouser), Similarity: 0.1306
# 	19916.png (1 - Trouser) vs 32110.png (1 - Trouser), Similarity: 0.1307
# 	32110.png (1 - Trouser) vs 7058.png (1 - Trouser), Similarity: 0.1319
#
# Muestras más atípicas de esta clase:
# 	#1: 32110.png con 16 apariciones
# 	#2: 5188.png con 4 apariciones
# 	#3: 34547.png con 2 apariciones
# 	#4: 46375.png con 2 apariciones
# 	#5: 5556.png con 2 apariciones
# 	#6: 26254.png con 1 apariciones
# 	#7: 43542.png con 1 apariciones
# 	#8: 33875.png con 1 apariciones
# 	#9: 58065.png con 1 apariciones
# 	#10: 43178.png con 1 apariciones
#
#
# Clase: 2 - Pullover
# Shape of the class matrix 2 - Pullover: (6000, 6000)
# 	16361.png (2 - Pullover) vs 36674.png (2 - Pullover), Similarity: 0.0788
# 	23414.png (2 - Pullover) vs 18913.png (2 - Pullover), Similarity: 0.0798
# 	16361.png (2 - Pullover) vs 55368.png (2 - Pullover), Similarity: 0.0799
# 	11374.png (2 - Pullover) vs 16361.png (2 - Pullover), Similarity: 0.1009
# 	54621.png (2 - Pullover) vs 23414.png (2 - Pullover), Similarity: 0.1111
# 	53579.png (2 - Pullover) vs 23414.png (2 - Pullover), Similarity: 0.1116
# 	23414.png (2 - Pullover) vs 58583.png (2 - Pullover), Similarity: 0.1149
# 	16361.png (2 - Pullover) vs 14667.png (2 - Pullover), Similarity: 0.1149
# 	27683.png (2 - Pullover) vs 23414.png (2 - Pullover), Similarity: 0.1150
# 	23414.png (2 - Pullover) vs 57753.png (2 - Pullover), Similarity: 0.1153
# 	22955.png (2 - Pullover) vs 23414.png (2 - Pullover), Similarity: 0.1161
# 	23414.png (2 - Pullover) vs 59981.png (2 - Pullover), Similarity: 0.1165
# 	23414.png (2 - Pullover) vs 40241.png (2 - Pullover), Similarity: 0.1166
# 	22069.png (2 - Pullover) vs 23414.png (2 - Pullover), Similarity: 0.1168
# 	10570.png (2 - Pullover) vs 23414.png (2 - Pullover), Similarity: 0.1173
# 	15953.png (2 - Pullover) vs 23414.png (2 - Pullover), Similarity: 0.1175
# 	29432.png (2 - Pullover) vs 23414.png (2 - Pullover), Similarity: 0.1177
# 	26778.png (2 - Pullover) vs 23414.png (2 - Pullover), Similarity: 0.1179
# 	23414.png (2 - Pullover) vs 40487.png (2 - Pullover), Similarity: 0.1179
# 	23414.png (2 - Pullover) vs 16361.png (2 - Pullover), Similarity: 0.1182
#
# Muestras más atípicas de esta clase:
# 	#1: 23414.png con 16 apariciones
# 	#2: 16361.png con 5 apariciones
# 	#3: 36674.png con 1 apariciones
# 	#4: 18913.png con 1 apariciones
# 	#5: 55368.png con 1 apariciones
# 	#6: 11374.png con 1 apariciones
# 	#7: 54621.png con 1 apariciones
# 	#8: 53579.png con 1 apariciones
# 	#9: 58583.png con 1 apariciones
# 	#10: 14667.png con 1 apariciones
#
#
# Clase: 3 - Dress
# Shape of the class matrix 3 - Dress: (6000, 6000)
# 	34314.png (3 - Dress) vs 39077.png (3 - Dress), Similarity: 0.0910
# 	14842.png (3 - Dress) vs 34314.png (3 - Dress), Similarity: 0.1036
# 	34314.png (3 - Dress) vs 53509.png (3 - Dress), Similarity: 0.1082
# 	34314.png (3 - Dress) vs 21452.png (3 - Dress), Similarity: 0.1087
# 	34314.png (3 - Dress) vs 21859.png (3 - Dress), Similarity: 0.1127
# 	35649.png (3 - Dress) vs 34314.png (3 - Dress), Similarity: 0.1131
# 	34314.png (3 - Dress) vs 51238.png (3 - Dress), Similarity: 0.1153
# 	34314.png (3 - Dress) vs 38066.png (3 - Dress), Similarity: 0.1162
# 	34314.png (3 - Dress) vs 31345.png (3 - Dress), Similarity: 0.1200
# 	53825.png (3 - Dress) vs 34314.png (3 - Dress), Similarity: 0.1208
# 	24070.png (3 - Dress) vs 34314.png (3 - Dress), Similarity: 0.1217
# 	37904.png (3 - Dress) vs 34314.png (3 - Dress), Similarity: 0.1232
# 	34314.png (3 - Dress) vs 17805.png (3 - Dress), Similarity: 0.1236
# 	34314.png (3 - Dress) vs 16799.png (3 - Dress), Similarity: 0.1245
# 	34314.png (3 - Dress) vs 19138.png (3 - Dress), Similarity: 0.1252
# 	19794.png (3 - Dress) vs 34314.png (3 - Dress), Similarity: 0.1254
# 	34314.png (3 - Dress) vs 14660.png (3 - Dress), Similarity: 0.1256
# 	34314.png (3 - Dress) vs 17740.png (3 - Dress), Similarity: 0.1257
# 	52759.png (3 - Dress) vs 34314.png (3 - Dress), Similarity: 0.1264
# 	42587.png (3 - Dress) vs 39077.png (3 - Dress), Similarity: 0.1271
#
# Muestras más atípicas de esta clase:
# 	#1: 34314.png con 19 apariciones
# 	#2: 39077.png con 2 apariciones
# 	#3: 14842.png con 1 apariciones
# 	#4: 53509.png con 1 apariciones
# 	#5: 21452.png con 1 apariciones
# 	#6: 21859.png con 1 apariciones
# 	#7: 35649.png con 1 apariciones
# 	#8: 51238.png con 1 apariciones
# 	#9: 38066.png con 1 apariciones
# 	#10: 31345.png con 1 apariciones
#
#
# Clase: 4 - Coat
# Shape of the class matrix 4 - Coat: (6000, 6000)
# 	38223.png (4 - Coat) vs 14286.png (4 - Coat), Similarity: 0.0958
# 	51152.png (4 - Coat) vs 17267.png (4 - Coat), Similarity: 0.0962
# 	17267.png (4 - Coat) vs 22161.png (4 - Coat), Similarity: 0.1030
# 	15345.png (4 - Coat) vs 17267.png (4 - Coat), Similarity: 0.1033
# 	37113.png (4 - Coat) vs 17267.png (4 - Coat), Similarity: 0.1063
# 	17267.png (4 - Coat) vs 19370.png (4 - Coat), Similarity: 0.1073
# 	47230.png (4 - Coat) vs 17267.png (4 - Coat), Similarity: 0.1125
# 	14286.png (4 - Coat) vs 36473.png (4 - Coat), Similarity: 0.1126
# 	28855.png (4 - Coat) vs 14286.png (4 - Coat), Similarity: 0.1131
# 	17267.png (4 - Coat) vs 53411.png (4 - Coat), Similarity: 0.1132
# 	21724.png (4 - Coat) vs 17267.png (4 - Coat), Similarity: 0.1142
# 	17267.png (4 - Coat) vs 47746.png (4 - Coat), Similarity: 0.1144
# 	12210.png (4 - Coat) vs 14286.png (4 - Coat), Similarity: 0.1153
# 	38223.png (4 - Coat) vs 46237.png (4 - Coat), Similarity: 0.1159
# 	17267.png (4 - Coat) vs 16691.png (4 - Coat), Similarity: 0.1162
# 	16017.png (4 - Coat) vs 17267.png (4 - Coat), Similarity: 0.1163
# 	55930.png (4 - Coat) vs 17267.png (4 - Coat), Similarity: 0.1167
# 	17267.png (4 - Coat) vs 59033.png (4 - Coat), Similarity: 0.1170
# 	12336.png (4 - Coat) vs 24172.png (4 - Coat), Similarity: 0.1172
# 	53398.png (4 - Coat) vs 14286.png (4 - Coat), Similarity: 0.1175
#
# Muestras más atípicas de esta clase:
# 	#1: 17267.png con 13 apariciones
# 	#2: 14286.png con 5 apariciones
# 	#3: 38223.png con 2 apariciones
# 	#4: 51152.png con 1 apariciones
# 	#5: 22161.png con 1 apariciones
# 	#6: 15345.png con 1 apariciones
# 	#7: 37113.png con 1 apariciones
# 	#8: 19370.png con 1 apariciones
# 	#9: 47230.png con 1 apariciones
# 	#10: 36473.png con 1 apariciones
#
#
# Clase: 5 - Sandal
# Shape of the class matrix 5 - Sandal: (6000, 6000)
# 	14410.png (5 - Sandal) vs 28733.png (5 - Sandal), Similarity: 0.0083
# 	6844.png (5 - Sandal) vs 14410.png (5 - Sandal), Similarity: 0.0106
# 	21487.png (5 - Sandal) vs 14410.png (5 - Sandal), Similarity: 0.0106
# 	35508.png (5 - Sandal) vs 10250.png (5 - Sandal), Similarity: 0.0113
# 	35508.png (5 - Sandal) vs 28733.png (5 - Sandal), Similarity: 0.0113
# 	14410.png (5 - Sandal) vs 40647.png (5 - Sandal), Similarity: 0.0116
# 	14410.png (5 - Sandal) vs 40743.png (5 - Sandal), Similarity: 0.0117
# 	58301.png (5 - Sandal) vs 28733.png (5 - Sandal), Similarity: 0.0118
# 	41586.png (5 - Sandal) vs 28733.png (5 - Sandal), Similarity: 0.0118
# 	39009.png (5 - Sandal) vs 28733.png (5 - Sandal), Similarity: 0.0119
# 	14410.png (5 - Sandal) vs 27801.png (5 - Sandal), Similarity: 0.0119
# 	44491.png (5 - Sandal) vs 14410.png (5 - Sandal), Similarity: 0.0121
# 	32724.png (5 - Sandal) vs 28733.png (5 - Sandal), Similarity: 0.0121
# 	14410.png (5 - Sandal) vs 1434.png (5 - Sandal), Similarity: 0.0123
# 	39009.png (5 - Sandal) vs 59685.png (5 - Sandal), Similarity: 0.0124
# 	29494.png (5 - Sandal) vs 14410.png (5 - Sandal), Similarity: 0.0126
# 	14410.png (5 - Sandal) vs 30273.png (5 - Sandal), Similarity: 0.0126
# 	14410.png (5 - Sandal) vs 31065.png (5 - Sandal), Similarity: 0.0128
# 	28733.png (5 - Sandal) vs 28869.png (5 - Sandal), Similarity: 0.0130
# 	3300.png (5 - Sandal) vs 14410.png (5 - Sandal), Similarity: 0.0131
#
# Muestras más atípicas de esta clase:
# 	#1: 14410.png con 12 apariciones
# 	#2: 28733.png con 7 apariciones
# 	#3: 35508.png con 2 apariciones
# 	#4: 39009.png con 2 apariciones
# 	#5: 6844.png con 1 apariciones
# 	#6: 21487.png con 1 apariciones
# 	#7: 10250.png con 1 apariciones
# 	#8: 40647.png con 1 apariciones
# 	#9: 40743.png con 1 apariciones
# 	#10: 58301.png con 1 apariciones
#
#
# Clase: 6 - Shirt
# Shape of the class matrix 6 - Shirt: (6000, 6000)
# 	58130.png (6 - Shirt) vs 24014.png (6 - Shirt), Similarity: 0.0545
# 	58130.png (6 - Shirt) vs 40308.png (6 - Shirt), Similarity: 0.0770
# 	58130.png (6 - Shirt) vs 34381.png (6 - Shirt), Similarity: 0.0789
# 	20112.png (6 - Shirt) vs 58130.png (6 - Shirt), Similarity: 0.0791
# 	22178.png (6 - Shirt) vs 58130.png (6 - Shirt), Similarity: 0.0793
# 	11651.png (6 - Shirt) vs 58130.png (6 - Shirt), Similarity: 0.0794
# 	58130.png (6 - Shirt) vs 16246.png (6 - Shirt), Similarity: 0.0798
# 	58130.png (6 - Shirt) vs 49995.png (6 - Shirt), Similarity: 0.0802
# 	28159.png (6 - Shirt) vs 24014.png (6 - Shirt), Similarity: 0.0803
# 	58130.png (6 - Shirt) vs 38945.png (6 - Shirt), Similarity: 0.0807
# 	58130.png (6 - Shirt) vs 52994.png (6 - Shirt), Similarity: 0.0809
# 	58130.png (6 - Shirt) vs 46507.png (6 - Shirt), Similarity: 0.0819
# 	58130.png (6 - Shirt) vs 52591.png (6 - Shirt), Similarity: 0.0827
# 	43415.png (6 - Shirt) vs 58130.png (6 - Shirt), Similarity: 0.0836
# 	16738.png (6 - Shirt) vs 58130.png (6 - Shirt), Similarity: 0.0841
# 	4814.png (6 - Shirt) vs 58130.png (6 - Shirt), Similarity: 0.0847
# 	52669.png (6 - Shirt) vs 58130.png (6 - Shirt), Similarity: 0.0848
# 	58130.png (6 - Shirt) vs 226.png (6 - Shirt), Similarity: 0.0850
# 	58130.png (6 - Shirt) vs 33503.png (6 - Shirt), Similarity: 0.0852
# 	58130.png (6 - Shirt) vs 25593.png (6 - Shirt), Similarity: 0.0858
#
# Muestras más atípicas de esta clase:
# 	#1: 58130.png con 19 apariciones
# 	#2: 24014.png con 2 apariciones
# 	#3: 40308.png con 1 apariciones
# 	#4: 34381.png con 1 apariciones
# 	#5: 20112.png con 1 apariciones
# 	#6: 22178.png con 1 apariciones
# 	#7: 11651.png con 1 apariciones
# 	#8: 16246.png con 1 apariciones
# 	#9: 49995.png con 1 apariciones
# 	#10: 28159.png con 1 apariciones
#
#
# Clase: 7 - Sneaker
# Shape of the class matrix 7 - Sneaker: (6000, 6000)
# 	42559.png (7 - Sneaker) vs 43277.png (7 - Sneaker), Similarity: 0.0048
# 	58157.png (7 - Sneaker) vs 43277.png (7 - Sneaker), Similarity: 0.0051
# 	43277.png (7 - Sneaker) vs 7990.png (7 - Sneaker), Similarity: 0.0053
# 	43277.png (7 - Sneaker) vs 10051.png (7 - Sneaker), Similarity: 0.0058
# 	43277.png (7 - Sneaker) vs 37719.png (7 - Sneaker), Similarity: 0.0059
# 	43277.png (7 - Sneaker) vs 17358.png (7 - Sneaker), Similarity: 0.0060
# 	55561.png (7 - Sneaker) vs 43277.png (7 - Sneaker), Similarity: 0.0064
# 	43277.png (7 - Sneaker) vs 12773.png (7 - Sneaker), Similarity: 0.0065
# 	43277.png (7 - Sneaker) vs 14977.png (7 - Sneaker), Similarity: 0.0068
# 	43277.png (7 - Sneaker) vs 770.png (7 - Sneaker), Similarity: 0.0069
# 	25831.png (7 - Sneaker) vs 43277.png (7 - Sneaker), Similarity: 0.0071
# 	59170.png (7 - Sneaker) vs 43277.png (7 - Sneaker), Similarity: 0.0073
# 	43277.png (7 - Sneaker) vs 16110.png (7 - Sneaker), Similarity: 0.0073
# 	46975.png (7 - Sneaker) vs 43277.png (7 - Sneaker), Similarity: 0.0075
# 	43277.png (7 - Sneaker) vs 41503.png (7 - Sneaker), Similarity: 0.0075
# 	43277.png (7 - Sneaker) vs 14175.png (7 - Sneaker), Similarity: 0.0075
# 	43277.png (7 - Sneaker) vs 50776.png (7 - Sneaker), Similarity: 0.0076
# 	35171.png (7 - Sneaker) vs 43277.png (7 - Sneaker), Similarity: 0.0078
# 	43277.png (7 - Sneaker) vs 31368.png (7 - Sneaker), Similarity: 0.0079
# 	43277.png (7 - Sneaker) vs 44591.png (7 - Sneaker), Similarity: 0.0080
#
# Muestras más atípicas de esta clase:
# 	#1: 43277.png con 20 apariciones
# 	#2: 42559.png con 1 apariciones
# 	#3: 58157.png con 1 apariciones
# 	#4: 7990.png con 1 apariciones
# 	#5: 10051.png con 1 apariciones
# 	#6: 37719.png con 1 apariciones
# 	#7: 17358.png con 1 apariciones
# 	#8: 55561.png con 1 apariciones
# 	#9: 12773.png con 1 apariciones
# 	#10: 14977.png con 1 apariciones
#
#
# Clase: 8 - Bag
# Shape of the class matrix 8 - Bag: (6000, 6000)
# 	4195.png (8 - Bag) vs 29088.png (8 - Bag), Similarity: 0.0057
# 	4752.png (8 - Bag) vs 58841.png (8 - Bag), Similarity: 0.0093
# 	4752.png (8 - Bag) vs 44423.png (8 - Bag), Similarity: 0.0108
# 	4195.png (8 - Bag) vs 38806.png (8 - Bag), Similarity: 0.0116
# 	51236.png (8 - Bag) vs 4752.png (8 - Bag), Similarity: 0.0118
# 	35336.png (8 - Bag) vs 4752.png (8 - Bag), Similarity: 0.0119
# 	11992.png (8 - Bag) vs 58708.png (8 - Bag), Similarity: 0.0122
# 	4752.png (8 - Bag) vs 8891.png (8 - Bag), Similarity: 0.0123
# 	29012.png (8 - Bag) vs 4752.png (8 - Bag), Similarity: 0.0124
# 	4752.png (8 - Bag) vs 39814.png (8 - Bag), Similarity: 0.0124
# 	11992.png (8 - Bag) vs 4752.png (8 - Bag), Similarity: 0.0125
# 	58708.png (8 - Bag) vs 8891.png (8 - Bag), Similarity: 0.0127
# 	4752.png (8 - Bag) vs 30029.png (8 - Bag), Similarity: 0.0128
# 	4752.png (8 - Bag) vs 29088.png (8 - Bag), Similarity: 0.0137
# 	4752.png (8 - Bag) vs 24430.png (8 - Bag), Similarity: 0.0137
# 	4752.png (8 - Bag) vs 15226.png (8 - Bag), Similarity: 0.0141
# 	8891.png (8 - Bag) vs 52836.png (8 - Bag), Similarity: 0.0141
# 	43149.png (8 - Bag) vs 4752.png (8 - Bag), Similarity: 0.0144
# 	4752.png (8 - Bag) vs 58858.png (8 - Bag), Similarity: 0.0147
# 	26805.png (8 - Bag) vs 4752.png (8 - Bag), Similarity: 0.0148
#
# Muestras más atípicas de esta clase:
# 	#1: 4752.png con 15 apariciones
# 	#2: 8891.png con 3 apariciones
# 	#3: 4195.png con 2 apariciones
# 	#4: 29088.png con 2 apariciones
# 	#5: 11992.png con 2 apariciones
# 	#6: 58708.png con 2 apariciones
# 	#7: 58841.png con 1 apariciones
# 	#8: 44423.png con 1 apariciones
# 	#9: 38806.png con 1 apariciones
# 	#10: 51236.png con 1 apariciones
#
#
# Clase: 9 - Ankle boot
# Shape of the class matrix 9 - Ankle boot: (6000, 6000)
# 	34122.png (9 - Ankle boot) vs 26054.png (9 - Ankle boot), Similarity: 0.0966
# 	37122.png (9 - Ankle boot) vs 34122.png (9 - Ankle boot), Similarity: 0.0983
# 	360.png (9 - Ankle boot) vs 34122.png (9 - Ankle boot), Similarity: 0.1001
# 	34122.png (9 - Ankle boot) vs 20221.png (9 - Ankle boot), Similarity: 0.1012
# 	6818.png (9 - Ankle boot) vs 34122.png (9 - Ankle boot), Similarity: 0.1037
# 	26781.png (9 - Ankle boot) vs 34122.png (9 - Ankle boot), Similarity: 0.1042
# 	27991.png (9 - Ankle boot) vs 34122.png (9 - Ankle boot), Similarity: 0.1050
# 	317.png (9 - Ankle boot) vs 34122.png (9 - Ankle boot), Similarity: 0.1074
# 	34122.png (9 - Ankle boot) vs 44171.png (9 - Ankle boot), Similarity: 0.1081
# 	26252.png (9 - Ankle boot) vs 34122.png (9 - Ankle boot), Similarity: 0.1082
# 	11737.png (9 - Ankle boot) vs 34122.png (9 - Ankle boot), Similarity: 0.1098
# 	34122.png (9 - Ankle boot) vs 30185.png (9 - Ankle boot), Similarity: 0.1102
# 	34122.png (9 - Ankle boot) vs 59763.png (9 - Ankle boot), Similarity: 0.1113
# 	34122.png (9 - Ankle boot) vs 25919.png (9 - Ankle boot), Similarity: 0.1118
# 	34122.png (9 - Ankle boot) vs 31270.png (9 - Ankle boot), Similarity: 0.1119
# 	34122.png (9 - Ankle boot) vs 17991.png (9 - Ankle boot), Similarity: 0.1127
# 	11193.png (9 - Ankle boot) vs 34122.png (9 - Ankle boot), Similarity: 0.1128
# 	34122.png (9 - Ankle boot) vs 20285.png (9 - Ankle boot), Similarity: 0.1137
# 	2740.png (9 - Ankle boot) vs 34122.png (9 - Ankle boot), Similarity: 0.1143
# 	34122.png (9 - Ankle boot) vs 26759.png (9 - Ankle boot), Similarity: 0.1146
#
# Muestras más atípicas de esta clase:
# 	#1: 34122.png con 20 apariciones
# 	#2: 26054.png con 1 apariciones
# 	#3: 37122.png con 1 apariciones
# 	#4: 360.png con 1 apariciones
# 	#5: 20221.png con 1 apariciones
# 	#6: 6818.png con 1 apariciones
# 	#7: 26781.png con 1 apariciones
# 	#8: 27991.png con 1 apariciones
# 	#9: 317.png con 1 apariciones
# 	#10: 44171.png con 1 apariciones
