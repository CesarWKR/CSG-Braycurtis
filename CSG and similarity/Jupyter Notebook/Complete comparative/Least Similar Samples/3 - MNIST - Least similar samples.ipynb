# %% [markdown]
# # Librerias

# %%
# Carga de librerías
import numpy as np
import tensorflow as tf
import PIL
import PIL.Image
import pathlib
import scipy as sp
import seaborn as sns
from itertools import product
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
import os
import pathlib
from pathlib import Path

# %%
import pickle
import sys
from pathlib import Path

from numpy.linalg import LinAlgError
from scipy.sparse.csgraph import laplacian
from new_spectral_metric.new_estimator_complete import CumulativeGradientEstimator_Complete
from new_spectral_metric.new_visualize import make_graph
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Conv2D, Dense, MaxPooling2D, Lambda
from tensorflow.keras import backend as K
from pathlib import Path
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from matplotlib.collections import LineCollection
from matplotlib.font_manager import FontProperties
from pathlib import Path

# %% [markdown]
# # DATASET DESDE DIRECTORIO

# %%
#Lectura de dataset

directorio_dataset = ('../../../../Datasets/MNIST')
directorio_dataset = pathlib.Path(directorio_dataset)

# Lectura de la carpeta train
directorio_train = ('../../../../Datasets/MNIST/train')
directorio_train = pathlib.Path(directorio_train)

# Lectura de la carpeta test
directorio_test = ('../../../../Datasets/MNIST/test')
directorio_test = pathlib.Path(directorio_test)

total_dataset = len(list(directorio_dataset.glob('*/*/*.png')))  # Cuenta la cantidad de imagenes del dataset (Aqui busca en las subcarpetas del directorio del dataset)
total_train = len(list(directorio_train.glob('*/*.png')))  # Cuenta la cantidad de imagenes de train
total_test = len(list(directorio_test.glob('*/*.png')))  # Cuenta la cantidad de imagenes de test

print(f"Total imagenes dataset: {total_dataset}")
print(f"Total imagenes train: {total_train}")
print(f"Total imagenes test: {total_test}")
# Out:
# Total imagenes dataset: 70000
# Total imagenes train: 60000
# Total imagenes test: 10000

# %%
# Definir el batchsize del dataset completo
batch_size_total = total_dataset

# %%
# Dimensiones de imagen y tamaño de batch en train
img_height = 28
img_width = 28
#batch_size = 32
batch_size_train = total_train

# %%
import tensorflow as tf
import pathlib

# Data splitting (entrenamiento y validación)
train_images = tf.keras.preprocessing.image_dataset_from_directory(
  directorio_train,
  #validation_split=0.2,
  color_mode='rgb',
  label_mode='int',
  #subset="training",
  #seed=123,
  shuffle=False,
  image_size=(img_height, img_width),
  batch_size=batch_size_train)
# Out:
# Found 60000 files belonging to 10 classes.

# %%
# Dimensiones de imagen y tamaño de batch en test
img_height = 28
img_width = 28
#batch_size = 32
batch_size_test = total_test

# %%
# Data splitting (entrenamiento y validación)
test_images = tf.keras.preprocessing.image_dataset_from_directory(
  directorio_test,
  #validation_split=0.2,
  color_mode='rgb',
  label_mode='int',
  #subset="training",
  #seed=123,
  shuffle=False,
  image_size=(img_height, img_width),
  batch_size=batch_size_test)
# Out:
# Found 10000 files belonging to 10 classes.

# %%
# Contar el total de imágenes por clase en train y test  
class_counts_total = {p.name: len(list(p.glob('*.png'))) for p in directorio_dataset.glob('*/*')}  
class_counts_train = {p.name: len(list(p.glob('*.png'))) for p in directorio_train.glob('*')}  
class_counts_test = {p.name: len(list(p.glob('*.png'))) for p in directorio_test.glob('*')}  

# Encontrar el valor más bajo de imágenes por clase en train  
menor_train = min(class_counts_train.values()) if class_counts_train else None  # Se almacena el valor de la clase que menos muestras tiene

# Encontrar el valor más alto de imágenes por clase en train  
mayor_train = max(class_counts_train.values()) if class_counts_train else None  # Se almacena el valor de la clase que mas muestras tiene


# Encontrar el valor más bajo de imágenes por clase en test  
menor_test = min(class_counts_test.values()) if class_counts_test else None  # Se almacena el valor de la clase que menos muestras tiene

# Encontrar el valor más alto de imágenes por clase en test  
mayor_test = max(class_counts_test.values()) if class_counts_test else None  # Se almacena el valor de la clase que mas muestras tiene


# Mostrar el total de imágenes por clase en train  
print("\nTotal images per class in train:")  
for class_name, count in class_counts_train.items():  
    print(f"Class: {class_name}, Number of images: {count}")  
print(f"Total images train: {sum(class_counts_train.values())}")  

# Mostrar el valor más bajo en train  
print(f"Fewer number of images in train: {menor_train}")  

# Mostrar el valor más alto en train  
print(f"Higher number of images in train: {mayor_train}")  

# Mostrar el total de imágenes por clase en test  
print("\nTotal images per class in test:")  
for class_name, count in class_counts_test.items():  
    print(f"Class: {class_name}, Number of images: {count}")  
print(f"Total images test: {sum(class_counts_test.values())}")  

# Mostrar el valor más bajo en test  
print(f"Fewer images in test: {menor_test}")

# Mostrar el valor más alto en test  
print(f"Higher number of images in test: {mayor_test}")
# Out:
# Total images per class in train:
# Class: 0_train, Number of images: 5923
# Class: 1_train, Number of images: 6742
# Class: 2_train, Number of images: 5958
# Class: 3_train, Number of images: 6131
# Class: 4_train, Number of images: 5842
# Class: 5_train, Number of images: 5421
# Class: 6_train, Number of images: 5918
# Class: 7_train, Number of images: 6265
# Class: 8_train, Number of images: 5851
# Class: 9_train, Number of images: 5949
# Total images train: 60000
# Fewer number of images in train: 5421
# Higher number of images in train: 6742
#
# Total images per class in test:
# Class: 0_test, Number of images: 980
# Class: 1_test, Number of images: 1135
# Class: 2_test, Number of images: 1032
# Class: 3_test, Number of images: 1010
# Class: 4_test, Number of images: 982
# Class: 5_test, Number of images: 892
# Class: 6_test, Number of images: 958
# Class: 7_test, Number of images: 1028
# Class: 8_test, Number of images: 974
# Class: 9_test, Number of images: 1009
# Total images test: 10000
# Fewer images in test: 892
# Higher number of images in test: 1135

# %%
# Nombres de las clases
class_names_train = list(class_counts_train.keys())
class_names_test = list(class_counts_test.keys())
#class_names_total = sorted(list(set(class_names_train + class_names_test)))
class_names_total = list(class_counts_total.keys())

# Mostrar el número de clases y los nombres
print(f"\nNúmero de clases en train: {len(class_names_train)}")
print(f"Nombres de las clases en train: {class_names_train}")

print(f"\nNúmero de clases en test: {len(class_names_test)}")
print(f"Nombres de las clases en test: {class_names_test}")

print(f"\nNúmero total de clases en el dataset: {len(class_names_total)}")   # Este valor cambia si el nombre de las clases es diferente
print(f"Nombres de todas las clases en el dataset: {class_names_total}")     # Este valor tambien cambia si el nombre de las clases es diferente
# Out:
# Número de clases en train: 10
# Nombres de las clases en train: ['0_train', '1_train', '2_train', '3_train', '4_train', '5_train', '6_train', '7_train', '8_train', '9_train']
#
# Número de clases en test: 10
# Nombres de las clases en test: ['0_test', '1_test', '2_test', '3_test', '4_test', '5_test', '6_test', '7_test', '8_test', '9_test']
#
# Número total de clases en el dataset: 20
# Nombres de todas las clases en el dataset: ['0_test', '1_test', '2_test', '3_test', '4_test', '5_test', '6_test', '7_test', '8_test', '9_test', '0_train', '1_train', '2_train', '3_train', '4_train', '5_train', '6_train', '7_train', '8_train', '9_train']

# %%
for images, labels0 in train_images.take(1):  # only take first element of dataset
    numpy_all_images = images.numpy()  # convertir el tensor de imágenes en un arreglo de numpy y ahora contiene las imágenes del conjunto de datos en formato de numpy.
    numpy_all_labels = labels0.numpy()  # convierte el tensor de etiquetas en un arreglo de numpy y ahora contiene las etiquetas del conjunto de datos en formato de numpy

numpy_all_images /= 255.0  # Scale the features to the [0, 1] range
print(numpy_all_images.shape)

# CIFAR-10 
fully_dataset_train = numpy_all_images.reshape((numpy_all_images.shape[0], numpy_all_images.shape[1]*numpy_all_images.shape[2]*numpy_all_images.shape[3])) # es un arreglo bidimensional donde cada fila representa una imagen y cada columna representa un píxel de la imagen
fully_labels_train = numpy_all_labels.reshape(numpy_all_labels.shape[0],)
# Out:
# (60000, 28, 28, 3)

# %% [markdown]
# # Dataset complexity using CSG

# %%
estimator = CumulativeGradientEstimator_Complete(M_sample=mayor_train, k_nearest=10)  # Utiliza el numero menor de muestras encontrado en cada clase dependiendo si es train o test
estimator.fit(data=fully_dataset_train, target=fully_labels_train)
csg = estimator.csg  # The actual complexity values.
estimator.evals, estimator.evecs  # The eigenvalues and vectors.

make_graph(estimator.difference, title="Dataset Complexity - MNIST: "+str(csg), classes=class_names_train)
# Out:
# c:\Users\Cesar\AppData\Local\Programs\Python\Python312\Lib\site-packages\new_spectral_metric\new_visualize.py:48: RuntimeWarning: divide by zero encountered in divide
#   similarities = difference.max() / difference * 100
# c:\Users\Cesar\AppData\Local\Programs\Python\Python312\Lib\site-packages\new_spectral_metric\new_visualize.py:59: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# # Calcular la similitud entre clases

# %%
from scipy.stats import entropy
import pandas as pd

# Calcular la entropía por clase  
entropy_per_class = entropy(estimator.W / estimator.W.sum(-1)[:, None], axis=-1)  

# Encontrar la clase menos confusa (menor entropía)  
least_confused_class_index = np.argmin(entropy_per_class)  
least_confused_class_name = class_names_train[least_confused_class_index]  

print("Class that is the least confused (lowest entropy):", least_confused_class_name)
# Out:
# Class that is the least confused (lowest entropy): 0_train

# %%
# Obtener los índices de los pares menos similares  
pairs = list(zip(*np.unravel_index(np.argsort(estimator.W, axis=None), estimator.W.shape)))  

# Filtrar pares donde i != j para evitar pares de la misma clase  
pairs = [(i, j) for i, j in pairs if i != j]  

print("Least similar pairs")  
lst = []  
seen_pairs = set()  

# Iterar sobre los primeros 10 pares menos similares  
for i, j in pairs:  
    # Verificar si el par o su inverso ya ha sido visto  
    if (i, j) not in seen_pairs and (j, i) not in seen_pairs:  
        lst.append({"Intent pair": f"{class_names_train[i]} <> {class_names_train[j]}", "Similarity": estimator.W[i, j]})  
        seen_pairs.add((i, j))  
        seen_pairs.add((j, i))  
    
    # Detenerse después de encontrar 10 pares únicos  
    if len(lst) == 10:  
        break  

# Mostrar los resultados en un DataFrame  
print(pd.DataFrame(lst))
# Out:
# Least similar pairs
#           Intent pair  Similarity
# 0  1_train <> 6_train    0.005626
# 1  0_train <> 1_train    0.005650
# 2  7_train <> 0_train    0.006209
# 3  6_train <> 7_train    0.006585
# 4  5_train <> 1_train    0.009657
# 5  3_train <> 0_train    0.009746
# 6  0_train <> 4_train    0.009942
# 7  1_train <> 9_train    0.010410
# 8  6_train <> 4_train    0.010979
# 9  9_train <> 0_train    0.011052

# %% [markdown]
# # Obtener los nombres de las imagenes en train o test (dependiendo de lo que se quiera probar)

# %%
# Obtener todos los nombres de archivo en el dataset
filenames = [str(f) for f in directorio_train.glob('*/*.png')]

# Crear un mapeo de índices a rutas completas de archivo  
filenames_dict = {i: str(f) for i, f in enumerate(directorio_train.glob('*/*.png'))}

# %% [markdown]
# # Calcular la similitud entre muestras

# %%
# Función para encontrar y mostrar las imágenes menos similares dentro de cada clase usando la matriz C  
def show_least_similar_using_C_all_classes(estimator, class_names, filenames_dict):  
    images_to_show = []  # Lista para almacenar las imágenes y sus detalles  

    # Primero, recorre las clases y genera la lista de descripciones  
    for class_intent in range(len(class_names)):  
        class_name = class_names[class_intent]  
        print(f"Clase: {class_name}")  
        
        # Obtener la matriz de similitud de las muestras dentro de la clase  
        C = estimator.C[class_intent]  

        # Imprimir la forma de la matriz de similitud de la clase  
        print(f"Shape of the class matrix {class_name}: {C.shape}")
        
        # Ordenar los índices según las similitudes (de menor a mayor)  
        least_similar_indices = np.argsort(C, axis=None)  
        
        shown_pairs = set()  # Para rastrear los pares de índices ya mostrados  
        count = 0  
        show_samples = 20  # Número de muestras para visualizar la similitud  
        
        # Diccionario para contar la participación de cada imagen  
        participation_count = {}

        for idx in least_similar_indices:  
            if count >= show_samples:  
                break  
            
            # Convertir el índice plano a índice 2D  
            idx_2d = np.unravel_index(idx, C.shape)  
            
            # Saltar las comparaciones de una muestra consigo misma  
            if idx_2d[0] == idx_2d[1]:  
                continue  
            
            # Crear un par ordenado de índices para prevenir duplicados  
            index_pair = tuple(sorted((idx_2d[0], idx_2d[1])))  
            
            # Verificamos si el par ya fue mostrado  
            if index_pair in shown_pairs:  
                continue  
            
            shown_pairs.add(index_pair)  
            
            # Actualizar el conteo de participación  
            participation_count[idx_2d[0]] = participation_count.get(idx_2d[0], 0) + 1  
            participation_count[idx_2d[1]] = participation_count.get(idx_2d[1], 0) + 1

            # Obtener los índices de las muestras en el dataset  
            source_idx = estimator.class_indices[class_intent][idx_2d[0]]  
            target_idx = estimator.class_indices[class_intent][idx_2d[1]]  
            
            # Verificar que los índices estén dentro de los límites del dataset  
            if source_idx < len(filenames_dict) and target_idx < len(filenames_dict):  
                source_filename = Path(filenames_dict[int(source_idx)])  
                target_filename = Path(filenames_dict[int(target_idx)])  
                
                value = C[idx_2d]  
                
                # Formatear y mostrar la salida  
                print(f"\t{source_filename.name} ({class_name}) vs {target_filename.name} ({class_name}), Simililarity: {value:.4f}")  
                
                # Agrega los detalles a la lista para visualización  
                images_to_show.append((source_filename, target_filename, class_name, value))  
                
                count += 1  
    

        # Encontrar las muestras más atípicas  
        most_atypical = sorted(participation_count.items(), key=lambda x: -x[1])  
        
        # Mostrar las 10 más atípicas  
        print("\nMuestras más atípicas de esta clase:")  
        for rank, (img_idx, freq) in enumerate(most_atypical[:10], 1):  
            img_name = Path(filenames_dict[int(estimator.class_indices[class_intent][img_idx])]).name  
            print(f"\t#{rank}: {img_name} con {freq} apariciones")  
        print("\n")


    # Luego, realiza la visualización de las imágenes  
    for source_filename, target_filename, class_name, value in images_to_show:  
        img_source = plt.imread(source_filename)  
        img_target = plt.imread(target_filename)  
        
        fig, axs = plt.subplots(1, 2, figsize=(5, 3))  
        axs[0].imshow(img_source)  
        axs[0].set_title(f"{class_name}: \n{source_filename.name}", fontsize=8) 
        axs[0].axis('off')  # Elimina los ejes para centrar la atención en la imagen  
        
        axs[1].imshow(img_target)  
        axs[1].set_title(f"{class_name}: \n{target_filename.name}", fontsize=8)  
        axs[1].axis('off') 
        plt.suptitle(f"Similarity: {value:.4f}")  
        plt.subplots_adjust(wspace=0.3, hspace=0.3)  # Ajusta el espacio entre subtramas  
        plt.show()  


print("Muestras menos similares entre las imágenes de la misma clase \n")  
show_least_similar_using_C_all_classes(estimator, class_names_train, filenames_dict)
# Out:
# Muestras menos similares entre las imágenes de la misma clase
#
# Clase: 0_train
# Shape of the class matrix 0_train: (5923, 5923)
# 	24444.png (0_train) vs 42703.png (0_train), Simililarity: 0.0000
# 	38106.png (0_train) vs 42703.png (0_train), Simililarity: 0.0004
# 	42703.png (0_train) vs 28016.png (0_train), Simililarity: 0.0009
# 	37678.png (0_train) vs 42703.png (0_train), Simililarity: 0.0012
# 	8449.png (0_train) vs 38106.png (0_train), Simililarity: 0.0014
# 	42703.png (0_train) vs 50344.png (0_train), Simililarity: 0.0015
# 	19744.png (0_train) vs 42703.png (0_train), Simililarity: 0.0015
# 	32575.png (0_train) vs 42703.png (0_train), Simililarity: 0.0019
# 	12748.png (0_train) vs 42703.png (0_train), Simililarity: 0.0025
# 	42703.png (0_train) vs 13830.png (0_train), Simililarity: 0.0026
# 	42703.png (0_train) vs 41030.png (0_train), Simililarity: 0.0028
# 	24988.png (0_train) vs 42703.png (0_train), Simililarity: 0.0029
# 	24444.png (0_train) vs 8449.png (0_train), Simililarity: 0.0031
# 	7409.png (0_train) vs 42703.png (0_train), Simililarity: 0.0032
# 	42703.png (0_train) vs 51490.png (0_train), Simililarity: 0.0035
# 	42703.png (0_train) vs 51415.png (0_train), Simililarity: 0.0035
# 	1102.png (0_train) vs 37921.png (0_train), Simililarity: 0.0036
# 	42703.png (0_train) vs 17122.png (0_train), Simililarity: 0.0038
# 	51866.png (0_train) vs 42703.png (0_train), Simililarity: 0.0039
# 	10372.png (0_train) vs 42703.png (0_train), Simililarity: 0.0039
#
# Muestras más atípicas de esta clase:
# 	#1: 42703.png con 17 apariciones
# 	#2: 24444.png con 2 apariciones
# 	#3: 38106.png con 2 apariciones
# 	#4: 8449.png con 2 apariciones
# 	#5: 28016.png con 1 apariciones
# 	#6: 37678.png con 1 apariciones
# 	#7: 50344.png con 1 apariciones
# 	#8: 19744.png con 1 apariciones
# 	#9: 32575.png con 1 apariciones
# 	#10: 12748.png con 1 apariciones
#
#
# Clase: 1_train
# Shape of the class matrix 1_train: (6742, 6742)
# 	27793.png (1_train) vs 31727.png (1_train), Simililarity: 0.0000
# 	29609.png (1_train) vs 31727.png (1_train), Simililarity: 0.0000
# 	38415.png (1_train) vs 31727.png (1_train), Simililarity: 0.0000
# 	31727.png (1_train) vs 41956.png (1_train), Simililarity: 0.0004
# 	19176.png (1_train) vs 31727.png (1_train), Simililarity: 0.0005
# 	31727.png (1_train) vs 12230.png (1_train), Simililarity: 0.0010
# 	31727.png (1_train) vs 56071.png (1_train), Simililarity: 0.0010
# 	47796.png (1_train) vs 31727.png (1_train), Simililarity: 0.0015
# 	58147.png (1_train) vs 31727.png (1_train), Simililarity: 0.0016
# 	3592.png (1_train) vs 31727.png (1_train), Simililarity: 0.0016
# 	31727.png (1_train) vs 38164.png (1_train), Simililarity: 0.0020
# 	13449.png (1_train) vs 31727.png (1_train), Simililarity: 0.0020
# 	31727.png (1_train) vs 48573.png (1_train), Simililarity: 0.0026
# 	21601.png (1_train) vs 14016.png (1_train), Simililarity: 0.0027
# 	31727.png (1_train) vs 43897.png (1_train), Simililarity: 0.0029
# 	31727.png (1_train) vs 35995.png (1_train), Simililarity: 0.0029
# 	31727.png (1_train) vs 32204.png (1_train), Simililarity: 0.0040
# 	31727.png (1_train) vs 25767.png (1_train), Simililarity: 0.0046
# 	31727.png (1_train) vs 26587.png (1_train), Simililarity: 0.0052
# 	38487.png (1_train) vs 31727.png (1_train), Simililarity: 0.0052
#
# Muestras más atípicas de esta clase:
# 	#1: 31727.png con 19 apariciones
# 	#2: 27793.png con 1 apariciones
# 	#3: 29609.png con 1 apariciones
# 	#4: 38415.png con 1 apariciones
# 	#5: 41956.png con 1 apariciones
# 	#6: 19176.png con 1 apariciones
# 	#7: 12230.png con 1 apariciones
# 	#8: 56071.png con 1 apariciones
# 	#9: 47796.png con 1 apariciones
# 	#10: 58147.png con 1 apariciones
#
#
# Clase: 2_train
# Shape of the class matrix 2_train: (5958, 5958)
# 	32561.png (2_train) vs 24360.png (2_train), Simililarity: 0.0217
# 	29967.png (2_train) vs 27413.png (2_train), Simililarity: 0.0223
# 	35947.png (2_train) vs 52109.png (2_train), Simililarity: 0.0226
# 	27413.png (2_train) vs 20967.png (2_train), Simililarity: 0.0244
# 	27367.png (2_train) vs 27791.png (2_train), Simililarity: 0.0245
# 	18845.png (2_train) vs 27413.png (2_train), Simililarity: 0.0248
# 	45779.png (2_train) vs 29967.png (2_train), Simililarity: 0.0256
# 	11420.png (2_train) vs 59734.png (2_train), Simililarity: 0.0259
# 	35947.png (2_train) vs 558.png (2_train), Simililarity: 0.0263
# 	29967.png (2_train) vs 32751.png (2_train), Simililarity: 0.0266
# 	35947.png (2_train) vs 47966.png (2_train), Simililarity: 0.0268
# 	32751.png (2_train) vs 18845.png (2_train), Simililarity: 0.0281
# 	46001.png (2_train) vs 33930.png (2_train), Simililarity: 0.0285
# 	39899.png (2_train) vs 22112.png (2_train), Simililarity: 0.0288
# 	27791.png (2_train) vs 1900.png (2_train), Simililarity: 0.0291
# 	33505.png (2_train) vs 45501.png (2_train), Simililarity: 0.0297
# 	35947.png (2_train) vs 18514.png (2_train), Simililarity: 0.0302
# 	29967.png (2_train) vs 32561.png (2_train), Simililarity: 0.0305
# 	33930.png (2_train) vs 29967.png (2_train), Simililarity: 0.0305
# 	18845.png (2_train) vs 32561.png (2_train), Simililarity: 0.0308
#
# Muestras más atípicas de esta clase:
# 	#1: 29967.png con 5 apariciones
# 	#2: 35947.png con 4 apariciones
# 	#3: 32561.png con 3 apariciones
# 	#4: 27413.png con 3 apariciones
# 	#5: 18845.png con 3 apariciones
# 	#6: 27791.png con 2 apariciones
# 	#7: 32751.png con 2 apariciones
# 	#8: 33930.png con 2 apariciones
# 	#9: 24360.png con 1 apariciones
# 	#10: 52109.png con 1 apariciones
#
#
# Clase: 3_train
# Shape of the class matrix 3_train: (6131, 6131)
# 	53570.png (3_train) vs 18986.png (3_train), Simililarity: 0.0353
# 	41565.png (3_train) vs 2092.png (3_train), Simililarity: 0.0363
# 	13831.png (3_train) vs 13713.png (3_train), Simililarity: 0.0384
# 	57474.png (3_train) vs 41565.png (3_train), Simililarity: 0.0417
# 	23490.png (3_train) vs 52129.png (3_train), Simililarity: 0.0417
# 	17062.png (3_train) vs 34048.png (3_train), Simililarity: 0.0432
# 	32688.png (3_train) vs 52129.png (3_train), Simililarity: 0.0443
# 	52394.png (3_train) vs 52129.png (3_train), Simililarity: 0.0451
# 	14266.png (3_train) vs 41565.png (3_train), Simililarity: 0.0456
# 	41565.png (3_train) vs 23490.png (3_train), Simililarity: 0.0464
# 	52129.png (3_train) vs 47618.png (3_train), Simililarity: 0.0471
# 	11693.png (3_train) vs 57474.png (3_train), Simililarity: 0.0472
# 	22522.png (3_train) vs 11693.png (3_train), Simililarity: 0.0476
# 	14916.png (3_train) vs 11693.png (3_train), Simililarity: 0.0478
# 	11583.png (3_train) vs 17062.png (3_train), Simililarity: 0.0479
# 	31703.png (3_train) vs 11693.png (3_train), Simililarity: 0.0480
# 	11693.png (3_train) vs 21112.png (3_train), Simililarity: 0.0481
# 	52129.png (3_train) vs 51274.png (3_train), Simililarity: 0.0483
# 	34048.png (3_train) vs 52404.png (3_train), Simililarity: 0.0484
# 	39851.png (3_train) vs 14266.png (3_train), Simililarity: 0.0490
#
# Muestras más atípicas de esta clase:
# 	#1: 52129.png con 5 apariciones
# 	#2: 11693.png con 5 apariciones
# 	#3: 41565.png con 4 apariciones
# 	#4: 57474.png con 2 apariciones
# 	#5: 23490.png con 2 apariciones
# 	#6: 17062.png con 2 apariciones
# 	#7: 34048.png con 2 apariciones
# 	#8: 14266.png con 2 apariciones
# 	#9: 53570.png con 1 apariciones
# 	#10: 18986.png con 1 apariciones
#
#
# Clase: 4_train
# Shape of the class matrix 4_train: (5842, 5842)
# 	31114.png (4_train) vs 18308.png (4_train), Simililarity: 0.0276
# 	1004.png (4_train) vs 4952.png (4_train), Simililarity: 0.0279
# 	31114.png (4_train) vs 32830.png (4_train), Simililarity: 0.0282
# 	6810.png (4_train) vs 16068.png (4_train), Simililarity: 0.0285
# 	17576.png (4_train) vs 54452.png (4_train), Simililarity: 0.0295
# 	17576.png (4_train) vs 6810.png (4_train), Simililarity: 0.0302
# 	18551.png (4_train) vs 54452.png (4_train), Simililarity: 0.0306
# 	828.png (4_train) vs 5936.png (4_train), Simililarity: 0.0311
# 	828.png (4_train) vs 34750.png (4_train), Simililarity: 0.0319
# 	828.png (4_train) vs 52279.png (4_train), Simililarity: 0.0323
# 	6810.png (4_train) vs 17926.png (4_train), Simililarity: 0.0323
# 	24514.png (4_train) vs 31114.png (4_train), Simililarity: 0.0324
# 	24822.png (4_train) vs 828.png (4_train), Simililarity: 0.0325
# 	17406.png (4_train) vs 55490.png (4_train), Simililarity: 0.0328
# 	16912.png (4_train) vs 828.png (4_train), Simililarity: 0.0332
# 	33726.png (4_train) vs 31114.png (4_train), Simililarity: 0.0333
# 	28706.png (4_train) vs 828.png (4_train), Simililarity: 0.0334
# 	53363.png (4_train) vs 6810.png (4_train), Simililarity: 0.0334
# 	40288.png (4_train) vs 17576.png (4_train), Simililarity: 0.0335
# 	31114.png (4_train) vs 49398.png (4_train), Simililarity: 0.0335
#
# Muestras más atípicas de esta clase:
# 	#1: 828.png con 6 apariciones
# 	#2: 31114.png con 5 apariciones
# 	#3: 6810.png con 4 apariciones
# 	#4: 17576.png con 3 apariciones
# 	#5: 54452.png con 2 apariciones
# 	#6: 18308.png con 1 apariciones
# 	#7: 1004.png con 1 apariciones
# 	#8: 4952.png con 1 apariciones
# 	#9: 32830.png con 1 apariciones
# 	#10: 16068.png con 1 apariciones
#
#
# Clase: 5_train
# Shape of the class matrix 5_train: (5421, 5421)
# 	34365.png (5_train) vs 57942.png (5_train), Simililarity: 0.0025
# 	34365.png (5_train) vs 29870.png (5_train), Simililarity: 0.0056
# 	36774.png (5_train) vs 5414.png (5_train), Simililarity: 0.0067
# 	5414.png (5_train) vs 12572.png (5_train), Simililarity: 0.0069
# 	34365.png (5_train) vs 7740.png (5_train), Simililarity: 0.0075
# 	57461.png (5_train) vs 51990.png (5_train), Simililarity: 0.0092
# 	12572.png (5_train) vs 34365.png (5_train), Simililarity: 0.0101
# 	51990.png (5_train) vs 6431.png (5_train), Simililarity: 0.0102
# 	47940.png (5_train) vs 14389.png (5_train), Simililarity: 0.0106
# 	30448.png (5_train) vs 13699.png (5_train), Simililarity: 0.0110
# 	51990.png (5_train) vs 11115.png (5_train), Simililarity: 0.0116
# 	13699.png (5_train) vs 36774.png (5_train), Simililarity: 0.0116
# 	49460.png (5_train) vs 5414.png (5_train), Simililarity: 0.0120
# 	36774.png (5_train) vs 34365.png (5_train), Simililarity: 0.0121
# 	51990.png (5_train) vs 59993.png (5_train), Simililarity: 0.0122
# 	34365.png (5_train) vs 37448.png (5_train), Simililarity: 0.0126
# 	36774.png (5_train) vs 53715.png (5_train), Simililarity: 0.0126
# 	31242.png (5_train) vs 34365.png (5_train), Simililarity: 0.0127
# 	34365.png (5_train) vs 50322.png (5_train), Simililarity: 0.0127
# 	57461.png (5_train) vs 55322.png (5_train), Simililarity: 0.0131
#
# Muestras más atípicas de esta clase:
# 	#1: 34365.png con 8 apariciones
# 	#2: 36774.png con 4 apariciones
# 	#3: 51990.png con 4 apariciones
# 	#4: 5414.png con 3 apariciones
# 	#5: 12572.png con 2 apariciones
# 	#6: 57461.png con 2 apariciones
# 	#7: 13699.png con 2 apariciones
# 	#8: 57942.png con 1 apariciones
# 	#9: 29870.png con 1 apariciones
# 	#10: 7740.png con 1 apariciones
#
#
# Clase: 6_train
# Shape of the class matrix 6_train: (5918, 5918)
# 	3136.png (6_train) vs 35026.png (6_train), Simililarity: 0.0267
# 	3136.png (6_train) vs 53398.png (6_train), Simililarity: 0.0366
# 	33790.png (6_train) vs 3136.png (6_train), Simililarity: 0.0368
# 	3136.png (6_train) vs 18908.png (6_train), Simililarity: 0.0369
# 	3136.png (6_train) vs 4170.png (6_train), Simililarity: 0.0382
# 	3136.png (6_train) vs 1190.png (6_train), Simililarity: 0.0412
# 	2588.png (6_train) vs 3136.png (6_train), Simililarity: 0.0413
# 	3136.png (6_train) vs 12220.png (6_train), Simililarity: 0.0418
# 	27812.png (6_train) vs 47962.png (6_train), Simililarity: 0.0426
# 	35734.png (6_train) vs 3136.png (6_train), Simililarity: 0.0426
# 	53398.png (6_train) vs 39709.png (6_train), Simililarity: 0.0431
# 	3136.png (6_train) vs 38936.png (6_train), Simililarity: 0.0434
# 	9860.png (6_train) vs 3136.png (6_train), Simililarity: 0.0446
# 	3136.png (6_train) vs 770.png (6_train), Simililarity: 0.0452
# 	28066.png (6_train) vs 15183.png (6_train), Simililarity: 0.0457
# 	3136.png (6_train) vs 34698.png (6_train), Simililarity: 0.0470
# 	3136.png (6_train) vs 44128.png (6_train), Simililarity: 0.0473
# 	35026.png (6_train) vs 45580.png (6_train), Simililarity: 0.0477
# 	9534.png (6_train) vs 53398.png (6_train), Simililarity: 0.0477
# 	16188.png (6_train) vs 18220.png (6_train), Simililarity: 0.0480
#
# Muestras más atípicas de esta clase:
# 	#1: 3136.png con 14 apariciones
# 	#2: 53398.png con 3 apariciones
# 	#3: 35026.png con 2 apariciones
# 	#4: 33790.png con 1 apariciones
# 	#5: 18908.png con 1 apariciones
# 	#6: 4170.png con 1 apariciones
# 	#7: 1190.png con 1 apariciones
# 	#8: 2588.png con 1 apariciones
# 	#9: 12220.png con 1 apariciones
# 	#10: 27812.png con 1 apariciones
#
#
# Clase: 7_train
# Shape of the class matrix 7_train: (6265, 6265)
# 	20720.png (7_train) vs 45811.png (7_train), Simililarity: 0.0123
# 	34314.png (7_train) vs 54871.png (7_train), Simililarity: 0.0153
# 	27265.png (7_train) vs 15922.png (7_train), Simililarity: 0.0197
# 	41535.png (7_train) vs 28670.png (7_train), Simililarity: 0.0217
# 	41535.png (7_train) vs 15554.png (7_train), Simililarity: 0.0232
# 	5068.png (7_train) vs 9235.png (7_train), Simililarity: 0.0263
# 	57672.png (7_train) vs 16264.png (7_train), Simililarity: 0.0263
# 	1127.png (7_train) vs 586.png (7_train), Simililarity: 0.0268
# 	31300.png (7_train) vs 5068.png (7_train), Simililarity: 0.0273
# 	34314.png (7_train) vs 55291.png (7_train), Simililarity: 0.0284
# 	16264.png (7_train) vs 14522.png (7_train), Simililarity: 0.0287
# 	28670.png (7_train) vs 44323.png (7_train), Simililarity: 0.0288
# 	46009.png (7_train) vs 15922.png (7_train), Simililarity: 0.0290
# 	50664.png (7_train) vs 16264.png (7_train), Simililarity: 0.0291
# 	16264.png (7_train) vs 28670.png (7_train), Simililarity: 0.0293
# 	28670.png (7_train) vs 52486.png (7_train), Simililarity: 0.0295
# 	586.png (7_train) vs 28670.png (7_train), Simililarity: 0.0296
# 	5068.png (7_train) vs 46009.png (7_train), Simililarity: 0.0298
# 	39316.png (7_train) vs 46009.png (7_train), Simililarity: 0.0299
# 	20720.png (7_train) vs 49933.png (7_train), Simililarity: 0.0302
#
# Muestras más atípicas de esta clase:
# 	#1: 28670.png con 5 apariciones
# 	#2: 16264.png con 4 apariciones
# 	#3: 5068.png con 3 apariciones
# 	#4: 46009.png con 3 apariciones
# 	#5: 20720.png con 2 apariciones
# 	#6: 34314.png con 2 apariciones
# 	#7: 15922.png con 2 apariciones
# 	#8: 41535.png con 2 apariciones
# 	#9: 586.png con 2 apariciones
# 	#10: 45811.png con 1 apariciones
#
#
# Clase: 8_train
# Shape of the class matrix 8_train: (5851, 5851)
# 	45954.png (8_train) vs 1120.png (8_train), Simililarity: 0.0821
# 	8761.png (8_train) vs 25546.png (8_train), Simililarity: 0.0850
# 	8761.png (8_train) vs 12032.png (8_train), Simililarity: 0.0900
# 	25546.png (8_train) vs 20157.png (8_train), Simililarity: 0.0934
# 	25546.png (8_train) vs 8701.png (8_train), Simililarity: 0.0948
# 	10064.png (8_train) vs 30777.png (8_train), Simililarity: 0.0955
# 	8867.png (8_train) vs 25546.png (8_train), Simililarity: 0.0960
# 	55368.png (8_train) vs 10064.png (8_train), Simililarity: 0.0963
# 	49543.png (8_train) vs 1120.png (8_train), Simililarity: 0.0968
# 	25546.png (8_train) vs 30147.png (8_train), Simililarity: 0.0972
# 	25232.png (8_train) vs 42504.png (8_train), Simililarity: 0.0978
# 	33074.png (8_train) vs 10358.png (8_train), Simililarity: 0.0981
# 	30545.png (8_train) vs 25986.png (8_train), Simililarity: 0.0983
# 	43109.png (8_train) vs 42504.png (8_train), Simililarity: 0.1005
# 	8761.png (8_train) vs 31972.png (8_train), Simililarity: 0.1008
# 	1120.png (8_train) vs 7851.png (8_train), Simililarity: 0.1014
# 	14478.png (8_train) vs 10064.png (8_train), Simililarity: 0.1022
# 	25232.png (8_train) vs 10064.png (8_train), Simililarity: 0.1023
# 	42504.png (8_train) vs 46504.png (8_train), Simililarity: 0.1052
# 	42987.png (8_train) vs 10064.png (8_train), Simililarity: 0.1055
#
# Muestras más atípicas de esta clase:
# 	#1: 25546.png con 5 apariciones
# 	#2: 10064.png con 5 apariciones
# 	#3: 1120.png con 3 apariciones
# 	#4: 8761.png con 3 apariciones
# 	#5: 42504.png con 3 apariciones
# 	#6: 25232.png con 2 apariciones
# 	#7: 45954.png con 1 apariciones
# 	#8: 12032.png con 1 apariciones
# 	#9: 20157.png con 1 apariciones
# 	#10: 8701.png con 1 apariciones
#
#
# Clase: 9_train
# Shape of the class matrix 9_train: (5949, 5949)
# 	9938.png (9_train) vs 2798.png (9_train), Simililarity: 0.0100
# 	40804.png (9_train) vs 2798.png (9_train), Simililarity: 0.0148
# 	2798.png (9_train) vs 32256.png (9_train), Simililarity: 0.0179
# 	2798.png (9_train) vs 600.png (9_train), Simililarity: 0.0182
# 	25900.png (9_train) vs 2798.png (9_train), Simililarity: 0.0217
# 	2798.png (9_train) vs 20054.png (9_train), Simililarity: 0.0218
# 	2798.png (9_train) vs 48224.png (9_train), Simililarity: 0.0229
# 	13728.png (9_train) vs 2798.png (9_train), Simililarity: 0.0239
# 	2798.png (9_train) vs 49442.png (9_train), Simililarity: 0.0244
# 	15970.png (9_train) vs 2798.png (9_train), Simililarity: 0.0256
# 	2798.png (9_train) vs 49690.png (9_train), Simililarity: 0.0257
# 	21302.png (9_train) vs 2798.png (9_train), Simililarity: 0.0258
# 	2798.png (9_train) vs 27968.png (9_train), Simililarity: 0.0260
# 	43058.png (9_train) vs 2798.png (9_train), Simililarity: 0.0260
# 	2798.png (9_train) vs 38809.png (9_train), Simililarity: 0.0273
# 	2798.png (9_train) vs 21592.png (9_train), Simililarity: 0.0275
# 	3745.png (9_train) vs 2798.png (9_train), Simililarity: 0.0278
# 	54335.png (9_train) vs 2798.png (9_train), Simililarity: 0.0279
# 	2798.png (9_train) vs 45756.png (9_train), Simililarity: 0.0280
# 	5746.png (9_train) vs 9876.png (9_train), Simililarity: 0.0281
#
# Muestras más atípicas de esta clase:
# 	#1: 2798.png con 19 apariciones
# 	#2: 9938.png con 1 apariciones
# 	#3: 40804.png con 1 apariciones
# 	#4: 32256.png con 1 apariciones
# 	#5: 600.png con 1 apariciones
# 	#6: 25900.png con 1 apariciones
# 	#7: 20054.png con 1 apariciones
# 	#8: 48224.png con 1 apariciones
# 	#9: 13728.png con 1 apariciones
# 	#10: 49442.png con 1 apariciones

# %%
# Función para encontrar y mostrar las imágenes menos similares usando la matriz M  
def show_least_similar_using_M(estimator, filenames_dict):  
    images_to_show = []  # Lista para almacenar las imágenes y sus detalles  

    # Obtener la matriz de similitud global (M)  
    M = estimator.M  

    # Imprimir la forma de la matriz de similitud  
    print(f"Forma de la matriz M: {M.shape}")  

    # Ordenar los índices según las similitudes (de menor a mayor)  
    least_similar_indices = np.argsort(M, axis=None)  

    shown_pairs = set()  # Para rastrear los pares de índices ya mostrados  
    count = 0  
    show_samples = 20  # Número de muestras para visualizar la similitud  

    # Diccionario para contar la participación de cada imagen  
    participation_count = {}  

    for idx in least_similar_indices:  
        if count >= show_samples:  
            break  

        # Convertir el índice plano a índice 2D  
        idx_2d = np.unravel_index(idx, M.shape)  

        # Saltar las comparaciones de una muestra consigo misma  
        if idx_2d[0] == idx_2d[1]:  
            continue  

        # Crear un par ordenado de índices para prevenir duplicados  
        index_pair = tuple(sorted((idx_2d[0], idx_2d[1])))  

        # Verificamos si el par ya fue mostrado  
        if index_pair in shown_pairs:  
            continue  

        shown_pairs.add(index_pair)  

        # Actualizar el conteo de participación  
        participation_count[idx_2d[0]] = participation_count.get(idx_2d[0], 0) + 1  
        participation_count[idx_2d[1]] = participation_count.get(idx_2d[1], 0) + 1  

        # Verificar que los índices estén dentro de los límites del dataset  
        if idx_2d[0] < len(filenames_dict) and idx_2d[1] < len(filenames_dict):  
            source_filename = Path(filenames_dict[int(idx_2d[0])])  
            target_filename = Path(filenames_dict[int(idx_2d[1])])  

            value = M[idx_2d]  

            # Formatear y mostrar la salida  
            print(f"{source_filename.name} vs {target_filename.name}, Similitud: {value:.4f}")  

            # Agrega los detalles a la lista para visualización  
            images_to_show.append((source_filename, target_filename, value))  

            count += 1  

    # Encontrar las muestras más atípicas  
    most_atypical = sorted(participation_count.items(), key=lambda x: -x[1])  

    # Mostrar las 10 más atípicas  
    print("\nMuestras más atípicas del dataset:")  
    for rank, (img_idx, freq) in enumerate(most_atypical[:10], 1):  
        img_name = Path(filenames_dict[int(img_idx)]).name  
        print(f"\t#{rank}: {img_name} con {freq} apariciones")  
    print("\n")  

    # Luego, realiza la visualización de las imágenes  
    for source_filename, target_filename, value in images_to_show:  
        img_source = plt.imread(source_filename)  
        img_target = plt.imread(target_filename)  

        fig, axs = plt.subplots(1, 2, figsize=(5, 3))  
        axs[0].imshow(img_source)  
        axs[0].set_title(f"{source_filename.name}", fontsize=8)  
        axs[0].axis('off')  # Elimina los ejes para centrar la atención en la imagen  

        axs[1].imshow(img_target)  
        axs[1].set_title(f"{target_filename.name}", fontsize=8)  
        axs[1].axis('off')  
        plt.suptitle(f"Similarity: {value:.4f}")  
        plt.subplots_adjust(wspace=0.3, hspace=0.3)  # Ajusta el espacio entre subtramas  
        plt.show()  


print("Muestras menos similares entre todas las imágenes del dataset \n")  
show_least_similar_using_M(estimator, filenames_dict)
# Out:
# Muestras menos similares entre todas las imágenes del dataset
#
# Forma de la matriz M: (60000, 60000)
# 31727.png vs 29609.png, Similitud: 0.0000
# 25456.png vs 35777.png, Similitud: 0.0000
# 1046.png vs 35777.png, Similitud: 0.0000
# 24444.png vs 42703.png, Similitud: 0.0000
# 23136.png vs 35777.png, Similitud: 0.0000
# 49613.png vs 28414.png, Similitud: 0.0000
# 42503.png vs 13673.png, Similitud: 0.0000
# 11514.png vs 35777.png, Similitud: 0.0000
# 38415.png vs 31727.png, Similitud: 0.0000
# 42415.png vs 35787.png, Similitud: 0.0000
# 27793.png vs 31727.png, Similitud: 0.0000
# 35777.png vs 7318.png, Similitud: 0.0001
# 47572.png vs 35777.png, Similitud: 0.0004
# 38106.png vs 42703.png, Similitud: 0.0004
# 31727.png vs 41956.png, Similitud: 0.0004
# 35777.png vs 27859.png, Similitud: 0.0005
# 35777.png vs 22008.png, Similitud: 0.0005
# 35777.png vs 17392.png, Similitud: 0.0005
# 5830.png vs 35777.png, Similitud: 0.0005
# 1416.png vs 14074.png, Similitud: 0.0005
#
# Muestras más atípicas del dataset:
# 	#1: 35777.png con 10 apariciones
# 	#2: 31727.png con 4 apariciones
# 	#3: 42703.png con 2 apariciones
# 	#4: 29609.png con 1 apariciones
# 	#5: 25456.png con 1 apariciones
# 	#6: 1046.png con 1 apariciones
# 	#7: 24444.png con 1 apariciones
# 	#8: 23136.png con 1 apariciones
# 	#9: 49613.png con 1 apariciones
# 	#10: 28414.png con 1 apariciones
