# %% [markdown]
# # Librerias

# %%
# Carga de librerías
import numpy as np
import tensorflow as tf
import PIL
import PIL.Image
import pathlib
import scipy as sp
import seaborn as sns
from itertools import product
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
import os
import pathlib
from pathlib import Path
# Out:
# WARNING:tensorflow:From C:\Users\Cesar\AppData\Local\Temp\ipykernel_1192\3157514746.py:13: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.

# %%
import pickle
import sys
from pathlib import Path

from numpy.linalg import LinAlgError
from scipy.sparse.csgraph import laplacian
from new_spectral_metric.new_estimator_complete import CumulativeGradientEstimator_Complete
from new_spectral_metric.new_visualize import make_graph
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Conv2D, Dense, MaxPooling2D, Lambda
from tensorflow.keras import backend as K
from pathlib import Path
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from matplotlib.collections import LineCollection
from matplotlib.font_manager import FontProperties
from pathlib import Path

# %% [markdown]
# # DATASET DESDE DIRECTORIO

# %%
#Lectura de dataset

directorio_dataset = ('../../../../Datasets/Fashion_MNIST')
directorio_dataset = pathlib.Path(directorio_dataset)

# Lectura de la carpeta train
directorio_train = ('../../../../Datasets/Fashion_MNIST/train')
directorio_train = pathlib.Path(directorio_train)

# Lectura de la carpeta test
directorio_test = ('../../../../Datasets/Fashion_MNIST/test')
directorio_test = pathlib.Path(directorio_test)

total_dataset = len(list(directorio_dataset.glob('*/*/*.png')))  # Cuenta la cantidad de imagenes del dataset (Aqui busca en las subcarpetas del directorio del dataset)
total_train = len(list(directorio_train.glob('*/*.png')))  # Cuenta la cantidad de imagenes de train
total_test = len(list(directorio_test.glob('*/*.png')))  # Cuenta la cantidad de imagenes de test

print(f"Total imagenes dataset: {total_dataset}")
print(f"Total imagenes train: {total_train}")
print(f"Total imagenes test: {total_test}")
# Out:
# Total imagenes dataset: 70000
# Total imagenes train: 60000
# Total imagenes test: 10000

# %%
# Definir el batchsize del dataset completo
batch_size_total = total_dataset

# %%
# Dimensiones de imagen y tamaño de batch en train
img_height = 28
img_width = 28
#batch_size = 32
batch_size_train = total_train

# %%
import tensorflow as tf
import pathlib

# Data splitting (entrenamiento y validación)
train_images = tf.keras.preprocessing.image_dataset_from_directory(
  directorio_train,
  #validation_split=0.2,
  color_mode='rgb',
  label_mode='int',
  #subset="training",
  #seed=123,
  shuffle=False,
  image_size=(img_height, img_width),
  batch_size=batch_size_train)
# Out:
# Found 60000 files belonging to 10 classes.

# %%
# Dimensiones de imagen y tamaño de batch en test
img_height = 28
img_width = 28
#batch_size = 32
batch_size_test = total_test

# %%
# Data splitting (entrenamiento y validación)
test_images = tf.keras.preprocessing.image_dataset_from_directory(
  directorio_test,
  #validation_split=0.2,
  color_mode='rgb',
  label_mode='int',
  #subset="training",
  #seed=123,
  shuffle=False,
  image_size=(img_height, img_width),
  batch_size=batch_size_test)
# Out:
# Found 10000 files belonging to 10 classes.

# %%
# Contar el total de imágenes por clase en train y test  
class_counts_total = {p.name: len(list(p.glob('*.png'))) for p in directorio_dataset.glob('*/*')}  
class_counts_train = {p.name: len(list(p.glob('*.png'))) for p in directorio_train.glob('*')}  
class_counts_test = {p.name: len(list(p.glob('*.png'))) for p in directorio_test.glob('*')}  

# Encontrar el valor más bajo de imágenes por clase en train  
menor_train = min(class_counts_train.values()) if class_counts_train else None  # Se almacena el valor de la clase que menos muestras tiene

# Encontrar el valor más alto de imágenes por clase en train  
mayor_train = max(class_counts_train.values()) if class_counts_train else None  # Se almacena el valor de la clase que mas muestras tiene


# Encontrar el valor más bajo de imágenes por clase en test  
menor_test = min(class_counts_test.values()) if class_counts_test else None  # Se almacena el valor de la clase que menos muestras tiene

# Encontrar el valor más alto de imágenes por clase en test  
mayor_test = max(class_counts_test.values()) if class_counts_test else None  # Se almacena el valor de la clase que mas muestras tiene


# Mostrar el total de imágenes por clase en train  
print("\nTotal images per class in train:")  
for class_name, count in class_counts_train.items():  
    print(f"Class: {class_name}, Number of images: {count}")  
print(f"Total images train: {sum(class_counts_train.values())}")  

# Mostrar el valor más bajo en train  
print(f"Fewer number of images in train: {menor_train}")  

# Mostrar el valor más alto en train  
print(f"Higher number of images in train: {mayor_train}")  

# Mostrar el total de imágenes por clase en test  
print("\nTotal images per class in test:")  
for class_name, count in class_counts_test.items():  
    print(f"Class: {class_name}, Number of images: {count}")  
print(f"Total images test: {sum(class_counts_test.values())}")  

# Mostrar el valor más bajo en test  
print(f"Fewer images in test: {menor_test}")

# Mostrar el valor más alto en test  
print(f"Higher number of images in test: {mayor_test}")
# Out:
# Total images per class in train:
# Class: 0 - T shirt_top, Number of images: 6000
# Class: 1 - Trouser, Number of images: 6000
# Class: 2 - Pullover, Number of images: 6000
# Class: 3 - Dress, Number of images: 6000
# Class: 4 - Coat, Number of images: 6000
# Class: 5 - Sandal, Number of images: 6000
# Class: 6 - Shirt, Number of images: 6000
# Class: 7 - Sneaker, Number of images: 6000
# Class: 8 - Bag, Number of images: 6000
# Class: 9 - Ankle boot, Number of images: 6000
# Total images train: 60000
# Fewer number of images in train: 6000
# Higher number of images in train: 6000
#
# Total images per class in test:
# Class: 0 - T shirt_top, Number of images: 1000
# Class: 1 - Trouser, Number of images: 1000
# Class: 2 - Pullover, Number of images: 1000
# Class: 3 - Dress, Number of images: 1000
# Class: 4 - Coat, Number of images: 1000
# Class: 5 - Sandal, Number of images: 1000
# Class: 6 - Shirt, Number of images: 1000
# Class: 7 - Sneaker, Number of images: 1000
# Class: 8 - Bag, Number of images: 1000
# Class: 9 - Ankle boot, Number of images: 1000
# Total images test: 10000
# Fewer images in test: 1000
# Higher number of images in test: 1000

# %%
# Nombres de las clases
class_names_train = list(class_counts_train.keys())
class_names_test = list(class_counts_test.keys())
#class_names_total = sorted(list(set(class_names_train + class_names_test)))
class_names_total = list(class_counts_total.keys())

# Mostrar el número de clases y los nombres
print(f"\nNúmero de clases en train: {len(class_names_train)}")
print(f"Nombres de las clases en train: {class_names_train}")

print(f"\nNúmero de clases en test: {len(class_names_test)}")
print(f"Nombres de las clases en test: {class_names_test}")

print(f"\nNúmero total de clases en el dataset: {len(class_names_total)}")   # Este valor cambia si el nombre de las clases es diferente
print(f"Nombres de todas las clases en el dataset: {class_names_total}")     # Este valor tambien cambia si el nombre de las clases es diferente
# Out:
# Número de clases en train: 10
# Nombres de las clases en train: ['0 - T shirt_top', '1 - Trouser', '2 - Pullover', '3 - Dress', '4 - Coat', '5 - Sandal', '6 - Shirt', '7 - Sneaker', '8 - Bag', '9 - Ankle boot']
#
# Número de clases en test: 10
# Nombres de las clases en test: ['0 - T shirt_top', '1 - Trouser', '2 - Pullover', '3 - Dress', '4 - Coat', '5 - Sandal', '6 - Shirt', '7 - Sneaker', '8 - Bag', '9 - Ankle boot']
#
# Número total de clases en el dataset: 10
# Nombres de todas las clases en el dataset: ['0 - T shirt_top', '1 - Trouser', '2 - Pullover', '3 - Dress', '4 - Coat', '5 - Sandal', '6 - Shirt', '7 - Sneaker', '8 - Bag', '9 - Ankle boot']

# %%
for images, labels0 in train_images.take(1):  # only take first element of dataset
    numpy_all_images = images.numpy()  # convertir el tensor de imágenes en un arreglo de numpy y ahora contiene las imágenes del conjunto de datos en formato de numpy.
    numpy_all_labels = labels0.numpy()  # convierte el tensor de etiquetas en un arreglo de numpy y ahora contiene las etiquetas del conjunto de datos en formato de numpy

numpy_all_images /= 255.0  # Scale the features to the [0, 1] range
print(numpy_all_images.shape)

# CIFAR-10 
fully_dataset_train = numpy_all_images.reshape((numpy_all_images.shape[0], numpy_all_images.shape[1]*numpy_all_images.shape[2]*numpy_all_images.shape[3])) # es un arreglo bidimensional donde cada fila representa una imagen y cada columna representa un píxel de la imagen
fully_labels_train = numpy_all_labels.reshape(numpy_all_labels.shape[0],)
# Out:
# (60000, 28, 28, 3)

# %% [markdown]
# # Dataset complexity using CSG

# %%
estimator = CumulativeGradientEstimator_Complete(M_sample=mayor_train, k_nearest=10)  # Utiliza el numero menor de muestras encontrado en cada clase dependiendo si es train o test
estimator.fit(data=fully_dataset_train, target=fully_labels_train)
csg = estimator.csg  # The actual complexity values.
estimator.evals, estimator.evecs  # The eigenvalues and vectors.

make_graph(estimator.difference, title="Dataset Complexity - Fashion MNIST: "+str(csg), classes=class_names_train)
# Out:
# c:\Users\Cesar\AppData\Local\Programs\Python\Python312\Lib\site-packages\new_spectral_metric\new_visualize.py:48: RuntimeWarning: divide by zero encountered in divide
#   similarities = difference.max() / difference * 100
# c:\Users\Cesar\AppData\Local\Programs\Python\Python312\Lib\site-packages\new_spectral_metric\new_visualize.py:59: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# # Calcular la similitud entre clases

# %%
from scipy.stats import entropy  
import pandas as pd  

# Calcular la entropía por clase  
entropy_per_class = entropy(estimator.W / estimator.W.sum(-1)[:, None], axis=-1)  

# Encontrar la clase más confusa (mayor entropía)  
most_confused_class_index = np.argmax(entropy_per_class)  
most_confused_class_name = class_names_train[most_confused_class_index]  

print("Class that is the most confused (highest entropy):", most_confused_class_name)
# Out:
# Class that is the most confused (highest entropy): 6 - Shirt

# %%
# Obtener los índices de los pares más similares  
pairs = list(zip(*np.unravel_index(np.argsort(estimator.W, axis=None)[::-1], estimator.W.shape)))  

# Filtrar pares donde i != j para evitar pares de la misma clase  
pairs = [(i, j) for i, j in pairs if i != j]  

print("Most similar pairs")  
lst = []  
seen_pairs = set()  

# Iterar sobre los primeros 10 pares más similares  
for i, j in pairs:  
    # Verificar si el par o su inverso ya ha sido visto  
    if (i, j) not in seen_pairs and (j, i) not in seen_pairs:  
        lst.append({"Intent pair": f"{class_names_train[i]} <> {class_names_train[j]}", "Similarity": estimator.W[i, j]})  
        seen_pairs.add((i, j))  
        seen_pairs.add((j, i))  
    
    # Detenerse después de encontrar 10 pares únicos  
    if len(lst) == 10:  
        break  

# Mostrar los resultados en un DataFrame  
print(pd.DataFrame(lst))
# Out:
# Most similar pairs
#                        Intent pair  Similarity
# 0         4 - Coat <> 2 - Pullover    0.416067
# 1            4 - Coat <> 6 - Shirt    0.382050
# 2     6 - Shirt <> 0 - T shirt_top    0.381333
# 3        6 - Shirt <> 2 - Pullover    0.375117
# 4        7 - Sneaker <> 5 - Sandal    0.200067
# 5      4 - Coat <> 0 - T shirt_top    0.195883
# 6           6 - Shirt <> 3 - Dress    0.194117
# 7  0 - T shirt_top <> 2 - Pullover    0.183433
# 8            4 - Coat <> 3 - Dress    0.161100
# 9     0 - T shirt_top <> 3 - Dress    0.153117

# %% [markdown]
# # Obtener los nombres de las imagenes en train o test (dependiendo de lo que se quiera probar)

# %%
# Obtener todos los nombres de archivo en el dataset
filenames = [str(f) for f in directorio_train.glob('*/*.png')]

# Crear un mapeo de índices a rutas completas de archivo  
filenames_dict = {i: str(f) for i, f in enumerate(directorio_train.glob('*/*.png'))}

# %% [markdown]
# # Calcular la similitud entre muestras

# %%
# Función para encontrar y mostrar las imágenes más similares dentro de cada clase usando la matriz C  
def show_most_similar_using_C_all_classes(estimator, class_names, filenames_dict):  
    images_to_show = []  # Lista para almacenar las imágenes y sus detalles  

    # Primero, recorre las clases y genera la lista de descripciones  
    for class_intent in range(len(class_names)):  
        class_name = class_names[class_intent]  
        print(f"Clase: {class_name}")  
        
        # Obtener la matriz de similitud de las muestras dentro de la clase  
        C = estimator.C[class_intent]  

        # Imprimir la forma de la matriz de similitud de la clase  
        print(f"Forma de la matriz de la clase {class_name}: {C.shape}")  
        
        # Ordenar los índices según las similitudes (de mayor a menor)  
        most_similar_indices = np.argsort(C, axis=None)[::-1]  
        
        shown_pairs = set()  # Para rastrear los pares de índices ya mostrados  
        count = 0  
        show_samples = 20  # Número de muestras para visualizar la similitud  
        
        # Diccionario para contar la participación de cada imagen  
        participation_count = {}  

        for idx in most_similar_indices:  
            if count >= show_samples:  
                break  
            
            # Convertir el índice plano a índice 2D  
            idx_2d = np.unravel_index(idx, C.shape)  
            
            # Saltar las comparaciones de una muestra consigo misma  
            if idx_2d[0] == idx_2d[1]:  
                continue  
            
            # Crear un par ordenado de índices para prevenir duplicados  
            index_pair = tuple(sorted((idx_2d[0], idx_2d[1])))  
            
            # Verificamos si el par ya fue mostrado  
            if index_pair in shown_pairs:  
                continue  
            
            shown_pairs.add(index_pair)  
            
            # Actualizar el conteo de participación  
            participation_count[idx_2d[0]] = participation_count.get(idx_2d[0], 0) + 1  
            participation_count[idx_2d[1]] = participation_count.get(idx_2d[1], 0) + 1  

            # Obtener los índices de las muestras en el dataset  
            source_idx = estimator.class_indices[class_intent][idx_2d[0]]  
            target_idx = estimator.class_indices[class_intent][idx_2d[1]]  
            
            # Verificar que los índices estén dentro de los límites del dataset  
            if source_idx < len(filenames_dict) and target_idx < len(filenames_dict):  
                source_filename = Path(filenames_dict[int(source_idx)])  
                target_filename = Path(filenames_dict[int(target_idx)])  
                
                value = C[idx_2d]  
                
                # Formatear y mostrar la salida  
                print(f"\t{source_filename.name} ({class_name}) vs {target_filename.name} ({class_name}), Similitud: {value:.4f}")  
                
                # Agrega los detalles a la lista para visualización  
                images_to_show.append((source_filename, target_filename, class_name, value))  
                
                count += 1  
    

        # Encontrar las muestras más representativas  
        most_representative = sorted(participation_count.items(), key=lambda x: -x[1])  
        
        # Mostrar las 10 más representativas  
        print("\nMuestras más representativas de esta clase:")  
        for rank, (img_idx, freq) in enumerate(most_representative[:10], 1):  
            img_name = Path(filenames_dict[int(estimator.class_indices[class_intent][img_idx])]).name  
            print(f"\t#{rank}: {img_name} con {freq} apariciones")  
        print("\n")  


    # Luego, realiza la visualización de las imágenes  
    for source_filename, target_filename, class_name, value in images_to_show:  
        img_source = plt.imread(source_filename)  
        img_target = plt.imread(target_filename)  
        
        fig, axs = plt.subplots(1, 2, figsize=(5, 3))  
        axs[0].imshow(img_source)  
        axs[0].set_title(f"{class_name}: \n{source_filename.name}", fontsize=8)   
        axs[0].axis('off')  # Elimina los ejes para centrar la atención en la imagen  
        
        axs[1].imshow(img_target)  
        axs[1].set_title(f"{class_name}: \n{target_filename.name}", fontsize=8)  
        axs[1].axis('off')   
        plt.suptitle(f"Similarity: {value:.4f}")  
        plt.subplots_adjust(wspace=0.3, hspace=0.3)  # Ajusta el espacio entre subtramas    
        plt.show()  


print("Muestras más similares entre las imágenes de la misma clase \n")  
show_most_similar_using_C_all_classes(estimator, class_names_train, filenames_dict)
# Out:
# Muestras más similares entre las imágenes de la misma clase
#
# Clase: 0 - T shirt_top
# Forma de la matriz de la clase 0 - T shirt_top: (6000, 6000)
# 	39882.png (0 - T shirt_top) vs 32140.png (0 - T shirt_top), Similitud: 0.9946
# 	56004.png (0 - T shirt_top) vs 58762.png (0 - T shirt_top), Similitud: 0.9940
# 	13005.png (0 - T shirt_top) vs 25251.png (0 - T shirt_top), Similitud: 0.9906
# 	32812.png (0 - T shirt_top) vs 13005.png (0 - T shirt_top), Similitud: 0.9887
# 	55613.png (0 - T shirt_top) vs 27857.png (0 - T shirt_top), Similitud: 0.9873
# 	55763.png (0 - T shirt_top) vs 19152.png (0 - T shirt_top), Similitud: 0.9852
# 	25251.png (0 - T shirt_top) vs 32812.png (0 - T shirt_top), Similitud: 0.9821
# 	14568.png (0 - T shirt_top) vs 5138.png (0 - T shirt_top), Similitud: 0.9805
# 	48677.png (0 - T shirt_top) vs 10075.png (0 - T shirt_top), Similitud: 0.9805
# 	31786.png (0 - T shirt_top) vs 14568.png (0 - T shirt_top), Similitud: 0.9791
# 	54857.png (0 - T shirt_top) vs 58762.png (0 - T shirt_top), Similitud: 0.9779
# 	57471.png (0 - T shirt_top) vs 27130.png (0 - T shirt_top), Similitud: 0.9778
# 	42540.png (0 - T shirt_top) vs 58762.png (0 - T shirt_top), Similitud: 0.9773
# 	43863.png (0 - T shirt_top) vs 24887.png (0 - T shirt_top), Similitud: 0.9771
# 	11916.png (0 - T shirt_top) vs 54360.png (0 - T shirt_top), Similitud: 0.9769
# 	54857.png (0 - T shirt_top) vs 56004.png (0 - T shirt_top), Similitud: 0.9768
# 	22400.png (0 - T shirt_top) vs 26512.png (0 - T shirt_top), Similitud: 0.9766
# 	50193.png (0 - T shirt_top) vs 22400.png (0 - T shirt_top), Similitud: 0.9765
# 	28191.png (0 - T shirt_top) vs 3777.png (0 - T shirt_top), Similitud: 0.9760
# 	39537.png (0 - T shirt_top) vs 22400.png (0 - T shirt_top), Similitud: 0.9755
#
# Muestras más representativas de esta clase:
# 	#1: 58762.png con 3 apariciones
# 	#2: 22400.png con 3 apariciones
# 	#3: 56004.png con 2 apariciones
# 	#4: 13005.png con 2 apariciones
# 	#5: 25251.png con 2 apariciones
# 	#6: 32812.png con 2 apariciones
# 	#7: 14568.png con 2 apariciones
# 	#8: 54857.png con 2 apariciones
# 	#9: 39882.png con 1 apariciones
# 	#10: 32140.png con 1 apariciones
#
#
# Clase: 1 - Trouser
# Forma de la matriz de la clase 1 - Trouser: (6000, 6000)
# 	29413.png (1 - Trouser) vs 43549.png (1 - Trouser), Similitud: 0.9981
# 	43549.png (1 - Trouser) vs 753.png (1 - Trouser), Similitud: 0.9978
# 	29413.png (1 - Trouser) vs 753.png (1 - Trouser), Similitud: 0.9978
# 	43549.png (1 - Trouser) vs 21295.png (1 - Trouser), Similitud: 0.9973
# 	31061.png (1 - Trouser) vs 56201.png (1 - Trouser), Similitud: 0.9971
# 	29413.png (1 - Trouser) vs 21295.png (1 - Trouser), Similitud: 0.9968
# 	51503.png (1 - Trouser) vs 56201.png (1 - Trouser), Similitud: 0.9962
# 	753.png (1 - Trouser) vs 21295.png (1 - Trouser), Similitud: 0.9960
# 	51503.png (1 - Trouser) vs 31061.png (1 - Trouser), Similitud: 0.9947
# 	34772.png (1 - Trouser) vs 49602.png (1 - Trouser), Similitud: 0.9885
# 	51970.png (1 - Trouser) vs 24633.png (1 - Trouser), Similitud: 0.9841
# 	6132.png (1 - Trouser) vs 36774.png (1 - Trouser), Similitud: 0.9773
# 	59025.png (1 - Trouser) vs 18494.png (1 - Trouser), Similitud: 0.9759
# 	38570.png (1 - Trouser) vs 29937.png (1 - Trouser), Similitud: 0.9732
# 	9256.png (1 - Trouser) vs 18802.png (1 - Trouser), Similitud: 0.9726
# 	42634.png (1 - Trouser) vs 20080.png (1 - Trouser), Similitud: 0.9716
# 	31553.png (1 - Trouser) vs 12590.png (1 - Trouser), Similitud: 0.9715
# 	39143.png (1 - Trouser) vs 4540.png (1 - Trouser), Similitud: 0.9709
# 	17776.png (1 - Trouser) vs 38608.png (1 - Trouser), Similitud: 0.9700
# 	2265.png (1 - Trouser) vs 3394.png (1 - Trouser), Similitud: 0.9691
#
# Muestras más representativas de esta clase:
# 	#1: 29413.png con 3 apariciones
# 	#2: 43549.png con 3 apariciones
# 	#3: 753.png con 3 apariciones
# 	#4: 21295.png con 3 apariciones
# 	#5: 31061.png con 2 apariciones
# 	#6: 56201.png con 2 apariciones
# 	#7: 51503.png con 2 apariciones
# 	#8: 34772.png con 1 apariciones
# 	#9: 49602.png con 1 apariciones
# 	#10: 51970.png con 1 apariciones
#
#
# Clase: 2 - Pullover
# Forma de la matriz de la clase 2 - Pullover: (6000, 6000)
# 	9664.png (2 - Pullover) vs 5081.png (2 - Pullover), Similitud: 0.9920
# 	35999.png (2 - Pullover) vs 9664.png (2 - Pullover), Similitud: 0.9904
# 	5081.png (2 - Pullover) vs 35999.png (2 - Pullover), Similitud: 0.9903
# 	24208.png (2 - Pullover) vs 56477.png (2 - Pullover), Similitud: 0.9893
# 	8338.png (2 - Pullover) vs 9664.png (2 - Pullover), Similitud: 0.9869
# 	47716.png (2 - Pullover) vs 35999.png (2 - Pullover), Similitud: 0.9867
# 	8338.png (2 - Pullover) vs 5081.png (2 - Pullover), Similitud: 0.9862
# 	5081.png (2 - Pullover) vs 47716.png (2 - Pullover), Similitud: 0.9853
# 	8338.png (2 - Pullover) vs 35999.png (2 - Pullover), Similitud: 0.9846
# 	9664.png (2 - Pullover) vs 47716.png (2 - Pullover), Similitud: 0.9844
# 	47716.png (2 - Pullover) vs 8338.png (2 - Pullover), Similitud: 0.9823
# 	5081.png (2 - Pullover) vs 40888.png (2 - Pullover), Similitud: 0.9797
# 	9664.png (2 - Pullover) vs 40888.png (2 - Pullover), Similitud: 0.9788
# 	35221.png (2 - Pullover) vs 9664.png (2 - Pullover), Similitud: 0.9778
# 	41357.png (2 - Pullover) vs 37744.png (2 - Pullover), Similitud: 0.9777
# 	35999.png (2 - Pullover) vs 40888.png (2 - Pullover), Similitud: 0.9776
# 	1928.png (2 - Pullover) vs 3704.png (2 - Pullover), Similitud: 0.9768
# 	35221.png (2 - Pullover) vs 35999.png (2 - Pullover), Similitud: 0.9759
# 	7582.png (2 - Pullover) vs 18978.png (2 - Pullover), Similitud: 0.9759
# 	22801.png (2 - Pullover) vs 65.png (2 - Pullover), Similitud: 0.9754
#
# Muestras más representativas de esta clase:
# 	#1: 9664.png con 6 apariciones
# 	#2: 35999.png con 6 apariciones
# 	#3: 5081.png con 5 apariciones
# 	#4: 8338.png con 4 apariciones
# 	#5: 47716.png con 4 apariciones
# 	#6: 40888.png con 3 apariciones
# 	#7: 35221.png con 2 apariciones
# 	#8: 24208.png con 1 apariciones
# 	#9: 56477.png con 1 apariciones
# 	#10: 41357.png con 1 apariciones
#
#
# Clase: 3 - Dress
# Forma de la matriz de la clase 3 - Dress: (6000, 6000)
# 	334.png (3 - Dress) vs 4849.png (3 - Dress), Similitud: 0.9778
# 	31575.png (3 - Dress) vs 50007.png (3 - Dress), Similitud: 0.9761
# 	56704.png (3 - Dress) vs 57553.png (3 - Dress), Similitud: 0.9737
# 	27080.png (3 - Dress) vs 20390.png (3 - Dress), Similitud: 0.9719
# 	54535.png (3 - Dress) vs 1367.png (3 - Dress), Similitud: 0.9692
# 	30527.png (3 - Dress) vs 9819.png (3 - Dress), Similitud: 0.9665
# 	28625.png (3 - Dress) vs 26301.png (3 - Dress), Similitud: 0.9657
# 	4867.png (3 - Dress) vs 37711.png (3 - Dress), Similitud: 0.9653
# 	9000.png (3 - Dress) vs 29202.png (3 - Dress), Similitud: 0.9653
# 	23538.png (3 - Dress) vs 21356.png (3 - Dress), Similitud: 0.9641
# 	13050.png (3 - Dress) vs 31344.png (3 - Dress), Similitud: 0.9633
# 	48469.png (3 - Dress) vs 2295.png (3 - Dress), Similitud: 0.9629
# 	55034.png (3 - Dress) vs 13816.png (3 - Dress), Similitud: 0.9625
# 	59327.png (3 - Dress) vs 27423.png (3 - Dress), Similitud: 0.9622
# 	5448.png (3 - Dress) vs 3568.png (3 - Dress), Similitud: 0.9617
# 	25370.png (3 - Dress) vs 26301.png (3 - Dress), Similitud: 0.9605
# 	2500.png (3 - Dress) vs 37170.png (3 - Dress), Similitud: 0.9604
# 	30133.png (3 - Dress) vs 14834.png (3 - Dress), Similitud: 0.9594
# 	55699.png (3 - Dress) vs 30035.png (3 - Dress), Similitud: 0.9588
# 	53281.png (3 - Dress) vs 44267.png (3 - Dress), Similitud: 0.9587
#
# Muestras más representativas de esta clase:
# 	#1: 26301.png con 2 apariciones
# 	#2: 334.png con 1 apariciones
# 	#3: 4849.png con 1 apariciones
# 	#4: 31575.png con 1 apariciones
# 	#5: 50007.png con 1 apariciones
# 	#6: 56704.png con 1 apariciones
# 	#7: 57553.png con 1 apariciones
# 	#8: 27080.png con 1 apariciones
# 	#9: 20390.png con 1 apariciones
# 	#10: 54535.png con 1 apariciones
#
#
# Clase: 4 - Coat
# Forma de la matriz de la clase 4 - Coat: (6000, 6000)
# 	23412.png (4 - Coat) vs 10205.png (4 - Coat), Similitud: 0.9967
# 	50759.png (4 - Coat) vs 12981.png (4 - Coat), Similitud: 0.9959
# 	47750.png (4 - Coat) vs 567.png (4 - Coat), Similitud: 0.9943
# 	54953.png (4 - Coat) vs 46517.png (4 - Coat), Similitud: 0.9912
# 	18103.png (4 - Coat) vs 24819.png (4 - Coat), Similitud: 0.9890
# 	6300.png (4 - Coat) vs 19456.png (4 - Coat), Similitud: 0.9860
# 	3116.png (4 - Coat) vs 36319.png (4 - Coat), Similitud: 0.9761
# 	128.png (4 - Coat) vs 35650.png (4 - Coat), Similitud: 0.9759
# 	20357.png (4 - Coat) vs 55276.png (4 - Coat), Similitud: 0.9737
# 	38620.png (4 - Coat) vs 47627.png (4 - Coat), Similitud: 0.9726
# 	5251.png (4 - Coat) vs 10435.png (4 - Coat), Similitud: 0.9711
# 	264.png (4 - Coat) vs 37264.png (4 - Coat), Similitud: 0.9701
# 	40018.png (4 - Coat) vs 14283.png (4 - Coat), Similitud: 0.9701
# 	13704.png (4 - Coat) vs 24859.png (4 - Coat), Similitud: 0.9691
# 	56775.png (4 - Coat) vs 34976.png (4 - Coat), Similitud: 0.9689
# 	43300.png (4 - Coat) vs 23105.png (4 - Coat), Similitud: 0.9688
# 	26572.png (4 - Coat) vs 51118.png (4 - Coat), Similitud: 0.9679
# 	1113.png (4 - Coat) vs 19727.png (4 - Coat), Similitud: 0.9679
# 	58125.png (4 - Coat) vs 7752.png (4 - Coat), Similitud: 0.9671
# 	26262.png (4 - Coat) vs 1324.png (4 - Coat), Similitud: 0.9665
#
# Muestras más representativas de esta clase:
# 	#1: 23412.png con 1 apariciones
# 	#2: 10205.png con 1 apariciones
# 	#3: 50759.png con 1 apariciones
# 	#4: 12981.png con 1 apariciones
# 	#5: 47750.png con 1 apariciones
# 	#6: 567.png con 1 apariciones
# 	#7: 54953.png con 1 apariciones
# 	#8: 46517.png con 1 apariciones
# 	#9: 18103.png con 1 apariciones
# 	#10: 24819.png con 1 apariciones
#
#
# Clase: 5 - Sandal
# Forma de la matriz de la clase 5 - Sandal: (6000, 6000)
# 	36357.png (5 - Sandal) vs 20554.png (5 - Sandal), Similitud: 0.9938
# 	59217.png (5 - Sandal) vs 33022.png (5 - Sandal), Similitud: 0.9359
# 	14797.png (5 - Sandal) vs 35465.png (5 - Sandal), Similitud: 0.9270
# 	49970.png (5 - Sandal) vs 34835.png (5 - Sandal), Similitud: 0.9213
# 	42944.png (5 - Sandal) vs 49362.png (5 - Sandal), Similitud: 0.9203
# 	13778.png (5 - Sandal) vs 18264.png (5 - Sandal), Similitud: 0.9195
# 	18862.png (5 - Sandal) vs 41776.png (5 - Sandal), Similitud: 0.9168
# 	18862.png (5 - Sandal) vs 23769.png (5 - Sandal), Similitud: 0.9154
# 	25941.png (5 - Sandal) vs 38560.png (5 - Sandal), Similitud: 0.9148
# 	50394.png (5 - Sandal) vs 11539.png (5 - Sandal), Similitud: 0.9109
# 	28933.png (5 - Sandal) vs 43117.png (5 - Sandal), Similitud: 0.9094
# 	30669.png (5 - Sandal) vs 10055.png (5 - Sandal), Similitud: 0.9091
# 	4123.png (5 - Sandal) vs 22163.png (5 - Sandal), Similitud: 0.9078
# 	46512.png (5 - Sandal) vs 41776.png (5 - Sandal), Similitud: 0.9065
# 	56567.png (5 - Sandal) vs 50041.png (5 - Sandal), Similitud: 0.9049
# 	46512.png (5 - Sandal) vs 4155.png (5 - Sandal), Similitud: 0.9048
# 	56920.png (5 - Sandal) vs 2551.png (5 - Sandal), Similitud: 0.9044
# 	3981.png (5 - Sandal) vs 58437.png (5 - Sandal), Similitud: 0.9040
# 	23769.png (5 - Sandal) vs 41776.png (5 - Sandal), Similitud: 0.9039
# 	18547.png (5 - Sandal) vs 56073.png (5 - Sandal), Similitud: 0.9019
#
# Muestras más representativas de esta clase:
# 	#1: 41776.png con 3 apariciones
# 	#2: 18862.png con 2 apariciones
# 	#3: 23769.png con 2 apariciones
# 	#4: 46512.png con 2 apariciones
# 	#5: 36357.png con 1 apariciones
# 	#6: 20554.png con 1 apariciones
# 	#7: 59217.png con 1 apariciones
# 	#8: 33022.png con 1 apariciones
# 	#9: 14797.png con 1 apariciones
# 	#10: 35465.png con 1 apariciones
#
#
# Clase: 6 - Shirt
# Forma de la matriz de la clase 6 - Shirt: (6000, 6000)
# 	31038.png (6 - Shirt) vs 5453.png (6 - Shirt), Similitud: 0.9981
# 	31836.png (6 - Shirt) vs 32754.png (6 - Shirt), Similitud: 0.9972
# 	51488.png (6 - Shirt) vs 11932.png (6 - Shirt), Similitud: 0.9953
# 	13618.png (6 - Shirt) vs 29645.png (6 - Shirt), Similitud: 0.9847
# 	44342.png (6 - Shirt) vs 40753.png (6 - Shirt), Similitud: 0.9827
# 	20679.png (6 - Shirt) vs 57724.png (6 - Shirt), Similitud: 0.9827
# 	3350.png (6 - Shirt) vs 53657.png (6 - Shirt), Similitud: 0.9781
# 	1756.png (6 - Shirt) vs 56506.png (6 - Shirt), Similitud: 0.9756
# 	12109.png (6 - Shirt) vs 5931.png (6 - Shirt), Similitud: 0.9730
# 	56744.png (6 - Shirt) vs 29705.png (6 - Shirt), Similitud: 0.9724
# 	49469.png (6 - Shirt) vs 57696.png (6 - Shirt), Similitud: 0.9721
# 	6861.png (6 - Shirt) vs 10210.png (6 - Shirt), Similitud: 0.9686
# 	5961.png (6 - Shirt) vs 57577.png (6 - Shirt), Similitud: 0.9683
# 	26276.png (6 - Shirt) vs 24438.png (6 - Shirt), Similitud: 0.9672
# 	57724.png (6 - Shirt) vs 32754.png (6 - Shirt), Similitud: 0.9663
# 	35777.png (6 - Shirt) vs 57237.png (6 - Shirt), Similitud: 0.9662
# 	4382.png (6 - Shirt) vs 26920.png (6 - Shirt), Similitud: 0.9660
# 	57724.png (6 - Shirt) vs 31836.png (6 - Shirt), Similitud: 0.9657
# 	28493.png (6 - Shirt) vs 12967.png (6 - Shirt), Similitud: 0.9653
# 	28208.png (6 - Shirt) vs 12611.png (6 - Shirt), Similitud: 0.9651
#
# Muestras más representativas de esta clase:
# 	#1: 57724.png con 3 apariciones
# 	#2: 31836.png con 2 apariciones
# 	#3: 32754.png con 2 apariciones
# 	#4: 31038.png con 1 apariciones
# 	#5: 5453.png con 1 apariciones
# 	#6: 51488.png con 1 apariciones
# 	#7: 11932.png con 1 apariciones
# 	#8: 13618.png con 1 apariciones
# 	#9: 29645.png con 1 apariciones
# 	#10: 44342.png con 1 apariciones
#
#
# Clase: 7 - Sneaker
# Forma de la matriz de la clase 7 - Sneaker: (6000, 6000)
# 	59812.png (7 - Sneaker) vs 45497.png (7 - Sneaker), Similitud: 0.9889
# 	52412.png (7 - Sneaker) vs 7963.png (7 - Sneaker), Similitud: 0.9592
# 	12888.png (7 - Sneaker) vs 46106.png (7 - Sneaker), Similitud: 0.9520
# 	17112.png (7 - Sneaker) vs 29916.png (7 - Sneaker), Similitud: 0.9472
# 	49994.png (7 - Sneaker) vs 47200.png (7 - Sneaker), Similitud: 0.9467
# 	15862.png (7 - Sneaker) vs 32407.png (7 - Sneaker), Similitud: 0.9457
# 	17264.png (7 - Sneaker) vs 8498.png (7 - Sneaker), Similitud: 0.9421
# 	47454.png (7 - Sneaker) vs 38136.png (7 - Sneaker), Similitud: 0.9419
# 	14947.png (7 - Sneaker) vs 22390.png (7 - Sneaker), Similitud: 0.9418
# 	29387.png (7 - Sneaker) vs 38441.png (7 - Sneaker), Similitud: 0.9396
# 	20460.png (7 - Sneaker) vs 15133.png (7 - Sneaker), Similitud: 0.9396
# 	48793.png (7 - Sneaker) vs 729.png (7 - Sneaker), Similitud: 0.9395
# 	3280.png (7 - Sneaker) vs 21803.png (7 - Sneaker), Similitud: 0.9393
# 	50336.png (7 - Sneaker) vs 9714.png (7 - Sneaker), Similitud: 0.9380
# 	22390.png (7 - Sneaker) vs 5756.png (7 - Sneaker), Similitud: 0.9376
# 	1501.png (7 - Sneaker) vs 48981.png (7 - Sneaker), Similitud: 0.9364
# 	20197.png (7 - Sneaker) vs 34470.png (7 - Sneaker), Similitud: 0.9358
# 	18798.png (7 - Sneaker) vs 30988.png (7 - Sneaker), Similitud: 0.9358
# 	2824.png (7 - Sneaker) vs 28302.png (7 - Sneaker), Similitud: 0.9355
# 	23777.png (7 - Sneaker) vs 5089.png (7 - Sneaker), Similitud: 0.9354
#
# Muestras más representativas de esta clase:
# 	#1: 22390.png con 2 apariciones
# 	#2: 59812.png con 1 apariciones
# 	#3: 45497.png con 1 apariciones
# 	#4: 52412.png con 1 apariciones
# 	#5: 7963.png con 1 apariciones
# 	#6: 12888.png con 1 apariciones
# 	#7: 46106.png con 1 apariciones
# 	#8: 17112.png con 1 apariciones
# 	#9: 29916.png con 1 apariciones
# 	#10: 49994.png con 1 apariciones
#
#
# Clase: 8 - Bag
# Forma de la matriz de la clase 8 - Bag: (6000, 6000)
# 	5503.png (8 - Bag) vs 28024.png (8 - Bag), Similitud: 0.9814
# 	13377.png (8 - Bag) vs 7226.png (8 - Bag), Similitud: 0.9672
# 	13764.png (8 - Bag) vs 20936.png (8 - Bag), Similitud: 0.9671
# 	48581.png (8 - Bag) vs 53410.png (8 - Bag), Similitud: 0.9665
# 	4902.png (8 - Bag) vs 16907.png (8 - Bag), Similitud: 0.9658
# 	18816.png (8 - Bag) vs 39864.png (8 - Bag), Similitud: 0.9649
# 	27796.png (8 - Bag) vs 59391.png (8 - Bag), Similitud: 0.9649
# 	42526.png (8 - Bag) vs 23447.png (8 - Bag), Similitud: 0.9633
# 	28928.png (8 - Bag) vs 47768.png (8 - Bag), Similitud: 0.9630
# 	46138.png (8 - Bag) vs 7855.png (8 - Bag), Similitud: 0.9619
# 	43460.png (8 - Bag) vs 29426.png (8 - Bag), Similitud: 0.9614
# 	17275.png (8 - Bag) vs 45385.png (8 - Bag), Similitud: 0.9612
# 	19976.png (8 - Bag) vs 11929.png (8 - Bag), Similitud: 0.9612
# 	5164.png (8 - Bag) vs 17947.png (8 - Bag), Similitud: 0.9604
# 	4348.png (8 - Bag) vs 53762.png (8 - Bag), Similitud: 0.9602
# 	45489.png (8 - Bag) vs 16089.png (8 - Bag), Similitud: 0.9579
# 	50023.png (8 - Bag) vs 34833.png (8 - Bag), Similitud: 0.9574
# 	6913.png (8 - Bag) vs 27005.png (8 - Bag), Similitud: 0.9574
# 	7226.png (8 - Bag) vs 48581.png (8 - Bag), Similitud: 0.9572
# 	14744.png (8 - Bag) vs 43541.png (8 - Bag), Similitud: 0.9556
#
# Muestras más representativas de esta clase:
# 	#1: 7226.png con 2 apariciones
# 	#2: 48581.png con 2 apariciones
# 	#3: 5503.png con 1 apariciones
# 	#4: 28024.png con 1 apariciones
# 	#5: 13377.png con 1 apariciones
# 	#6: 13764.png con 1 apariciones
# 	#7: 20936.png con 1 apariciones
# 	#8: 53410.png con 1 apariciones
# 	#9: 4902.png con 1 apariciones
# 	#10: 16907.png con 1 apariciones
#
#
# Clase: 9 - Ankle boot
# Forma de la matriz de la clase 9 - Ankle boot: (6000, 6000)
# 	40857.png (9 - Ankle boot) vs 38331.png (9 - Ankle boot), Similitud: 0.9583
# 	42090.png (9 - Ankle boot) vs 295.png (9 - Ankle boot), Similitud: 0.9563
# 	43733.png (9 - Ankle boot) vs 13491.png (9 - Ankle boot), Similitud: 0.9554
# 	41891.png (9 - Ankle boot) vs 55804.png (9 - Ankle boot), Similitud: 0.9532
# 	31616.png (9 - Ankle boot) vs 51773.png (9 - Ankle boot), Similitud: 0.9521
# 	18212.png (9 - Ankle boot) vs 12322.png (9 - Ankle boot), Similitud: 0.9512
# 	23409.png (9 - Ankle boot) vs 51313.png (9 - Ankle boot), Similitud: 0.9509
# 	39866.png (9 - Ankle boot) vs 6740.png (9 - Ankle boot), Similitud: 0.9503
# 	31114.png (9 - Ankle boot) vs 51773.png (9 - Ankle boot), Similitud: 0.9503
# 	23409.png (9 - Ankle boot) vs 34891.png (9 - Ankle boot), Similitud: 0.9499
# 	57494.png (9 - Ankle boot) vs 10237.png (9 - Ankle boot), Similitud: 0.9498
# 	48298.png (9 - Ankle boot) vs 9992.png (9 - Ankle boot), Similitud: 0.9492
# 	18033.png (9 - Ankle boot) vs 7905.png (9 - Ankle boot), Similitud: 0.9488
# 	34311.png (9 - Ankle boot) vs 35184.png (9 - Ankle boot), Similitud: 0.9486
# 	39736.png (9 - Ankle boot) vs 36652.png (9 - Ankle boot), Similitud: 0.9481
# 	39325.png (9 - Ankle boot) vs 25272.png (9 - Ankle boot), Similitud: 0.9480
# 	50549.png (9 - Ankle boot) vs 45047.png (9 - Ankle boot), Similitud: 0.9479
# 	51199.png (9 - Ankle boot) vs 59765.png (9 - Ankle boot), Similitud: 0.9478
# 	47905.png (9 - Ankle boot) vs 45047.png (9 - Ankle boot), Similitud: 0.9476
# 	32181.png (9 - Ankle boot) vs 10285.png (9 - Ankle boot), Similitud: 0.9475
#
# Muestras más representativas de esta clase:
# 	#1: 51773.png con 2 apariciones
# 	#2: 23409.png con 2 apariciones
# 	#3: 45047.png con 2 apariciones
# 	#4: 40857.png con 1 apariciones
# 	#5: 38331.png con 1 apariciones
# 	#6: 42090.png con 1 apariciones
# 	#7: 295.png con 1 apariciones
# 	#8: 43733.png con 1 apariciones
# 	#9: 13491.png con 1 apariciones
# 	#10: 41891.png con 1 apariciones

# %%
# Función para encontrar y mostrar las imágenes más similares usando la matriz M  
def show_most_similar_using_M(estimator, filenames_dict):  
    images_to_show = []  # Lista para almacenar las imágenes y sus detalles  

    # Obtener la matriz de similitud global (M)  
    M = estimator.M  

    # Imprimir la forma de la matriz de similitud  
    print(f"Forma de la matriz M: {M.shape}")  

    # Ordenar los índices según las similitudes (de mayor a menor)  
    most_similar_indices = np.argsort(-M, axis=None)  # El signo negativo invierte el orden  

    shown_pairs = set()  # Para rastrear los pares de índices ya mostrados  
    count = 0  
    show_samples = 20  # Número de muestras para visualizar la similitud  

    # Diccionario para contar la participación de cada imagen  
    participation_count = {}  

    for idx in most_similar_indices:  
        if count >= show_samples:  
            break  

        # Convertir el índice plano a índice 2D  
        idx_2d = np.unravel_index(idx, M.shape)  

        # Saltar las comparaciones de una muestra consigo misma  
        if idx_2d[0] == idx_2d[1]:  
            continue  

        # Crear un par ordenado de índices para prevenir duplicados  
        index_pair = tuple(sorted((idx_2d[0], idx_2d[1])))  

        # Verificamos si el par ya fue mostrado  
        if index_pair in shown_pairs:  
            continue  

        shown_pairs.add(index_pair)  

        # Actualizar el conteo de participación  
        participation_count[idx_2d[0]] = participation_count.get(idx_2d[0], 0) + 1  
        participation_count[idx_2d[1]] = participation_count.get(idx_2d[1], 0) + 1  

        # Verificar que los índices estén dentro de los límites del dataset  
        if idx_2d[0] < len(filenames_dict) and idx_2d[1] < len(filenames_dict):  
            source_filename = Path(filenames_dict[int(idx_2d[0])])  
            target_filename = Path(filenames_dict[int(idx_2d[1])])  

            value = M[idx_2d]  

            # Formatear y mostrar la salida  
            print(f"{source_filename.name} vs {target_filename.name}, Similitud: {value:.4f}")  

            # Agrega los detalles a la lista para visualización  
            images_to_show.append((source_filename, target_filename, value))  

            count += 1  

    # Encontrar las muestras más frecuentes en los pares más similares  
    most_frequent = sorted(participation_count.items(), key=lambda x: -x[1])  

    # Mostrar las 10 imágenes más frecuentes  
    print("\nMuestras más frecuentes en los pares más similares del dataset:")  
    for rank, (img_idx, freq) in enumerate(most_frequent[:10], 1):  
        img_name = Path(filenames_dict[int(img_idx)]).name  
        print(f"\t#{rank}: {img_name} con {freq} apariciones")  
    print("\n")  

    # Luego, realiza la visualización de las imágenes  
    for source_filename, target_filename, value in images_to_show:  
        img_source = plt.imread(source_filename)  
        img_target = plt.imread(target_filename)  

        fig, axs = plt.subplots(1, 2, figsize=(5, 3))  
        axs[0].imshow(img_source)  
        axs[0].set_title(f"{source_filename.name}", fontsize=8)  
        axs[0].axis('off')  # Elimina los ejes para centrar la atención en la imagen  

        axs[1].imshow(img_target)  
        axs[1].set_title(f"{target_filename.name}", fontsize=8)  
        axs[1].axis('off')  
        plt.suptitle(f"Similarity: {value:.4f}")  
        plt.subplots_adjust(wspace=0.3, hspace=0.3)  # Ajusta el espacio entre subtramas  
        plt.show()  


print("Muestras más similares entre todas las imágenes del dataset \n")  
show_most_similar_using_M(estimator, filenames_dict)
# Out:
# Muestras más similares entre todas las imágenes del dataset
#
# Forma de la matriz M: (60000, 60000)
# 29413.png vs 43549.png, Similitud: 0.9981
# 5453.png vs 31038.png, Similitud: 0.9981
# 43549.png vs 753.png, Similitud: 0.9978
# 29413.png vs 753.png, Similitud: 0.9978
# 21295.png vs 43549.png, Similitud: 0.9973
# 32754.png vs 31836.png, Similitud: 0.9972
# 56201.png vs 31061.png, Similitud: 0.9971
# 21295.png vs 29413.png, Similitud: 0.9968
# 10205.png vs 23412.png, Similitud: 0.9967
# 51503.png vs 56201.png, Similitud: 0.9962
# 753.png vs 21295.png, Similitud: 0.9960
# 50759.png vs 12981.png, Similitud: 0.9959
# 51488.png vs 11932.png, Similitud: 0.9953
# 31061.png vs 51503.png, Similitud: 0.9947
# 32140.png vs 39882.png, Similitud: 0.9946
# 567.png vs 47750.png, Similitud: 0.9943
# 56004.png vs 58762.png, Similitud: 0.9940
# 20554.png vs 36357.png, Similitud: 0.9938
# 5081.png vs 9664.png, Similitud: 0.9920
# 54953.png vs 46517.png, Similitud: 0.9912
#
# Muestras más frecuentes en los pares más similares del dataset:
# 	#1: 29413.png con 3 apariciones
# 	#2: 43549.png con 3 apariciones
# 	#3: 753.png con 3 apariciones
# 	#4: 21295.png con 3 apariciones
# 	#5: 56201.png con 2 apariciones
# 	#6: 31061.png con 2 apariciones
# 	#7: 51503.png con 2 apariciones
# 	#8: 5453.png con 1 apariciones
# 	#9: 31038.png con 1 apariciones
# 	#10: 32754.png con 1 apariciones
