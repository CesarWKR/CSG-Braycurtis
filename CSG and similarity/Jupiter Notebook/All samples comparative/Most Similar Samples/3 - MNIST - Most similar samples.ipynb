# %% [markdown]
# # Librerias

# %%
# Carga de librerías
import numpy as np
import tensorflow as tf
import PIL
import PIL.Image
import pathlib
import scipy as sp
import seaborn as sns
from itertools import product
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
import os
import pathlib
from pathlib import Path

# %%
import pickle
import sys
from pathlib import Path

from numpy.linalg import LinAlgError
from scipy.sparse.csgraph import laplacian
from new_spectral_metric.new_estimator_all_samples import CumulativeGradientEstimator_All_samples
from new_spectral_metric.new_visualize import make_graph
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Conv2D, Dense, MaxPooling2D, Lambda
from tensorflow.keras import backend as K
from pathlib import Path
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from matplotlib.collections import LineCollection
from matplotlib.font_manager import FontProperties
from pathlib import Path

# %% [markdown]
# # DATASET DESDE DIRECTORIO

# %%
#Lectura de dataset

directorio_dataset = ('../../../Datasets/MNIST')
directorio_dataset = pathlib.Path(directorio_dataset)

# Lectura de la carpeta train
directorio_train = ('../../../Datasets/MNIST/train')
directorio_train = pathlib.Path(directorio_train)

# Lectura de la carpeta test
directorio_test = ('../../../Datasets/MNIST/test')
directorio_test = pathlib.Path(directorio_test)

total_dataset = len(list(directorio_dataset.glob('*/*/*.png')))  # Cuenta la cantidad de imagenes del dataset (Aqui busca en las subcarpetas del directorio del dataset)
total_train = len(list(directorio_train.glob('*/*.png')))  # Cuenta la cantidad de imagenes de train
total_test = len(list(directorio_test.glob('*/*.png')))  # Cuenta la cantidad de imagenes de test

print(f"Total imagenes dataset: {total_dataset}")
print(f"Total imagenes train: {total_train}")
print(f"Total imagenes test: {total_test}")
# Out:
# Total imagenes dataset: 70000
# Total imagenes train: 60000
# Total imagenes test: 10000

# %%
# Definir el batchsize del dataset completo
batch_size_total = total_dataset

# %%
# Dimensiones de imagen y tamaño de batch en train
img_height = 28
img_width = 28
#batch_size = 32
batch_size_train = total_train

# %%
import tensorflow as tf
import pathlib

# Data splitting (entrenamiento y validación)
train_images = tf.keras.preprocessing.image_dataset_from_directory(
  directorio_train,
  #validation_split=0.2,
  color_mode='rgb',
  label_mode='int',
  #subset="training",
  #seed=123,
  shuffle=False,
  image_size=(img_height, img_width),
  batch_size=batch_size_train)
# Out:
# Found 60000 files belonging to 10 classes.

# %%
# Dimensiones de imagen y tamaño de batch en test
img_height = 28
img_width = 28
#batch_size = 32
batch_size_test = total_test

# %%
# Data splitting (entrenamiento y validación)
test_images = tf.keras.preprocessing.image_dataset_from_directory(
  directorio_test,
  #validation_split=0.2,
  color_mode='rgb',
  label_mode='int',
  #subset="training",
  #seed=123,
  shuffle=False,
  image_size=(img_height, img_width),
  batch_size=batch_size_test)
# Out:
# Found 10000 files belonging to 10 classes.

# %%
# Contar el total de imágenes por clase en train y test  
class_counts_total = {p.name: len(list(p.glob('*.png'))) for p in directorio_dataset.glob('*/*')}  
class_counts_train = {p.name: len(list(p.glob('*.png'))) for p in directorio_train.glob('*')}  
class_counts_test = {p.name: len(list(p.glob('*.png'))) for p in directorio_test.glob('*')}  

# Encontrar el valor más bajo de imágenes por clase en train  
menor_train = min(class_counts_train.values()) if class_counts_train else None  # Se almacena el valor de la clase que menos muestras tiene

# Encontrar el valor más alto de imágenes por clase en train  
mayor_train = max(class_counts_train.values()) if class_counts_train else None  # Se almacena el valor de la clase que mas muestras tiene


# Encontrar el valor más bajo de imágenes por clase en test  
menor_test = min(class_counts_test.values()) if class_counts_test else None  # Se almacena el valor de la clase que menos muestras tiene

# Encontrar el valor más alto de imágenes por clase en test  
mayor_test = max(class_counts_test.values()) if class_counts_test else None  # Se almacena el valor de la clase que mas muestras tiene


# Mostrar el total de imágenes por clase en train  
print("\nTotal images per class in train:")  
for class_name, count in class_counts_train.items():  
    print(f"Class: {class_name}, Number of images: {count}")  
print(f"Total images train: {sum(class_counts_train.values())}")  

# Mostrar el valor más bajo en train  
print(f"Fewer number of images in train: {menor_train}")  

# Mostrar el valor más alto en train  
print(f"Higher number of images in train: {mayor_train}")  

# Mostrar el total de imágenes por clase en test  
print("\nTotal images per class in test:")  
for class_name, count in class_counts_test.items():  
    print(f"Class: {class_name}, Number of images: {count}")  
print(f"Total images test: {sum(class_counts_test.values())}")  

# Mostrar el valor más bajo en test  
print(f"Fewer images in test: {menor_test}")

# Mostrar el valor más alto en test  
print(f"Higher number of images in test: {mayor_test}")
# Out:
# Total images per class in train:
# Class: 0_train, Number of images: 5923
# Class: 1_train, Number of images: 6742
# Class: 2_train, Number of images: 5958
# Class: 3_train, Number of images: 6131
# Class: 4_train, Number of images: 5842
# Class: 5_train, Number of images: 5421
# Class: 6_train, Number of images: 5918
# Class: 7_train, Number of images: 6265
# Class: 8_train, Number of images: 5851
# Class: 9_train, Number of images: 5949
# Total images train: 60000
# Fewer number of images in train: 5421
# Higher number of images in train: 6742
#
# Total images per class in test:
# Class: 0_test, Number of images: 980
# Class: 1_test, Number of images: 1135
# Class: 2_test, Number of images: 1032
# Class: 3_test, Number of images: 1010
# Class: 4_test, Number of images: 982
# Class: 5_test, Number of images: 892
# Class: 6_test, Number of images: 958
# Class: 7_test, Number of images: 1028
# Class: 8_test, Number of images: 974
# Class: 9_test, Number of images: 1009
# Total images test: 10000
# Fewer images in test: 892
# Higher number of images in test: 1135

# %%
# Nombres de las clases
class_names_train = list(class_counts_train.keys())
class_names_test = list(class_counts_test.keys())
#class_names_total = sorted(list(set(class_names_train + class_names_test)))
class_names_total = list(class_counts_total.keys())

# Mostrar el número de clases y los nombres
print(f"\nNúmero de clases en train: {len(class_names_train)}")
print(f"Nombres de las clases en train: {class_names_train}")

print(f"\nNúmero de clases en test: {len(class_names_test)}")
print(f"Nombres de las clases en test: {class_names_test}")

print(f"\nNúmero total de clases en el dataset: {len(class_names_total)}")   # Este valor cambia si el nombre de las clases es diferente
print(f"Nombres de todas las clases en el dataset: {class_names_total}")     # Este valor tambien cambia si el nombre de las clases es diferente
# Out:
# Número de clases en train: 10
# Nombres de las clases en train: ['0_train', '1_train', '2_train', '3_train', '4_train', '5_train', '6_train', '7_train', '8_train', '9_train']
#
# Número de clases en test: 10
# Nombres de las clases en test: ['0_test', '1_test', '2_test', '3_test', '4_test', '5_test', '6_test', '7_test', '8_test', '9_test']
#
# Número total de clases en el dataset: 20
# Nombres de todas las clases en el dataset: ['0_test', '1_test', '2_test', '3_test', '4_test', '5_test', '6_test', '7_test', '8_test', '9_test', '0_train', '1_train', '2_train', '3_train', '4_train', '5_train', '6_train', '7_train', '8_train', '9_train']

# %%
for images, labels0 in train_images.take(1):  # only take first element of dataset
    numpy_all_images = images.numpy()  # convertir el tensor de imágenes en un arreglo de numpy y ahora contiene las imágenes del conjunto de datos en formato de numpy.
    numpy_all_labels = labels0.numpy()  # convierte el tensor de etiquetas en un arreglo de numpy y ahora contiene las etiquetas del conjunto de datos en formato de numpy

numpy_all_images /= 255.0  # Scale the features to the [0, 1] range
print(numpy_all_images.shape)

# CIFAR-10 
fully_dataset_train = numpy_all_images.reshape((numpy_all_images.shape[0], numpy_all_images.shape[1]*numpy_all_images.shape[2]*numpy_all_images.shape[3])) # es un arreglo bidimensional donde cada fila representa una imagen y cada columna representa un píxel de la imagen
fully_labels_train = numpy_all_labels.reshape(numpy_all_labels.shape[0],)
# Out:
# (60000, 28, 28, 3)

# %% [markdown]
# # Dataset complexity using CSG

# %%
estimator = CumulativeGradientEstimator(M_sample=mayor_train, k_nearest=10)  # Utiliza el numero menor de muestras encontrado en cada clase dependiendo si es train o test
estimator.fit(data=fully_dataset_train, target=fully_labels_train)
csg = estimator.csg  # The actual complexity values.
estimator.evals, estimator.evecs  # The eigenvalues and vectors.

make_graph(estimator.difference, title="Dataset Complexity - MNIST: "+str(csg), classes=class_names_train)
# Out:
# c:\Users\Cesar\AppData\Local\Programs\Python\Python312\Lib\site-packages\new_spectral_metric\new_visualize.py:48: RuntimeWarning: divide by zero encountered in divide
#   similarities = difference.max() / difference * 100
# c:\Users\Cesar\AppData\Local\Programs\Python\Python312\Lib\site-packages\new_spectral_metric\new_visualize.py:59: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# # Calcular la similitud entre clases

# %%
from scipy.stats import entropy  
import pandas as pd  

# Calcular la entropía por clase  
entropy_per_class = entropy(estimator.W / estimator.W.sum(-1)[:, None], axis=-1)  

# Encontrar la clase más confusa (mayor entropía)  
most_confused_class_index = np.argmax(entropy_per_class)  
most_confused_class_name = class_names_train[most_confused_class_index]  

print("Class that is the most confused (highest entropy):", most_confused_class_name)
# Out:
# Class that is the most confused (highest entropy): 8_train

# %%
# Obtener los índices de los pares más similares  
pairs = list(zip(*np.unravel_index(np.argsort(estimator.W, axis=None)[::-1], estimator.W.shape)))  

# Filtrar pares donde i != j para evitar pares de la misma clase  
pairs = [(i, j) for i, j in pairs if i != j]  

print("Most similar pairs")  
lst = []  
seen_pairs = set()  

# Iterar sobre los primeros 10 pares más similares  
for i, j in pairs:  
    # Verificar si el par o su inverso ya ha sido visto  
    if (i, j) not in seen_pairs and (j, i) not in seen_pairs:  
        lst.append({"Intent pair": f"{class_names_train[i]} <> {class_names_train[j]}", "Similarity": estimator.W[i, j]})  
        seen_pairs.add((i, j))  
        seen_pairs.add((j, i))  
    
    # Detenerse después de encontrar 10 pares únicos  
    if len(lst) == 10:  
        break  

# Mostrar los resultados en un DataFrame  
print(pd.DataFrame(lst))
# Out:
# Most similar pairs
#           Intent pair  Similarity
# 0  5_train <> 8_train    0.084808
# 1  8_train <> 3_train    0.082364
# 2  9_train <> 4_train    0.076482
# 3  5_train <> 3_train    0.069904
# 4  9_train <> 7_train    0.054757
# 5  8_train <> 9_train    0.050559
# 6  2_train <> 8_train    0.050217
# 7  4_train <> 8_train    0.045376
# 8  8_train <> 7_train    0.044588
# 9  9_train <> 2_train    0.043102

# %% [markdown]
# # Obtener los nombres de las imagenes en train o test (dependiendo de lo que se quiera probar)

# %%
# Obtener todos los nombres de archivo en el dataset
filenames = [str(f) for f in directorio_train.glob('*/*.png')]

# Crear un mapeo de índices a rutas completas de archivo  
filenames_dict = {i: str(f) for i, f in enumerate(directorio_train.glob('*/*.png'))}

# %% [markdown]
# # Calcular la similitud entre muestras

# %%
# Función para encontrar y mostrar las imágenes más similares usando la matriz M  
def show_most_similar_using_M(estimator, filenames_dict):  
    images_to_show = []  # Lista para almacenar las imágenes y sus detalles  

    # Obtener la matriz de similitud global (M)  
    M = estimator.M  

    # Imprimir la forma de la matriz de similitud  
    print(f"Forma de la matriz M: {M.shape}")  

    # Ordenar los índices según las similitudes (de mayor a menor)  
    most_similar_indices = np.argsort(-M, axis=None)  # El signo negativo invierte el orden  

    shown_pairs = set()  # Para rastrear los pares de índices ya mostrados  
    count = 0  
    show_samples = 20  # Número de muestras para visualizar la similitud  

    # Diccionario para contar la participación de cada imagen  
    participation_count = {}  

    for idx in most_similar_indices:  
        if count >= show_samples:  
            break  

        # Convertir el índice plano a índice 2D  
        idx_2d = np.unravel_index(idx, M.shape)  

        # Saltar las comparaciones de una muestra consigo misma  
        if idx_2d[0] == idx_2d[1]:  
            continue  

        # Crear un par ordenado de índices para prevenir duplicados  
        index_pair = tuple(sorted((idx_2d[0], idx_2d[1])))  

        # Verificamos si el par ya fue mostrado  
        if index_pair in shown_pairs:  
            continue  

        shown_pairs.add(index_pair)  

        # Actualizar el conteo de participación  
        participation_count[idx_2d[0]] = participation_count.get(idx_2d[0], 0) + 1  
        participation_count[idx_2d[1]] = participation_count.get(idx_2d[1], 0) + 1  

        # Verificar que los índices estén dentro de los límites del dataset  
        if idx_2d[0] < len(filenames_dict) and idx_2d[1] < len(filenames_dict):  
            source_filename = Path(filenames_dict[int(idx_2d[0])])  
            target_filename = Path(filenames_dict[int(idx_2d[1])])  

            value = M[idx_2d]  

            # Formatear y mostrar la salida  
            print(f"{source_filename.name} vs {target_filename.name}, Similitud: {value:.4f}")  

            # Agrega los detalles a la lista para visualización  
            images_to_show.append((source_filename, target_filename, value))  

            count += 1  

    # Encontrar las muestras más frecuentes en los pares más similares  
    most_frequent = sorted(participation_count.items(), key=lambda x: -x[1])  

    # Mostrar las 10 imágenes más frecuentes  
    print("\nMuestras más frecuentes en los pares más similares del dataset:")  
    for rank, (img_idx, freq) in enumerate(most_frequent[:10], 1):  
        img_name = Path(filenames_dict[int(img_idx)]).name  
        print(f"\t#{rank}: {img_name} con {freq} apariciones")  
    print("\n")  

    # Luego, realiza la visualización de las imágenes  
    for source_filename, target_filename, value in images_to_show:  
        img_source = plt.imread(source_filename)  
        img_target = plt.imread(target_filename)  

        fig, axs = plt.subplots(1, 2, figsize=(5, 3))  
        axs[0].imshow(img_source)  
        axs[0].set_title(f"{source_filename.name}", fontsize=8)  
        axs[0].axis('off')  # Elimina los ejes para centrar la atención en la imagen  

        axs[1].imshow(img_target)  
        axs[1].set_title(f"{target_filename.name}", fontsize=8)  
        axs[1].axis('off')  
        plt.suptitle(f"Similarity: {value:.4f}")  
        plt.subplots_adjust(wspace=0.3, hspace=0.3)  # Ajusta el espacio entre subtramas  
        plt.show()  


print("Muestras más similares entre todas las imágenes del dataset \n")  
show_most_similar_using_M(estimator, filenames_dict)
# Out:
# Muestras más similares entre las imágenes de la misma clase
#
# Clase: 0_train
# Forma de la matriz de la clase 0_train: (5923, 5923)
# 	743.png (0_train) vs 781.png (0_train), Similitud: 0.9469
# 	28041.png (0_train) vs 28125.png (0_train), Similitud: 0.9382
# 	36667.png (0_train) vs 36741.png (0_train), Similitud: 0.9285
# 	10203.png (0_train) vs 10283.png (0_train), Similitud: 0.9275
# 	13081.png (0_train) vs 13077.png (0_train), Similitud: 0.9261
# 	6337.png (0_train) vs 11683.png (0_train), Similitud: 0.9256
# 	25051.png (0_train) vs 19583.png (0_train), Similitud: 0.9223
# 	30891.png (0_train) vs 37841.png (0_train), Similitud: 0.9214
# 	34553.png (0_train) vs 21521.png (0_train), Similitud: 0.9210
# 	1359.png (0_train) vs 1195.png (0_train), Similitud: 0.9204
# 	47923.png (0_train) vs 47917.png (0_train), Similitud: 0.9198
# 	19491.png (0_train) vs 21907.png (0_train), Similitud: 0.9198
# 	47887.png (0_train) vs 24809.png (0_train), Similitud: 0.9195
# 	949.png (0_train) vs 34054.png (0_train), Similitud: 0.9194
# 	5961.png (0_train) vs 45061.png (0_train), Similitud: 0.9193
# 	29405.png (0_train) vs 29421.png (0_train), Similitud: 0.9190
# 	36829.png (0_train) vs 29477.png (0_train), Similitud: 0.9190
# 	55617.png (0_train) vs 48607.png (0_train), Similitud: 0.9183
# 	55806.png (0_train) vs 50929.png (0_train), Similitud: 0.9178
# 	39207.png (0_train) vs 10323.png (0_train), Similitud: 0.9171
#
# Muestras más representativas de esta clase:
# 	#1: 743.png con 1 apariciones
# 	#2: 781.png con 1 apariciones
# 	#3: 28041.png con 1 apariciones
# 	#4: 28125.png con 1 apariciones
# 	#5: 36667.png con 1 apariciones
# 	#6: 36741.png con 1 apariciones
# 	#7: 10203.png con 1 apariciones
# 	#8: 10283.png con 1 apariciones
# 	#9: 13081.png con 1 apariciones
# 	#10: 13077.png con 1 apariciones
#
#
# Clase: 1_train
# Forma de la matriz de la clase 1_train: (6742, 6742)
# 	39152.png (1_train) vs 40971.png (1_train), Similitud: 0.9646
# 	27111.png (1_train) vs 51603.png (1_train), Similitud: 0.9588
# 	27242.png (1_train) vs 54417.png (1_train), Similitud: 0.9557
# 	58052.png (1_train) vs 4467.png (1_train), Similitud: 0.9555
# 	15722.png (1_train) vs 30368.png (1_train), Similitud: 0.9544
# 	59692.png (1_train) vs 29337.png (1_train), Similitud: 0.9543
# 	36509.png (1_train) vs 18863.png (1_train), Similitud: 0.9531
# 	45730.png (1_train) vs 33850.png (1_train), Similitud: 0.9528
# 	48044.png (1_train) vs 34980.png (1_train), Similitud: 0.9525
# 	11622.png (1_train) vs 36315.png (1_train), Similitud: 0.9524
# 	14859.png (1_train) vs 45373.png (1_train), Similitud: 0.9524
# 	28521.png (1_train) vs 17812.png (1_train), Similitud: 0.9508
# 	47709.png (1_train) vs 44454.png (1_train), Similitud: 0.9507
# 	28350.png (1_train) vs 37674.png (1_train), Similitud: 0.9506
# 	24707.png (1_train) vs 43151.png (1_train), Similitud: 0.9504
# 	45092.png (1_train) vs 56338.png (1_train), Similitud: 0.9496
# 	2645.png (1_train) vs 31993.png (1_train), Similitud: 0.9490
# 	39684.png (1_train) vs 13892.png (1_train), Similitud: 0.9487
# 	21847.png (1_train) vs 44453.png (1_train), Similitud: 0.9484
# 	10365.png (1_train) vs 49811.png (1_train), Similitud: 0.9484
#
# Muestras más representativas de esta clase:
# 	#1: 39152.png con 1 apariciones
# 	#2: 40971.png con 1 apariciones
# 	#3: 27111.png con 1 apariciones
# 	#4: 51603.png con 1 apariciones
# 	#5: 27242.png con 1 apariciones
# 	#6: 54417.png con 1 apariciones
# 	#7: 58052.png con 1 apariciones
# 	#8: 4467.png con 1 apariciones
# 	#9: 15722.png con 1 apariciones
# 	#10: 30368.png con 1 apariciones
#
#
# Clase: 2_train
# Forma de la matriz de la clase 2_train: (5958, 5958)
# 	19132.png (2_train) vs 42394.png (2_train), Similitud: 0.9049
# 	19653.png (2_train) vs 28021.png (2_train), Similitud: 0.8986
# 	30802.png (2_train) vs 40988.png (2_train), Similitud: 0.8985
# 	28369.png (2_train) vs 28407.png (2_train), Similitud: 0.8972
# 	55637.png (2_train) vs 23231.png (2_train), Similitud: 0.8964
# 	9722.png (2_train) vs 32768.png (2_train), Similitud: 0.8949
# 	19693.png (2_train) vs 5076.png (2_train), Similitud: 0.8943
# 	47650.png (2_train) vs 28013.png (2_train), Similitud: 0.8939
# 	27464.png (2_train) vs 57966.png (2_train), Similitud: 0.8922
# 	50105.png (2_train) vs 50271.png (2_train), Similitud: 0.8918
# 	17110.png (2_train) vs 6204.png (2_train), Similitud: 0.8906
# 	27935.png (2_train) vs 28021.png (2_train), Similitud: 0.8889
# 	56335.png (2_train) vs 2017.png (2_train), Similitud: 0.8883
# 	30443.png (2_train) vs 30561.png (2_train), Similitud: 0.8879
# 	32317.png (2_train) vs 32361.png (2_train), Similitud: 0.8872
# 	28013.png (2_train) vs 23564.png (2_train), Similitud: 0.8865
# 	37145.png (2_train) vs 5965.png (2_train), Similitud: 0.8854
# 	6204.png (2_train) vs 1550.png (2_train), Similitud: 0.8851
# 	28021.png (2_train) vs 28369.png (2_train), Similitud: 0.8833
# 	40037.png (2_train) vs 42159.png (2_train), Similitud: 0.8831
#
# Muestras más representativas de esta clase:
# 	#1: 28021.png con 3 apariciones
# 	#2: 28369.png con 2 apariciones
# 	#3: 28013.png con 2 apariciones
# 	#4: 6204.png con 2 apariciones
# 	#5: 19132.png con 1 apariciones
# 	#6: 42394.png con 1 apariciones
# 	#7: 19653.png con 1 apariciones
# 	#8: 30802.png con 1 apariciones
# 	#9: 40988.png con 1 apariciones
# 	#10: 28407.png con 1 apariciones
#
#
# Clase: 3_train
# Forma de la matriz de la clase 3_train: (6131, 6131)
# 	39125.png (3_train) vs 39061.png (3_train), Similitud: 0.8972
# 	34931.png (3_train) vs 32071.png (3_train), Similitud: 0.8968
# 	47821.png (3_train) vs 47975.png (3_train), Similitud: 0.8944
# 	42775.png (3_train) vs 5359.png (3_train), Similitud: 0.8938
# 	28111.png (3_train) vs 13417.png (3_train), Similitud: 0.8925
# 	20561.png (3_train) vs 12437.png (3_train), Similitud: 0.8921
# 	49324.png (3_train) vs 24442.png (3_train), Similitud: 0.8921
# 	18977.png (3_train) vs 58946.png (3_train), Similitud: 0.8916
# 	4674.png (3_train) vs 26364.png (3_train), Similitud: 0.8898
# 	5433.png (3_train) vs 215.png (3_train), Similitud: 0.8891
# 	46900.png (3_train) vs 17040.png (3_train), Similitud: 0.8870
# 	1185.png (3_train) vs 1233.png (3_train), Similitud: 0.8844
# 	8957.png (3_train) vs 20400.png (3_train), Similitud: 0.8842
# 	6071.png (3_train) vs 5987.png (3_train), Similitud: 0.8837
# 	39189.png (3_train) vs 19445.png (3_train), Similitud: 0.8832
# 	21524.png (3_train) vs 29300.png (3_train), Similitud: 0.8828
# 	1883.png (3_train) vs 14456.png (3_train), Similitud: 0.8827
# 	47979.png (3_train) vs 47913.png (3_train), Similitud: 0.8826
# 	8948.png (3_train) vs 33566.png (3_train), Similitud: 0.8825
# 	24635.png (3_train) vs 24787.png (3_train), Similitud: 0.8825
#
# Muestras más representativas de esta clase:
# 	#1: 39125.png con 1 apariciones
# 	#2: 39061.png con 1 apariciones
# 	#3: 34931.png con 1 apariciones
# 	#4: 32071.png con 1 apariciones
# 	#5: 47821.png con 1 apariciones
# 	#6: 47975.png con 1 apariciones
# 	#7: 42775.png con 1 apariciones
# 	#8: 5359.png con 1 apariciones
# 	#9: 28111.png con 1 apariciones
# 	#10: 13417.png con 1 apariciones
#
#
# Clase: 4_train
# Forma de la matriz de la clase 4_train: (5842, 5842)
# 	58.png (4_train) vs 56743.png (4_train), Similitud: 0.9152
# 	36502.png (4_train) vs 26456.png (4_train), Similitud: 0.9073
# 	20496.png (4_train) vs 56797.png (4_train), Similitud: 0.9009
# 	37221.png (4_train) vs 37087.png (4_train), Similitud: 0.8982
# 	8906.png (4_train) vs 25682.png (4_train), Similitud: 0.8980
# 	26352.png (4_train) vs 31378.png (4_train), Similitud: 0.8976
# 	3239.png (4_train) vs 54567.png (4_train), Similitud: 0.8956
# 	43812.png (4_train) vs 27040.png (4_train), Similitud: 0.8930
# 	38872.png (4_train) vs 9282.png (4_train), Similitud: 0.8917
# 	12033.png (4_train) vs 10789.png (4_train), Similitud: 0.8912
# 	36204.png (4_train) vs 21999.png (4_train), Similitud: 0.8911
# 	21875.png (4_train) vs 25293.png (4_train), Similitud: 0.8907
# 	47961.png (4_train) vs 47927.png (4_train), Similitud: 0.8906
# 	3222.png (4_train) vs 18233.png (4_train), Similitud: 0.8899
# 	36773.png (4_train) vs 8657.png (4_train), Similitud: 0.8897
# 	58.png (4_train) vs 59432.png (4_train), Similitud: 0.8897
# 	59432.png (4_train) vs 56743.png (4_train), Similitud: 0.8895
# 	24795.png (4_train) vs 24669.png (4_train), Similitud: 0.8879
# 	56799.png (4_train) vs 25361.png (4_train), Similitud: 0.8877
# 	8560.png (4_train) vs 32112.png (4_train), Similitud: 0.8877
#
# Muestras más representativas de esta clase:
# 	#1: 58.png con 2 apariciones
# 	#2: 56743.png con 2 apariciones
# 	#3: 59432.png con 2 apariciones
# 	#4: 36502.png con 1 apariciones
# 	#5: 26456.png con 1 apariciones
# 	#6: 20496.png con 1 apariciones
# 	#7: 56797.png con 1 apariciones
# 	#8: 37221.png con 1 apariciones
# 	#9: 37087.png con 1 apariciones
# 	#10: 8906.png con 1 apariciones
#
#
# Clase: 5_train
# Forma de la matriz de la clase 5_train: (5421, 5421)
# 	57302.png (5_train) vs 9450.png (5_train), Similitud: 0.8932
# 	23235.png (5_train) vs 23105.png (5_train), Similitud: 0.8928
# 	59338.png (5_train) vs 751.png (5_train), Similitud: 0.8903
# 	59459.png (5_train) vs 59426.png (5_train), Similitud: 0.8879
# 	36579.png (5_train) vs 36559.png (5_train), Similitud: 0.8878
# 	6363.png (5_train) vs 6401.png (5_train), Similitud: 0.8869
# 	23235.png (5_train) vs 23183.png (5_train), Similitud: 0.8857
# 	16426.png (5_train) vs 32052.png (5_train), Similitud: 0.8827
# 	51050.png (5_train) vs 18189.png (5_train), Similitud: 0.8814
# 	21059.png (5_train) vs 55823.png (5_train), Similitud: 0.8790
# 	20109.png (5_train) vs 20125.png (5_train), Similitud: 0.8780
# 	33221.png (5_train) vs 33077.png (5_train), Similitud: 0.8776
# 	25295.png (5_train) vs 59459.png (5_train), Similitud: 0.8766
# 	36217.png (5_train) vs 21819.png (5_train), Similitud: 0.8750
# 	273.png (5_train) vs 239.png (5_train), Similitud: 0.8747
# 	39689.png (5_train) vs 39539.png (5_train), Similitud: 0.8743
# 	33767.png (5_train) vs 33713.png (5_train), Similitud: 0.8727
# 	19741.png (5_train) vs 25483.png (5_train), Similitud: 0.8717
# 	55775.png (5_train) vs 55953.png (5_train), Similitud: 0.8711
# 	54465.png (5_train) vs 54429.png (5_train), Similitud: 0.8705
#
# Muestras más representativas de esta clase:
# 	#1: 23235.png con 2 apariciones
# 	#2: 59459.png con 2 apariciones
# 	#3: 57302.png con 1 apariciones
# 	#4: 9450.png con 1 apariciones
# 	#5: 23105.png con 1 apariciones
# 	#6: 59338.png con 1 apariciones
# 	#7: 751.png con 1 apariciones
# 	#8: 59426.png con 1 apariciones
# 	#9: 36579.png con 1 apariciones
# 	#10: 36559.png con 1 apariciones
#
#
# Clase: 6_train
# Forma de la matriz de la clase 6_train: (5918, 5918)
# 	56144.png (6_train) vs 50811.png (6_train), Similitud: 0.9293
# 	25435.png (6_train) vs 25499.png (6_train), Similitud: 0.9274
# 	5973.png (6_train) vs 10229.png (6_train), Similitud: 0.9263
# 	39379.png (6_train) vs 10307.png (6_train), Similitud: 0.9261
# 	11691.png (6_train) vs 11673.png (6_train), Similitud: 0.9251
# 	34905.png (6_train) vs 9872.png (6_train), Similitud: 0.9242
# 	42685.png (6_train) vs 42225.png (6_train), Similitud: 0.9200
# 	37990.png (6_train) vs 49258.png (6_train), Similitud: 0.9200
# 	42225.png (6_train) vs 43697.png (6_train), Similitud: 0.9188
# 	6456.png (6_train) vs 15674.png (6_train), Similitud: 0.9188
# 	28552.png (6_train) vs 22693.png (6_train), Similitud: 0.9172
# 	30904.png (6_train) vs 6031.png (6_train), Similitud: 0.9170
# 	30784.png (6_train) vs 20494.png (6_train), Similitud: 0.9169
# 	8792.png (6_train) vs 16788.png (6_train), Similitud: 0.9163
# 	19647.png (6_train) vs 42685.png (6_train), Similitud: 0.9163
# 	29275.png (6_train) vs 29295.png (6_train), Similitud: 0.9160
# 	43697.png (6_train) vs 19624.png (6_train), Similitud: 0.9158
# 	47877.png (6_train) vs 47911.png (6_train), Similitud: 0.9157
# 	14159.png (6_train) vs 14237.png (6_train), Similitud: 0.9152
# 	10229.png (6_train) vs 39385.png (6_train), Similitud: 0.9151
#
# Muestras más representativas de esta clase:
# 	#1: 10229.png con 2 apariciones
# 	#2: 42685.png con 2 apariciones
# 	#3: 42225.png con 2 apariciones
# 	#4: 43697.png con 2 apariciones
# 	#5: 56144.png con 1 apariciones
# 	#6: 50811.png con 1 apariciones
# 	#7: 25435.png con 1 apariciones
# 	#8: 25499.png con 1 apariciones
# 	#9: 5973.png con 1 apariciones
# 	#10: 39379.png con 1 apariciones
#
#
# Clase: 7_train
# Forma de la matriz de la clase 7_train: (6265, 6265)
# 	39651.png (7_train) vs 39605.png (7_train), Similitud: 0.9410
# 	12143.png (7_train) vs 23127.png (7_train), Similitud: 0.9306
# 	10243.png (7_train) vs 10309.png (7_train), Similitud: 0.9294
# 	16199.png (7_train) vs 32515.png (7_train), Similitud: 0.9286
# 	37245.png (7_train) vs 32515.png (7_train), Similitud: 0.9243
# 	1335.png (7_train) vs 10965.png (7_train), Similitud: 0.9239
# 	21937.png (7_train) vs 25439.png (7_train), Similitud: 0.9227
# 	41240.png (7_train) vs 29412.png (7_train), Similitud: 0.9223
# 	45314.png (7_train) vs 39687.png (7_train), Similitud: 0.9217
# 	19050.png (7_train) vs 29297.png (7_train), Similitud: 0.9215
# 	50227.png (7_train) vs 50697.png (7_train), Similitud: 0.9203
# 	58480.png (7_train) vs 47495.png (7_train), Similitud: 0.9201
# 	29333.png (7_train) vs 29277.png (7_train), Similitud: 0.9173
# 	10989.png (7_train) vs 20969.png (7_train), Similitud: 0.9172
# 	3317.png (7_train) vs 38819.png (7_train), Similitud: 0.9171
# 	29333.png (7_train) vs 8069.png (7_train), Similitud: 0.9170
# 	2090.png (7_train) vs 21949.png (7_train), Similitud: 0.9168
# 	9988.png (7_train) vs 9768.png (7_train), Similitud: 0.9168
# 	21783.png (7_train) vs 25363.png (7_train), Similitud: 0.9164
# 	11757.png (7_train) vs 1687.png (7_train), Similitud: 0.9163
#
# Muestras más representativas de esta clase:
# 	#1: 32515.png con 2 apariciones
# 	#2: 29333.png con 2 apariciones
# 	#3: 39651.png con 1 apariciones
# 	#4: 39605.png con 1 apariciones
# 	#5: 12143.png con 1 apariciones
# 	#6: 23127.png con 1 apariciones
# 	#7: 10243.png con 1 apariciones
# 	#8: 10309.png con 1 apariciones
# 	#9: 16199.png con 1 apariciones
# 	#10: 37245.png con 1 apariciones
#
#
# Clase: 8_train
# Forma de la matriz de la clase 8_train: (5851, 5851)
# 	19603.png (8_train) vs 10973.png (8_train), Similitud: 0.9233
# 	59393.png (8_train) vs 59399.png (8_train), Similitud: 0.9153
# 	53028.png (8_train) vs 37198.png (8_train), Similitud: 0.9151
# 	35242.png (8_train) vs 38858.png (8_train), Similitud: 0.9124
# 	36727.png (8_train) vs 36681.png (8_train), Similitud: 0.9082
# 	6369.png (8_train) vs 6093.png (8_train), Similitud: 0.9078
# 	11989.png (8_train) vs 12009.png (8_train), Similitud: 0.9077
# 	24769.png (8_train) vs 24757.png (8_train), Similitud: 0.9072
# 	6417.png (8_train) vs 6353.png (8_train), Similitud: 0.9045
# 	36677.png (8_train) vs 6093.png (8_train), Similitud: 0.9043
# 	50785.png (8_train) vs 50745.png (8_train), Similitud: 0.9009
# 	6891.png (8_train) vs 11989.png (8_train), Similitud: 0.9007
# 	48256.png (8_train) vs 31800.png (8_train), Similitud: 0.8999
# 	50869.png (8_train) vs 50873.png (8_train), Similitud: 0.8995
# 	28623.png (8_train) vs 28643.png (8_train), Similitud: 0.8992
# 	12943.png (8_train) vs 13089.png (8_train), Similitud: 0.8969
# 	23562.png (8_train) vs 33664.png (8_train), Similitud: 0.8968
# 	12009.png (8_train) vs 36681.png (8_train), Similitud: 0.8967
# 	6093.png (8_train) vs 33719.png (8_train), Similitud: 0.8964
# 	1207.png (8_train) vs 29319.png (8_train), Similitud: 0.8959
#
# Muestras más representativas de esta clase:
# 	#1: 6093.png con 3 apariciones
# 	#2: 36681.png con 2 apariciones
# 	#3: 11989.png con 2 apariciones
# 	#4: 12009.png con 2 apariciones
# 	#5: 19603.png con 1 apariciones
# 	#6: 10973.png con 1 apariciones
# 	#7: 59393.png con 1 apariciones
# 	#8: 59399.png con 1 apariciones
# 	#9: 53028.png con 1 apariciones
# 	#10: 37198.png con 1 apariciones
#
#
# Clase: 9_train
# Forma de la matriz de la clase 9_train: (5949, 5949)
# 	25303.png (9_train) vs 25323.png (9_train), Similitud: 0.9334
# 	16253.png (9_train) vs 16261.png (9_train), Similitud: 0.9277
# 	22256.png (9_train) vs 3770.png (9_train), Similitud: 0.9233
# 	47489.png (9_train) vs 6379.png (9_train), Similitud: 0.9216
# 	33215.png (9_train) vs 43343.png (9_train), Similitud: 0.9213
# 	29465.png (9_train) vs 29371.png (9_train), Similitud: 0.9198
# 	5233.png (9_train) vs 43167.png (9_train), Similitud: 0.9191
# 	36348.png (9_train) vs 7518.png (9_train), Similitud: 0.9182
# 	50851.png (9_train) vs 50867.png (9_train), Similitud: 0.9151
# 	26612.png (9_train) vs 30446.png (9_train), Similitud: 0.9133
# 	11557.png (9_train) vs 50110.png (9_train), Similitud: 0.9129
# 	11991.png (9_train) vs 30446.png (9_train), Similitud: 0.9118
# 	36793.png (9_train) vs 39997.png (9_train), Similitud: 0.9116
# 	47517.png (9_train) vs 24701.png (9_train), Similitud: 0.9116
# 	1399.png (9_train) vs 55938.png (9_train), Similitud: 0.9111
# 	39633.png (9_train) vs 38775.png (9_train), Similitud: 0.9105
# 	32816.png (9_train) vs 5999.png (9_train), Similitud: 0.9096
# 	14294.png (9_train) vs 42696.png (9_train), Similitud: 0.9090
# 	20084.png (9_train) vs 30277.png (9_train), Similitud: 0.9088
# 	31295.png (9_train) vs 31351.png (9_train), Similitud: 0.9087
#
# Muestras más representativas de esta clase:
# 	#1: 30446.png con 2 apariciones
# 	#2: 25303.png con 1 apariciones
# 	#3: 25323.png con 1 apariciones
# 	#4: 16253.png con 1 apariciones
# 	#5: 16261.png con 1 apariciones
# 	#6: 22256.png con 1 apariciones
# 	#7: 3770.png con 1 apariciones
# 	#8: 47489.png con 1 apariciones
# 	#9: 6379.png con 1 apariciones
# 	#10: 33215.png con 1 apariciones
